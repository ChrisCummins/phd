# %% [markdown]
# # Differential Test of CLgen kernels
#
# Run CLgen kernels on two different devices using the same inputs.
#
# Record any outputs which differ.

# %%
import clgen
clgen.platform_info()
# Out:
# CLgen:      0.2.15 (with CUDA)
# Platform:   Linux
# Memory:     32057 MB
#
# Device:     GPU GeForce GTX 1080
# Frequency:  1733 HZ
# Memory:     8114 MB
# Driver:     375.39
#
# Device:     CPU Intel(R) Xeon(R) CPU E5-2620 v4 @ 2.10GHz
# Frequency:  2100 HZ
# Memory:     32057 MB
# Driver:     1.2.0.25

# %% [markdown]
# ## 1. Experimental Results

# %% [markdown]
# Datasets:

# %%
# !ls -lh data/difftest/
# Out:
# total 107M
# -rw-r--r-- 1 cec cec  58M Mar 21 17:30 cpu.db
# -rw-rw-r-- 1 cec cec 1.8M Mar 21 17:30 cpu.log
# -rw-r--r-- 1 cec cec  46M Mar 21 17:30 gpu.db
# -rw-rw-r-- 1 cec cec 2.1M Mar 21 17:30 gpu.log
# drwxrwxr-x 2 cec cec 4.0K Mar 28 03:27 reports
# drwxrwxr-x 2 cec cec 4.0K Mar 28 03:31 verified

# %% [markdown]
# Load datasets. Set `in1` and `in2` appropriately:

# %%
from clgen import dbutil
from labm8 import fs

in1 = fs.path("data/difftest/cpu.db")
in2 = fs.path("data/difftest/gpu.db")

in1base = fs.basename(in1)
in2base = fs.basename(in2)

db1 = dbutil.connect(in1)
db2 = dbutil.connect(in2)

c1 = db1.cursor()
c2 = db2.cursor()

c1.execute("ATTACH DATABASE '{in2}' AS rhs".format(**vars()))
c2.execute("ATTACH DATABASE '{in1}' AS rhs".format(**vars()))

# num results
n1 = dbutil.num_rows_in(in1, "Data")
n2 = dbutil.num_rows_in(in2, "Data")

# metadata
device1 = dbutil.get_meta(in1, "device")
device2 = dbutil.get_meta(in2, "device")

host1 = dbutil.get_meta(in1, "host")
host2 = dbutil.get_meta(in2, "host")

c1.execute("""
SELECT COUNT(*)
FROM Data AS lData INNER JOIN rhs.Data AS rData ON lData.id=rData.id
""")
n3 = c1.fetchone()[0]

c1.execute("""
SELECT
    lData.id AS id,
    lData.status AS lstatus, rData.status AS rstatus,
    lData.result AS ldata, rData.result AS rdata
FROM Data AS lData INNER JOIN rhs.Data AS rData ON lData.id=rData.id
WHERE lData.result != "" AND rData.result != ""
""")
cdata = c1.fetchall()
ncdata = len(cdata)

print("""\
Number of results for {device1} on {host1}: {n1}.
Number of results for {device2} on {host2}: {n2}.
Number of common results: {n3}.
Number of common good results: {ncdata}.\
""".format(**vars()))
# Out:
# Number of results for Intel(R) Xeon(R) CPU E5-2620 v4 @ 2.10GHz on cc1: 13489.
# Number of results for GeForce GTX 1080 on cc1: 18070.
# Number of common results: 5129.
# Number of common good results: 940.

# %% [markdown]
# ## 2. Evaluation
#
# ### Per-device results

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from labm8 import viz

plt.style.use(["seaborn-white", "seaborn-paper"])
# %matplotlib inline

STATUS = ["ok", "ok (no outputs)", "ok (input insenstive)", "nondeterministic", "bad driver", "bad code"]

def plot_dist(path):
    basename = fs.basename(path)
    c = dbutil.connect(path).cursor()
    c.execute("SELECT status, COUNT(status) FROM Data GROUP BY status ORDER BY status")
    d = [{"status": STATUS[i], "n": x} for i, x in c.fetchall()]
    ax = sns.barplot(x="status", y="n", data=pd.DataFrame(d))
    device = dbutil.get_meta(path, "device")
    host = dbutil.get_meta(path, "host")
    plt.title("{device} on {host}".format(**vars()))
    plt.setp(ax.get_xticklabels(), rotation=45)  # rotate x ticks
    plt.xlabel("")
    plt.ylabel("#. results")

ax = plt.subplot(1, 2, 1)
plot_dist(in1)
ax = plt.subplot(1, 2, 2)
plot_dist(in2)

viz.finalise(figsize=(9, 4))

# %% [markdown]
# ### Generate reports

# %%
# write report files to:
reportdir = "data/difftest/reports"
fs.mkdir(reportdir)

# !rm -rf data/difftest/reports/*.txt

# %%
import json
import sys

from clgen.clutil import KernelPrototype

numstatusdiff = 0
numdatadiff = 0

def diff_arrays(t1, t2, fromfile="A", tofile="B"):
    diff = ["   | {fromfile} | {tofile}\n".format(**vars())]
    for i, (x, y) in enumerate(zip(t1, t2)):
        x = x.strip()
        y = y.strip()
        if x != y:
            diff.append("{i}: | {x} | {y}\n".format(**vars()))
    return diff
    

def get_src(c, id):
    c.execute("SELECT Source FROM Source WHERE id=?", (id,))
    r = c.fetchone()
    assert(len(r) == 1)
    return r[0]

for row in cdata:
    id, lstatus, rstatus, ldata, rdata = row

    if ldata != rdata:
        reportpath = fs.path(reportdir, "{id}-data.txt".format(**vars()))
        print("Data diff:", fs.basename(reportpath))        

        src1 = get_src(c1, id)
        src2 = get_src(c2, id)
        assert(src1 == src2)  # sanity check for hash collisions

        src_size = len(src1.split('\n'))
        prototype = KernelPrototype.from_source(src1)
        
        report = """\
===================================================
Kernel {id} ({src_size} lines):
===================================================

{src1}
""".format(**vars())
        
        srcpath = fs.path(reportdir, "{id}".format(**vars()))
        with open(srcpath, "w") as outfile:
            print(src1, file=outfile)
            
        ld = json.loads(ldata)
        rd = json.loads(rdata)
        assert(len(ld) == len(rd))  # payloads should have same length
        for i, r in enumerate(zip(ld, rd)):
            a1, a2 = r
            if a1 != a2:
                assert(len(a1) == len(a2))
   
                argtype = prototype.args[i]
                t1 = ["{}\n".format(x) for x in a1]
                t2 = ["{}\n".format(x) for x in a2]

                diff = diff_arrays(t1, t2, fromfile=device1, tofile=device2)
                diff_size = len(diff)
                diff = ''.join(diff)

                report += """\

===================================================
Output diff ({diff_size} lines) for arg {i}: {argtype}
===================================================

{diff}
""".format(**vars())
        
        with open(reportpath, "w") as reportfile:
            print(report, file=reportfile)
        numdatadiff += 1
    elif lstatus != rstatus:
        reportpath = fs.path(reportdir, "{id}-status.txt".format(**vars()))
        print("Status mismatch:", fs.basename(reportpath))
        
        STATUS = ["ok", "ok (no outputs)", "ok (input insenstive)", "nondeterministic", "bad driver", "bad code"]
        lstatus_txt = STATUS[lstatus]
        rstatus_txt = STATUS[rstatus]
        
        src1 = get_src(c1, id)
        src2 = get_src(c2, id)
        assert(src1 == src2)  # sanity check for hash collisions

        src_size = len(src1.split('\n'))

        report = """\
===================================================
Kernel {id} ({src_size} lines):
===================================================

{src1}

===================================================
Status mismatch:
===================================================

On {device1}: {lstatus_txt}
On {device2}: {rstatus_txt}
""".format(**vars())
        
        with open(reportpath, "w") as reportfile:
            print(report, file=reportfile)
        numstatusdiff += 1

n = len(cdata)
ratiostatusdiff = numstatusdiff / n
ratiodatadiff = numdatadiff / n
# Out:
# Data diff: 2706a7641f6178a675e80452fbfeca7ff3102b61.cl-data.txt
# Status mismatch: dcae239e1575c36df29326d586a6f9d70e57fb43.cl-status.txt
# Status mismatch: 9a16d4ce0fc164cb819a2a7c1508db9bd46629b5.cl-status.txt
# Data diff: e6b800e780afb35834c7d3ae96bbe57614e672fd.cl-data.txt
# Data diff: 8438b222e9a30fee8e0ba7910f1cd16d0c6ff9e8.cl-data.txt
# Data diff: 1ba6c22be25beda62bbef93cffec60c7c0970aae.cl-data.txt
# Data diff: 2a7583ba751fcc43999838e557f4257c58ce485e.cl-data.txt
# Data diff: 3de6c77341cfe05fe061ccbded043992094a170e.cl-data.txt
# Data diff: d745ff1ac43d192305833d0eee51df7cb8471603.cl-data.txt
# Data diff: cc4bd1b35e3f5181dc8bb084588ab48b24f349a4.cl-data.txt
# Data diff: cb21ab8e7056fa503d2d6100229cdae10aa26551.cl-data.txt
# Data diff: 2e202fb8472dd387791f1135f7e66e14e0c530cf.cl-data.txt
# Data diff: 19f51ce8f48716a0aea3083ceb1cf3453dacbec5.cl-data.txt
# Data diff: c3931a439a77f4130dcdd8874840b9b126348a42.cl-data.txt
# Data diff: 78434994bda77b8c9fb6b50d68be4e73b98b8151.cl-data.txt
# Data diff: 1df64378ef0bf6c406b2cb0ccc1012ddd6f65c60.cl-data.txt
# Data diff: 56e4ac3401d595b6f177d09bbc907a95f00a5484.cl-data.txt
# Data diff: c7a2276115e39e10e2f557c70c3e4f6274064e19.cl-data.txt
# Data diff: 7a185bdce5d0592df89c909c997fe2c06167bae6.cl-data.txt
# Data diff: 8636af9dc8212f5eefbe33f81ff6b262e5c2d566.cl-data.txt
# Data diff: e32e15e81a1470f695a323479c50533b0e3da388.cl-data.txt
# Data diff: 2e218b0e3e8f74eb3410a95de77bc10f91417612.cl-data.txt
# Data diff: 20e78fde43680b5832a80409fa64ae99dec36fd7.cl-data.txt
# Data diff: 7e9e6f3a63e717f71a40b4ca2eb61955dc4922ce.cl-data.txt
# Data diff: 956ce221a3637da86d18478ce59aaa2d653852ec.cl-data.txt
# Data diff: 04a16f578844d69c2a807dd494d7017af29d245a.cl-data.txt
# Status mismatch: d1214b0f7e3405edf4a79f159ecd073b061fa379.cl-status.txt
# Data diff: b51b307903d763b4307ea9ca638d9a239f716ed3.cl-data.txt
# Data diff: ee8a2e6632acc975c3f31b0779cded670bcc0c48.cl-data.txt
# Data diff: c39bdd07980a3ea026aaf091a5108a4d787d5cb4.cl-data.txt
# Data diff: 2fe3a72f1e60cb450d821ec61704bb9a74680fe6.cl-data.txt
# Data diff: 797cc4722f7d767fd04f845224c9faefcdd211b4.cl-data.txt
# Data diff: 0ed6e85e4289df27e83830231e3abf60742d6695.cl-data.txt
# Data diff: 5b5e8a390ad181d14d340d20daed8f0a602530bb.cl-data.txt
# Data diff: fd3f74620c0042b5187e0b4bdc62ef02147f9dbe.cl-data.txt
# Data diff: fb4547b1c0e4b251a6d3fb9d30d90a9b95fe2555.cl-data.txt
# Data diff: 5a3188ee0d18f6f2bf890d377de62a82dd1316e2.cl-data.txt
# Data diff: b3b9b0bc3d558a92c7077cbe39e0e7b4e4f9a8f5.cl-data.txt
# Data diff: cd6d6de046fcd79e1b31ed35ebc1062a2721378c.cl-data.txt
# Data diff: 68b3a692863975742bf5541b04c321b06c7d6e6e.cl-data.txt
# Data diff: d7a75ff493af21b74b40292ea0f81fd681f72b48.cl-data.txt
# Data diff: 78663bf3a85a4c870485e7049a19e85f1b8ca9e8.cl-data.txt
# Data diff: ea4b51a499933c2586b1fff6109cb8061e989680.cl-data.txt
# Data diff: c8e8fc25ae9e7bda2ef21fd9e29992ae97609236.cl-data.txt
# Data diff: 89d1fa1256f997f376690c903cba1f8652e43bf1.cl-data.txt
# Data diff: 17e6c8bcee409d5db27fbbc60f22e58e50aed6d6.cl-data.txt
# Data diff: 8738e95338f5b843f92a72b0520f97cca46b1ed9.cl-data.txt
# Data diff: d119d5ebb05f11f7859568499d5f9e54d002eda7.cl-data.txt
# Data diff: a9258b916a92fa2c189c94276d2ddd4341f16038.cl-data.txt
# Data diff: 65932dd44f7c37444488d1950ed6c6753e703d1b.cl-data.txt
# Data diff: f180a86f847d4c721ed3b1a3c81374aafef7aa81.cl-data.txt
# Status mismatch: 3e72be107ecd1568f6e285871d3a938c10055f7a.cl-status.txt
# Data diff: 1e7ec8f208eaf040e25f9bae47232c17d9b5892d.cl-data.txt
# Data diff: 81e5c6965b73f0d23e0e69b8a8120f3363457005.cl-data.txt
# Data diff: adc686ee51cca3710bd40a02053a73fdc73d94ae.cl-data.txt
# Data diff: 6fb9d002f73b4d430bbd799d118c9d3ea043afc5.cl-data.txt
# Data diff: 26496231dee4b4696b399b9caab80e57e37047a7.cl-data.txt
# Data diff: 3e42e3b385260a4dd4e74c522bf777313d394487.cl-data.txt
# Data diff: 8a5af2af494b578f66f3053d7db22dad097e5ebd.cl-data.txt
# Data diff: 422c8160a26b3c757c13021c74b195547e40456c.cl-data.txt
# Data diff: faa7dea520abcb9a526d6243f6d9b32659b657b0.cl-data.txt
# Data diff: d554f7034b79009041967428ec18bcfc633f149f.cl-data.txt
# Data diff: c3a9bfc99018dbac0fb18ec041661d46d423dc00.cl-data.txt
# Data diff: 4689740817172b7a4fd627707cc5b391637607d6.cl-data.txt
# Data diff: 9d29169a3ea3d5bb80f7234f6c2cd97484b7b8c5.cl-data.txt
# Data diff: 9af2073dfc983267f7895897c94124c31af40903.cl-data.txt
# Data diff: 255409f28fe8056cf6072e6de09a7d1b86f4a23e.cl-data.txt
# Data diff: 2edf9e7802bc5fe0cf00cd99e55bd7cb53bbfbf6.cl-data.txt

# %%
print("Of {n} results, {numstatusdiff} ({ratiostatusdiff:.2%}) resuulted in different statuses".format(**vars()))
print("Of {n} results, {numdatadiff} ({ratiodatadiff:.2%}) resulted in different data".format(**vars()))
# Out:
# Of 940 results, 4 (0.43%) resuulted in different statuses
# Of 940 results, 64 (6.81%) resulted in different data

# %% [markdown]
# ## Run GPUVerify on diff kernels
#
# "diff" kernels are those which have a difference in the computed data or runtime status when ran on different hardware.

# %%
from clgen import preprocess

src = """\
__kernel void A(__global int* a) {
  a[get_global_id(0)] *= 2.0f;
}
"""

print(preprocess.gpuverify(src, ["--local_size=64", "--num_groups=128"]))
# Out:
# __kernel void A(__global int* a) {
#   a[get_global_id(0)] *= 2.0f;
# }

# %%
# !rm -rf data/difftest/verified

import sys
kernels = [x for x in fs.ls(fs.path("data/difftest/reports"), abspaths=True) if x.endswith(".cl")]

fs.mkdir("data/difftest/verified")

err_count = 0
for path in kernels:
    with open(path) as infile:
        src = infile.read()
        try:
            preprocess.gpuverify(src, ["--local_size=64", "--num_groups=128"])
            
            outpath = fs.path("data/difftest/verified", fs.basename(path))
            with open(outpath, "w") as outfile:
                print(src, file=outfile)
        except preprocess.GPUVerifyException as e:
            outpath = fs.path("data/difftest/verified", fs.basename(path) + ".report")
            with open(outpath, "w") as outfile:
                print(e, file=outfile)
            err_count += 1
            
        print(outpath)
# Out:
# /home/cec/src/project_b/data/difftest/reports/04a16f578844d69c2a807dd494d7017af29d245a.cl
# /home/cec/src/project_b/data/difftest/reports/0ed6e85e4289df27e83830231e3abf60742d6695.cl
# /home/cec/src/project_b/data/difftest/reports/17e6c8bcee409d5db27fbbc60f22e58e50aed6d6.cl
# /home/cec/src/project_b/data/difftest/reports/19f51ce8f48716a0aea3083ceb1cf3453dacbec5.cl
# /home/cec/src/project_b/data/difftest/reports/1ba6c22be25beda62bbef93cffec60c7c0970aae.cl
# /home/cec/src/project_b/data/difftest/reports/1df64378ef0bf6c406b2cb0ccc1012ddd6f65c60.cl
# /home/cec/src/project_b/data/difftest/reports/1e7ec8f208eaf040e25f9bae47232c17d9b5892d.cl
# /home/cec/src/project_b/data/difftest/reports/20e78fde43680b5832a80409fa64ae99dec36fd7.cl
# /home/cec/src/project_b/data/difftest/reports/255409f28fe8056cf6072e6de09a7d1b86f4a23e.cl
# /home/cec/src/project_b/data/difftest/reports/26496231dee4b4696b399b9caab80e57e37047a7.cl
# /home/cec/src/project_b/data/difftest/reports/2706a7641f6178a675e80452fbfeca7ff3102b61.cl
# /home/cec/src/project_b/data/difftest/reports/2a7583ba751fcc43999838e557f4257c58ce485e.cl
# /home/cec/src/project_b/data/difftest/reports/2e202fb8472dd387791f1135f7e66e14e0c530cf.cl
# /home/cec/src/project_b/data/difftest/reports/2e218b0e3e8f74eb3410a95de77bc10f91417612.cl
# /home/cec/src/project_b/data/difftest/reports/2edf9e7802bc5fe0cf00cd99e55bd7cb53bbfbf6.cl
# /home/cec/src/project_b/data/difftest/reports/2fe3a72f1e60cb450d821ec61704bb9a74680fe6.cl
# /home/cec/src/project_b/data/difftest/reports/3de6c77341cfe05fe061ccbded043992094a170e.cl
# /home/cec/src/project_b/data/difftest/reports/3e42e3b385260a4dd4e74c522bf777313d394487.cl
# /home/cec/src/project_b/data/difftest/reports/422c8160a26b3c757c13021c74b195547e40456c.cl
# /home/cec/src/project_b/data/difftest/reports/4689740817172b7a4fd627707cc5b391637607d6.cl
# /home/cec/src/project_b/data/difftest/reports/56e4ac3401d595b6f177d09bbc907a95f00a5484.cl
# /home/cec/src/project_b/data/difftest/reports/5a3188ee0d18f6f2bf890d377de62a82dd1316e2.cl
# /home/cec/src/project_b/data/difftest/reports/5b5e8a390ad181d14d340d20daed8f0a602530bb.cl
# /home/cec/src/project_b/data/difftest/reports/65932dd44f7c37444488d1950ed6c6753e703d1b.cl
# /home/cec/src/project_b/data/difftest/reports/68b3a692863975742bf5541b04c321b06c7d6e6e.cl
# /home/cec/src/project_b/data/difftest/reports/6fb9d002f73b4d430bbd799d118c9d3ea043afc5.cl
# /home/cec/src/project_b/data/difftest/reports/78434994bda77b8c9fb6b50d68be4e73b98b8151.cl
# /home/cec/src/project_b/data/difftest/reports/78663bf3a85a4c870485e7049a19e85f1b8ca9e8.cl
# /home/cec/src/project_b/data/difftest/reports/797cc4722f7d767fd04f845224c9faefcdd211b4.cl
# /home/cec/src/project_b/data/difftest/reports/7a185bdce5d0592df89c909c997fe2c06167bae6.cl
# /home/cec/src/project_b/data/difftest/reports/7e9e6f3a63e717f71a40b4ca2eb61955dc4922ce.cl
# /home/cec/src/project_b/data/difftest/reports/81e5c6965b73f0d23e0e69b8a8120f3363457005.cl
# /home/cec/src/project_b/data/difftest/reports/8438b222e9a30fee8e0ba7910f1cd16d0c6ff9e8.cl
# /home/cec/src/project_b/data/difftest/reports/8636af9dc8212f5eefbe33f81ff6b262e5c2d566.cl
# /home/cec/src/project_b/data/difftest/reports/8738e95338f5b843f92a72b0520f97cca46b1ed9.cl
# /home/cec/src/project_b/data/difftest/reports/89d1fa1256f997f376690c903cba1f8652e43bf1.cl
# /home/cec/src/project_b/data/difftest/reports/8a5af2af494b578f66f3053d7db22dad097e5ebd.cl
# /home/cec/src/project_b/data/difftest/reports/956ce221a3637da86d18478ce59aaa2d653852ec.cl
# /home/cec/src/project_b/data/difftest/reports/9af2073dfc983267f7895897c94124c31af40903.cl
# /home/cec/src/project_b/data/difftest/reports/9d29169a3ea3d5bb80f7234f6c2cd97484b7b8c5.cl
# /home/cec/src/project_b/data/difftest/reports/a9258b916a92fa2c189c94276d2ddd4341f16038.cl
# /home/cec/src/project_b/data/difftest/reports/adc686ee51cca3710bd40a02053a73fdc73d94ae.cl
# /home/cec/src/project_b/data/difftest/reports/b3b9b0bc3d558a92c7077cbe39e0e7b4e4f9a8f5.cl
# /home/cec/src/project_b/data/difftest/reports/b51b307903d763b4307ea9ca638d9a239f716ed3.cl
# /home/cec/src/project_b/data/difftest/reports/c3931a439a77f4130dcdd8874840b9b126348a42.cl
# /home/cec/src/project_b/data/difftest/reports/c39bdd07980a3ea026aaf091a5108a4d787d5cb4.cl
# /home/cec/src/project_b/data/difftest/reports/c3a9bfc99018dbac0fb18ec041661d46d423dc00.cl
# /home/cec/src/project_b/data/difftest/reports/c7a2276115e39e10e2f557c70c3e4f6274064e19.cl
# /home/cec/src/project_b/data/difftest/reports/c8e8fc25ae9e7bda2ef21fd9e29992ae97609236.cl
# /home/cec/src/project_b/data/difftest/reports/cb21ab8e7056fa503d2d6100229cdae10aa26551.cl
# /home/cec/src/project_b/data/difftest/reports/cc4bd1b35e3f5181dc8bb084588ab48b24f349a4.cl
# /home/cec/src/project_b/data/difftest/reports/cd6d6de046fcd79e1b31ed35ebc1062a2721378c.cl
# /home/cec/src/project_b/data/difftest/reports/d119d5ebb05f11f7859568499d5f9e54d002eda7.cl
# /home/cec/src/project_b/data/difftest/reports/d554f7034b79009041967428ec18bcfc633f149f.cl
# /home/cec/src/project_b/data/difftest/reports/d745ff1ac43d192305833d0eee51df7cb8471603.cl
# /home/cec/src/project_b/data/difftest/reports/d7a75ff493af21b74b40292ea0f81fd681f72b48.cl
# /home/cec/src/project_b/data/difftest/reports/e32e15e81a1470f695a323479c50533b0e3da388.cl
# /home/cec/src/project_b/data/difftest/reports/e6b800e780afb35834c7d3ae96bbe57614e672fd.cl
# /home/cec/src/project_b/data/difftest/reports/ea4b51a499933c2586b1fff6109cb8061e989680.cl
# /home/cec/src/project_b/data/difftest/reports/ee8a2e6632acc975c3f31b0779cded670bcc0c48.cl
# /home/cec/src/project_b/data/difftest/reports/f180a86f847d4c721ed3b1a3c81374aafef7aa81.cl
# /home/cec/src/project_b/data/difftest/reports/faa7dea520abcb9a526d6243f6d9b32659b657b0.cl
# /home/cec/src/project_b/data/difftest/reports/fb4547b1c0e4b251a6d3fb9d30d90a9b95fe2555.cl
# /home/cec/src/project_b/data/difftest/reports/fd3f74620c0042b5187e0b4bdc62ef02147f9dbe.cl

# %%
n = len(kernels)
err_ratio = err_count / n

print("Of {n} kernels, {err_count} ({err_ratio:.2%}) were found by GPUVerify to contain errors.".format(**vars()))
# Out:
# Of 64 kernels, 34 (53.12%) were found by GPUVerify to contain errors.

# %% [markdown]
# ## Run Oclgrind on verified kernels

# %%
import subprocess
from clgen import native

def oclgrind(path):
    _oclgrind = native.OCLGRIND
    print(path)
    out = subprocess.check_output([_oclgrind, "cldrive", path])
    print(out.decode('utf-8'))

kernels = [x for x in fs.ls(fs.path("data/difftest/verified"), abspaths=True) if x.endswith(".cl")]

# err_count = 0
for path in kernels:
    with open(path) as infile:
        oclgrind(path)
# Out:
# /home/cec/src/project_b/data/difftest/verified/04a16f578844d69c2a807dd494d7017af29d245a.cl
# 04a16f578844d69c2a807dd494d7017af29d245a.cl,32,A,Oclgrind,Oclgrind Simulator,32,512,17.518080
# 04a16f578844d69c2a807dd494d7017af29d245a.cl,32,A,Oclgrind,Oclgrind Simulator,32,512,9.229056
# 04a16f578844d69c2a807dd494d7017af29d245a.cl,32,A,Oclgrind,Oclgrind Simulator,32,512,3.899648
# 04a16f578844d69c2a807dd494d7017af29d245a.cl,32,A,Oclgrind,Oclgrind Simulator,32,512,3.390208
# 04a16f578844d69c2a807dd494d7017af29d245a.cl,32,A,Oclgrind,Oclgrind Simulator,32,512,3.413248
# 04a16f578844d69c2a807dd494d7017af29d245a.cl,32,A,Oclgrind,Oclgrind Simulator,32,512,234.989056
# 04a16f578844d69c2a807dd494d7017af29d245a.cl,32,A,Oclgrind,Oclgrind Simulator,32,512,88.268032
# 04a16f578844d69c2a807dd494d7017af29d245a.cl,32,A,Oclgrind,Oclgrind Simulator,32,512,37.971968
# 04a16f578844d69c2a807dd494d7017af29d245a.cl,32,A,Oclgrind,Oclgrind Simulator,32,512,2.823168
# 04a16f578844d69c2a807dd494d7017af29d245a.cl,32,A,Oclgrind,Oclgrind Simulator,32,512,8.197888
#
# /home/cec/src/project_b/data/difftest/verified/17e6c8bcee409d5db27fbbc60f22e58e50aed6d6.cl
# 17e6c8bcee409d5db27fbbc60f22e58e50aed6d6.cl,2048,A,Oclgrind,Oclgrind Simulator,256,24576,13.786112
# 17e6c8bcee409d5db27fbbc60f22e58e50aed6d6.cl,2048,A,Oclgrind,Oclgrind Simulator,256,24576,10.194944
# 17e6c8bcee409d5db27fbbc60f22e58e50aed6d6.cl,2048,A,Oclgrind,Oclgrind Simulator,256,24576,5.932032
# 17e6c8bcee409d5db27fbbc60f22e58e50aed6d6.cl,2048,A,Oclgrind,Oclgrind Simulator,256,24576,5.863168
# 17e6c8bcee409d5db27fbbc60f22e58e50aed6d6.cl,2048,A,Oclgrind,Oclgrind Simulator,256,24576,5.392128
# 17e6c8bcee409d5db27fbbc60f22e58e50aed6d6.cl,2048,A,Oclgrind,Oclgrind Simulator,256,24576,4.892928
# 17e6c8bcee409d5db27fbbc60f22e58e50aed6d6.cl,2048,A,Oclgrind,Oclgrind Simulator,256,24576,4.711936
# 17e6c8bcee409d5db27fbbc60f22e58e50aed6d6.cl,2048,A,Oclgrind,Oclgrind Simulator,256,24576,4.527104
# 17e6c8bcee409d5db27fbbc60f22e58e50aed6d6.cl,2048,A,Oclgrind,Oclgrind Simulator,256,24576,4.487936
# 17e6c8bcee409d5db27fbbc60f22e58e50aed6d6.cl,2048,A,Oclgrind,Oclgrind Simulator,256,24576,4.285184
#
# /home/cec/src/project_b/data/difftest/verified/19f51ce8f48716a0aea3083ceb1cf3453dacbec5.cl
# 19f51ce8f48716a0aea3083ceb1cf3453dacbec5.cl,32,A,Oclgrind,Oclgrind Simulator,32,256,1.055232
# 19f51ce8f48716a0aea3083ceb1cf3453dacbec5.cl,32,A,Oclgrind,Oclgrind Simulator,32,256,0.946944
# 19f51ce8f48716a0aea3083ceb1cf3453dacbec5.cl,32,A,Oclgrind,Oclgrind Simulator,32,256,0.473088
# 19f51ce8f48716a0aea3083ceb1cf3453dacbec5.cl,32,A,Oclgrind,Oclgrind Simulator,32,256,0.779008
# 19f51ce8f48716a0aea3083ceb1cf3453dacbec5.cl,32,A,Oclgrind,Oclgrind Simulator,32,256,0.318976
# 19f51ce8f48716a0aea3083ceb1cf3453dacbec5.cl,32,A,Oclgrind,Oclgrind Simulator,32,256,0.780032
# 19f51ce8f48716a0aea3083ceb1cf3453dacbec5.cl,32,A,Oclgrind,Oclgrind Simulator,32,256,0.358912
# 19f51ce8f48716a0aea3083ceb1cf3453dacbec5.cl,32,A,Oclgrind,Oclgrind Simulator,32,256,0.766976
# 19f51ce8f48716a0aea3083ceb1cf3453dacbec5.cl,32,A,Oclgrind,Oclgrind Simulator,32,256,0.422144
# 19f51ce8f48716a0aea3083ceb1cf3453dacbec5.cl,32,A,Oclgrind,Oclgrind Simulator,32,256,0.727040
#
# /home/cec/src/project_b/data/difftest/verified/20e78fde43680b5832a80409fa64ae99dec36fd7.cl
# 20e78fde43680b5832a80409fa64ae99dec36fd7.cl,4096,A,Oclgrind,Oclgrind Simulator,256,98304,27.987200
# 20e78fde43680b5832a80409fa64ae99dec36fd7.cl,4096,A,Oclgrind,Oclgrind Simulator,256,98304,7.006976
# 20e78fde43680b5832a80409fa64ae99dec36fd7.cl,4096,A,Oclgrind,Oclgrind Simulator,256,98304,5.892096
# 20e78fde43680b5832a80409fa64ae99dec36fd7.cl,4096,A,Oclgrind,Oclgrind Simulator,256,98304,6.709760
# 20e78fde43680b5832a80409fa64ae99dec36fd7.cl,4096,A,Oclgrind,Oclgrind Simulator,256,98304,6.309120
# 20e78fde43680b5832a80409fa64ae99dec36fd7.cl,4096,A,Oclgrind,Oclgrind Simulator,256,98304,5.820928
# 20e78fde43680b5832a80409fa64ae99dec36fd7.cl,4096,A,Oclgrind,Oclgrind Simulator,256,98304,5.662976
# 20e78fde43680b5832a80409fa64ae99dec36fd7.cl,4096,A,Oclgrind,Oclgrind Simulator,256,98304,5.761792
# 20e78fde43680b5832a80409fa64ae99dec36fd7.cl,4096,A,Oclgrind,Oclgrind Simulator,256,98304,5.640960
# 20e78fde43680b5832a80409fa64ae99dec36fd7.cl,4096,A,Oclgrind,Oclgrind Simulator,256,98304,5.543936
#
# /home/cec/src/project_b/data/difftest/verified/26496231dee4b4696b399b9caab80e57e37047a7.cl
# 26496231dee4b4696b399b9caab80e57e37047a7.cl,1024,A,Oclgrind,Oclgrind Simulator,256,24576,5.995520
# 26496231dee4b4696b399b9caab80e57e37047a7.cl,1024,A,Oclgrind,Oclgrind Simulator,256,24576,3.697152
# 26496231dee4b4696b399b9caab80e57e37047a7.cl,1024,A,Oclgrind,Oclgrind Simulator,256,24576,10.245888
# 26496231dee4b4696b399b9caab80e57e37047a7.cl,1024,A,Oclgrind,Oclgrind Simulator,256,24576,5.149440
# 26496231dee4b4696b399b9caab80e57e37047a7.cl,1024,A,Oclgrind,Oclgrind Simulator,256,24576,3.375616
# 26496231dee4b4696b399b9caab80e57e37047a7.cl,1024,A,Oclgrind,Oclgrind Simulator,256,24576,5.542912
# 26496231dee4b4696b399b9caab80e57e37047a7.cl,1024,A,Oclgrind,Oclgrind Simulator,256,24576,2.638080
# 26496231dee4b4696b399b9caab80e57e37047a7.cl,1024,A,Oclgrind,Oclgrind Simulator,256,24576,1.715968
# 26496231dee4b4696b399b9caab80e57e37047a7.cl,1024,A,Oclgrind,Oclgrind Simulator,256,24576,2.391040
# 26496231dee4b4696b399b9caab80e57e37047a7.cl,1024,A,Oclgrind,Oclgrind Simulator,256,24576,1.745152
#
# /home/cec/src/project_b/data/difftest/verified/2e218b0e3e8f74eb3410a95de77bc10f91417612.cl
# 2e218b0e3e8f74eb3410a95de77bc10f91417612.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,37.720320
# 2e218b0e3e8f74eb3410a95de77bc10f91417612.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,13.851904
# 2e218b0e3e8f74eb3410a95de77bc10f91417612.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,12.345088
# 2e218b0e3e8f74eb3410a95de77bc10f91417612.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,13.709056
# 2e218b0e3e8f74eb3410a95de77bc10f91417612.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,10.753024
# 2e218b0e3e8f74eb3410a95de77bc10f91417612.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,10.349056
# 2e218b0e3e8f74eb3410a95de77bc10f91417612.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,10.607104
# 2e218b0e3e8f74eb3410a95de77bc10f91417612.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,9.827072
# 2e218b0e3e8f74eb3410a95de77bc10f91417612.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,9.294848
# 2e218b0e3e8f74eb3410a95de77bc10f91417612.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,8.391680
#
# /home/cec/src/project_b/data/difftest/verified/2edf9e7802bc5fe0cf00cd99e55bd7cb53bbfbf6.cl
# 2edf9e7802bc5fe0cf00cd99e55bd7cb53bbfbf6.cl,4096,A,Oclgrind,Oclgrind Simulator,256,49152,30.964992
# 2edf9e7802bc5fe0cf00cd99e55bd7cb53bbfbf6.cl,4096,A,Oclgrind,Oclgrind Simulator,256,49152,7.817984
# 2edf9e7802bc5fe0cf00cd99e55bd7cb53bbfbf6.cl,4096,A,Oclgrind,Oclgrind Simulator,256,49152,9.203200
# 2edf9e7802bc5fe0cf00cd99e55bd7cb53bbfbf6.cl,4096,A,Oclgrind,Oclgrind Simulator,256,49152,7.019776
# 2edf9e7802bc5fe0cf00cd99e55bd7cb53bbfbf6.cl,4096,A,Oclgrind,Oclgrind Simulator,256,49152,8.280064
# 2edf9e7802bc5fe0cf00cd99e55bd7cb53bbfbf6.cl,4096,A,Oclgrind,Oclgrind Simulator,256,49152,6.428928
# 2edf9e7802bc5fe0cf00cd99e55bd7cb53bbfbf6.cl,4096,A,Oclgrind,Oclgrind Simulator,256,49152,6.254080
# 2edf9e7802bc5fe0cf00cd99e55bd7cb53bbfbf6.cl,4096,A,Oclgrind,Oclgrind Simulator,256,49152,7.484928
# 2edf9e7802bc5fe0cf00cd99e55bd7cb53bbfbf6.cl,4096,A,Oclgrind,Oclgrind Simulator,256,49152,6.282240
# 2edf9e7802bc5fe0cf00cd99e55bd7cb53bbfbf6.cl,4096,A,Oclgrind,Oclgrind Simulator,256,49152,5.976064
#
# /home/cec/src/project_b/data/difftest/verified/2fe3a72f1e60cb450d821ec61704bb9a74680fe6.cl
# 2fe3a72f1e60cb450d821ec61704bb9a74680fe6.cl,512,A,Oclgrind,Oclgrind Simulator,256,13312,24.976640
# 2fe3a72f1e60cb450d821ec61704bb9a74680fe6.cl,512,A,Oclgrind,Oclgrind Simulator,256,13312,23.712768
# 2fe3a72f1e60cb450d821ec61704bb9a74680fe6.cl,512,A,Oclgrind,Oclgrind Simulator,256,13312,6.247168
# 2fe3a72f1e60cb450d821ec61704bb9a74680fe6.cl,512,A,Oclgrind,Oclgrind Simulator,256,13312,6.379008
# 2fe3a72f1e60cb450d821ec61704bb9a74680fe6.cl,512,A,Oclgrind,Oclgrind Simulator,256,13312,6.655744
# 2fe3a72f1e60cb450d821ec61704bb9a74680fe6.cl,512,A,Oclgrind,Oclgrind Simulator,256,13312,5.981952
# 2fe3a72f1e60cb450d821ec61704bb9a74680fe6.cl,512,A,Oclgrind,Oclgrind Simulator,256,13312,6.266112
# 2fe3a72f1e60cb450d821ec61704bb9a74680fe6.cl,512,A,Oclgrind,Oclgrind Simulator,256,13312,6.199552
# 2fe3a72f1e60cb450d821ec61704bb9a74680fe6.cl,512,A,Oclgrind,Oclgrind Simulator,256,13312,6.007296
# 2fe3a72f1e60cb450d821ec61704bb9a74680fe6.cl,512,A,Oclgrind,Oclgrind Simulator,256,13312,6.117120
#
# /home/cec/src/project_b/data/difftest/verified/3de6c77341cfe05fe061ccbded043992094a170e.cl
# 3de6c77341cfe05fe061ccbded043992094a170e.cl,2048,A,Oclgrind,Oclgrind Simulator,256,49152,10.351872
# 3de6c77341cfe05fe061ccbded043992094a170e.cl,2048,A,Oclgrind,Oclgrind Simulator,256,49152,10.077184
# 3de6c77341cfe05fe061ccbded043992094a170e.cl,2048,A,Oclgrind,Oclgrind Simulator,256,49152,9.689088
# 3de6c77341cfe05fe061ccbded043992094a170e.cl,2048,A,Oclgrind,Oclgrind Simulator,256,49152,5.158144
# 3de6c77341cfe05fe061ccbded043992094a170e.cl,2048,A,Oclgrind,Oclgrind Simulator,256,49152,7.483136
# 3de6c77341cfe05fe061ccbded043992094a170e.cl,2048,A,Oclgrind,Oclgrind Simulator,256,49152,6.368256
# 3de6c77341cfe05fe061ccbded043992094a170e.cl,2048,A,Oclgrind,Oclgrind Simulator,256,49152,3.948800
# 3de6c77341cfe05fe061ccbded043992094a170e.cl,2048,A,Oclgrind,Oclgrind Simulator,256,49152,3.476224
# 3de6c77341cfe05fe061ccbded043992094a170e.cl,2048,A,Oclgrind,Oclgrind Simulator,256,49152,3.474688
# 3de6c77341cfe05fe061ccbded043992094a170e.cl,2048,A,Oclgrind,Oclgrind Simulator,256,49152,3.282944
#
# /home/cec/src/project_b/data/difftest/verified/3e42e3b385260a4dd4e74c522bf777313d394487.cl
# 3e42e3b385260a4dd4e74c522bf777313d394487.cl,1024,A,Oclgrind,Oclgrind Simulator,256,4096,6.781184
# 3e42e3b385260a4dd4e74c522bf777313d394487.cl,1024,A,Oclgrind,Oclgrind Simulator,256,4096,6.010112
# 3e42e3b385260a4dd4e74c522bf777313d394487.cl,1024,A,Oclgrind,Oclgrind Simulator,256,4096,3.366144
# 3e42e3b385260a4dd4e74c522bf777313d394487.cl,1024,A,Oclgrind,Oclgrind Simulator,256,4096,4.455936
# 3e42e3b385260a4dd4e74c522bf777313d394487.cl,1024,A,Oclgrind,Oclgrind Simulator,256,4096,4.318720
# 3e42e3b385260a4dd4e74c522bf777313d394487.cl,1024,A,Oclgrind,Oclgrind Simulator,256,4096,3.292160
# 3e42e3b385260a4dd4e74c522bf777313d394487.cl,1024,A,Oclgrind,Oclgrind Simulator,256,4096,5.227008
# 3e42e3b385260a4dd4e74c522bf777313d394487.cl,1024,A,Oclgrind,Oclgrind Simulator,256,4096,2.926080
# 3e42e3b385260a4dd4e74c522bf777313d394487.cl,1024,A,Oclgrind,Oclgrind Simulator,256,4096,2.933248
# 3e42e3b385260a4dd4e74c522bf777313d394487.cl,1024,A,Oclgrind,Oclgrind Simulator,256,4096,2.746112
#
# /home/cec/src/project_b/data/difftest/verified/422c8160a26b3c757c13021c74b195547e40456c.cl
# 422c8160a26b3c757c13021c74b195547e40456c.cl,256,A,Oclgrind,Oclgrind Simulator,256,1536,2.964992
# 422c8160a26b3c757c13021c74b195547e40456c.cl,256,A,Oclgrind,Oclgrind Simulator,256,1536,3.656960
# 422c8160a26b3c757c13021c74b195547e40456c.cl,256,A,Oclgrind,Oclgrind Simulator,256,1536,3.051008
# 422c8160a26b3c757c13021c74b195547e40456c.cl,256,A,Oclgrind,Oclgrind Simulator,256,1536,2.819072
# 422c8160a26b3c757c13021c74b195547e40456c.cl,256,A,Oclgrind,Oclgrind Simulator,256,1536,2.994944
# 422c8160a26b3c757c13021c74b195547e40456c.cl,256,A,Oclgrind,Oclgrind Simulator,256,1536,2.795008
# 422c8160a26b3c757c13021c74b195547e40456c.cl,256,A,Oclgrind,Oclgrind Simulator,256,1536,3.273984
# 422c8160a26b3c757c13021c74b195547e40456c.cl,256,A,Oclgrind,Oclgrind Simulator,256,1536,2.785024
# 422c8160a26b3c757c13021c74b195547e40456c.cl,256,A,Oclgrind,Oclgrind Simulator,256,1536,2.711040
# 422c8160a26b3c757c13021c74b195547e40456c.cl,256,A,Oclgrind,Oclgrind Simulator,256,1536,2.908160
#
# /home/cec/src/project_b/data/difftest/verified/56e4ac3401d595b6f177d09bbc907a95f00a5484.cl
# 56e4ac3401d595b6f177d09bbc907a95f00a5484.cl,4096,A,Oclgrind,Oclgrind Simulator,256,24576,24.247040
# 56e4ac3401d595b6f177d09bbc907a95f00a5484.cl,4096,A,Oclgrind,Oclgrind Simulator,256,24576,6.402048
# 56e4ac3401d595b6f177d09bbc907a95f00a5484.cl,4096,A,Oclgrind,Oclgrind Simulator,256,24576,6.807808
# 56e4ac3401d595b6f177d09bbc907a95f00a5484.cl,4096,A,Oclgrind,Oclgrind Simulator,256,24576,6.073088
# 56e4ac3401d595b6f177d09bbc907a95f00a5484.cl,4096,A,Oclgrind,Oclgrind Simulator,256,24576,6.734848
# 56e4ac3401d595b6f177d09bbc907a95f00a5484.cl,4096,A,Oclgrind,Oclgrind Simulator,256,24576,6.553088
# 56e4ac3401d595b6f177d09bbc907a95f00a5484.cl,4096,A,Oclgrind,Oclgrind Simulator,256,24576,6.435840
# 56e4ac3401d595b6f177d09bbc907a95f00a5484.cl,4096,A,Oclgrind,Oclgrind Simulator,256,24576,5.946112
# 56e4ac3401d595b6f177d09bbc907a95f00a5484.cl,4096,A,Oclgrind,Oclgrind Simulator,256,24576,5.673728
# 56e4ac3401d595b6f177d09bbc907a95f00a5484.cl,4096,A,Oclgrind,Oclgrind Simulator,256,24576,5.651968
#
# /home/cec/src/project_b/data/difftest/verified/5a3188ee0d18f6f2bf890d377de62a82dd1316e2.cl
# 5a3188ee0d18f6f2bf890d377de62a82dd1316e2.cl,8192,A,Oclgrind,Oclgrind Simulator,256,49152,40.501248
# 5a3188ee0d18f6f2bf890d377de62a82dd1316e2.cl,8192,A,Oclgrind,Oclgrind Simulator,256,49152,11.925760
# 5a3188ee0d18f6f2bf890d377de62a82dd1316e2.cl,8192,A,Oclgrind,Oclgrind Simulator,256,49152,11.747840
# 5a3188ee0d18f6f2bf890d377de62a82dd1316e2.cl,8192,A,Oclgrind,Oclgrind Simulator,256,49152,11.910912
# 5a3188ee0d18f6f2bf890d377de62a82dd1316e2.cl,8192,A,Oclgrind,Oclgrind Simulator,256,49152,11.551744
# 5a3188ee0d18f6f2bf890d377de62a82dd1316e2.cl,8192,A,Oclgrind,Oclgrind Simulator,256,49152,11.059200
# 5a3188ee0d18f6f2bf890d377de62a82dd1316e2.cl,8192,A,Oclgrind,Oclgrind Simulator,256,49152,10.130688
# 5a3188ee0d18f6f2bf890d377de62a82dd1316e2.cl,8192,A,Oclgrind,Oclgrind Simulator,256,49152,9.560832
# 5a3188ee0d18f6f2bf890d377de62a82dd1316e2.cl,8192,A,Oclgrind,Oclgrind Simulator,256,49152,9.052160
# 5a3188ee0d18f6f2bf890d377de62a82dd1316e2.cl,8192,A,Oclgrind,Oclgrind Simulator,256,49152,9.023232
#
# /home/cec/src/project_b/data/difftest/verified/78663bf3a85a4c870485e7049a19e85f1b8ca9e8.cl
# 78663bf3a85a4c870485e7049a19e85f1b8ca9e8.cl,32,A,Oclgrind,Oclgrind Simulator,32,768,3.041280
# 78663bf3a85a4c870485e7049a19e85f1b8ca9e8.cl,32,A,Oclgrind,Oclgrind Simulator,32,768,2.379008
# 78663bf3a85a4c870485e7049a19e85f1b8ca9e8.cl,32,A,Oclgrind,Oclgrind Simulator,32,768,2.066944
# 78663bf3a85a4c870485e7049a19e85f1b8ca9e8.cl,32,A,Oclgrind,Oclgrind Simulator,32,768,2.079744
# 78663bf3a85a4c870485e7049a19e85f1b8ca9e8.cl,32,A,Oclgrind,Oclgrind Simulator,32,768,2.123776
# 78663bf3a85a4c870485e7049a19e85f1b8ca9e8.cl,32,A,Oclgrind,Oclgrind Simulator,32,768,1.889792
# 78663bf3a85a4c870485e7049a19e85f1b8ca9e8.cl,32,A,Oclgrind,Oclgrind Simulator,32,768,1.853952
# 78663bf3a85a4c870485e7049a19e85f1b8ca9e8.cl,32,A,Oclgrind,Oclgrind Simulator,32,768,1.845760
# 78663bf3a85a4c870485e7049a19e85f1b8ca9e8.cl,32,A,Oclgrind,Oclgrind Simulator,32,768,1.780224
# 78663bf3a85a4c870485e7049a19e85f1b8ca9e8.cl,32,A,Oclgrind,Oclgrind Simulator,32,768,1.844224
#
# /home/cec/src/project_b/data/difftest/verified/8738e95338f5b843f92a72b0520f97cca46b1ed9.cl
# 8738e95338f5b843f92a72b0520f97cca46b1ed9.cl,1024,A,Oclgrind,Oclgrind Simulator,256,6144,5.939968
# 8738e95338f5b843f92a72b0520f97cca46b1ed9.cl,1024,A,Oclgrind,Oclgrind Simulator,256,6144,6.072064
# 8738e95338f5b843f92a72b0520f97cca46b1ed9.cl,1024,A,Oclgrind,Oclgrind Simulator,256,6144,5.321728
# 8738e95338f5b843f92a72b0520f97cca46b1ed9.cl,1024,A,Oclgrind,Oclgrind Simulator,256,6144,3.086080
# 8738e95338f5b843f92a72b0520f97cca46b1ed9.cl,1024,A,Oclgrind,Oclgrind Simulator,256,6144,3.106048
# 8738e95338f5b843f92a72b0520f97cca46b1ed9.cl,1024,A,Oclgrind,Oclgrind Simulator,256,6144,2.948096
# 8738e95338f5b843f92a72b0520f97cca46b1ed9.cl,1024,A,Oclgrind,Oclgrind Simulator,256,6144,3.046144
# 8738e95338f5b843f92a72b0520f97cca46b1ed9.cl,1024,A,Oclgrind,Oclgrind Simulator,256,6144,3.132928
# 8738e95338f5b843f92a72b0520f97cca46b1ed9.cl,1024,A,Oclgrind,Oclgrind Simulator,256,6144,3.014144
# 8738e95338f5b843f92a72b0520f97cca46b1ed9.cl,1024,A,Oclgrind,Oclgrind Simulator,256,6144,2.923008
#
# /home/cec/src/project_b/data/difftest/verified/8a5af2af494b578f66f3053d7db22dad097e5ebd.cl
# 8a5af2af494b578f66f3053d7db22dad097e5ebd.cl,8192,A,Oclgrind,Oclgrind Simulator,256,196608,203.036928
# 8a5af2af494b578f66f3053d7db22dad097e5ebd.cl,8192,A,Oclgrind,Oclgrind Simulator,256,196608,112.007168
# 8a5af2af494b578f66f3053d7db22dad097e5ebd.cl,8192,A,Oclgrind,Oclgrind Simulator,256,196608,109.889792
# 8a5af2af494b578f66f3053d7db22dad097e5ebd.cl,8192,A,Oclgrind,Oclgrind Simulator,256,196608,107.417856
# 8a5af2af494b578f66f3053d7db22dad097e5ebd.cl,8192,A,Oclgrind,Oclgrind Simulator,256,196608,117.840896
# 8a5af2af494b578f66f3053d7db22dad097e5ebd.cl,8192,A,Oclgrind,Oclgrind Simulator,256,196608,99.916288
# 8a5af2af494b578f66f3053d7db22dad097e5ebd.cl,8192,A,Oclgrind,Oclgrind Simulator,256,196608,95.835136
# 8a5af2af494b578f66f3053d7db22dad097e5ebd.cl,8192,A,Oclgrind,Oclgrind Simulator,256,196608,94.819072
# 8a5af2af494b578f66f3053d7db22dad097e5ebd.cl,8192,A,Oclgrind,Oclgrind Simulator,256,196608,110.034944
# 8a5af2af494b578f66f3053d7db22dad097e5ebd.cl,8192,A,Oclgrind,Oclgrind Simulator,256,196608,117.805312
#
# /home/cec/src/project_b/data/difftest/verified/9af2073dfc983267f7895897c94124c31af40903.cl
# 9af2073dfc983267f7895897c94124c31af40903.cl,256,A,Oclgrind,Oclgrind Simulator,256,6144,2.443776
# 9af2073dfc983267f7895897c94124c31af40903.cl,256,A,Oclgrind,Oclgrind Simulator,256,6144,3.078912
# 9af2073dfc983267f7895897c94124c31af40903.cl,256,A,Oclgrind,Oclgrind Simulator,256,6144,3.568128
# 9af2073dfc983267f7895897c94124c31af40903.cl,256,A,Oclgrind,Oclgrind Simulator,256,6144,3.250176
# 9af2073dfc983267f7895897c94124c31af40903.cl,256,A,Oclgrind,Oclgrind Simulator,256,6144,3.063040
# 9af2073dfc983267f7895897c94124c31af40903.cl,256,A,Oclgrind,Oclgrind Simulator,256,6144,2.860032
# 9af2073dfc983267f7895897c94124c31af40903.cl,256,A,Oclgrind,Oclgrind Simulator,256,6144,2.055936
# 9af2073dfc983267f7895897c94124c31af40903.cl,256,A,Oclgrind,Oclgrind Simulator,256,6144,2.849024
# 9af2073dfc983267f7895897c94124c31af40903.cl,256,A,Oclgrind,Oclgrind Simulator,256,6144,2.102784
# 9af2073dfc983267f7895897c94124c31af40903.cl,256,A,Oclgrind,Oclgrind Simulator,256,6144,2.054144
#
# /home/cec/src/project_b/data/difftest/verified/9d29169a3ea3d5bb80f7234f6c2cd97484b7b8c5.cl
# 9d29169a3ea3d5bb80f7234f6c2cd97484b7b8c5.cl,32,A,Oclgrind,Oclgrind Simulator,32,1024,1.442816
# 9d29169a3ea3d5bb80f7234f6c2cd97484b7b8c5.cl,32,A,Oclgrind,Oclgrind Simulator,32,1024,1.245952
# 9d29169a3ea3d5bb80f7234f6c2cd97484b7b8c5.cl,32,A,Oclgrind,Oclgrind Simulator,32,1024,0.933120
# 9d29169a3ea3d5bb80f7234f6c2cd97484b7b8c5.cl,32,A,Oclgrind,Oclgrind Simulator,32,1024,0.855040
# 9d29169a3ea3d5bb80f7234f6c2cd97484b7b8c5.cl,32,A,Oclgrind,Oclgrind Simulator,32,1024,0.781056
# 9d29169a3ea3d5bb80f7234f6c2cd97484b7b8c5.cl,32,A,Oclgrind,Oclgrind Simulator,32,1024,0.774144
# 9d29169a3ea3d5bb80f7234f6c2cd97484b7b8c5.cl,32,A,Oclgrind,Oclgrind Simulator,32,1024,0.750080
# 9d29169a3ea3d5bb80f7234f6c2cd97484b7b8c5.cl,32,A,Oclgrind,Oclgrind Simulator,32,1024,0.624128
# 9d29169a3ea3d5bb80f7234f6c2cd97484b7b8c5.cl,32,A,Oclgrind,Oclgrind Simulator,32,1024,0.706816
# 9d29169a3ea3d5bb80f7234f6c2cd97484b7b8c5.cl,32,A,Oclgrind,Oclgrind Simulator,32,1024,0.632832
#
# /home/cec/src/project_b/data/difftest/verified/a9258b916a92fa2c189c94276d2ddd4341f16038.cl
# a9258b916a92fa2c189c94276d2ddd4341f16038.cl,512,A,Oclgrind,Oclgrind Simulator,256,12288,4.640000
# a9258b916a92fa2c189c94276d2ddd4341f16038.cl,512,A,Oclgrind,Oclgrind Simulator,256,12288,3.463936
# a9258b916a92fa2c189c94276d2ddd4341f16038.cl,512,A,Oclgrind,Oclgrind Simulator,256,12288,3.409152
# a9258b916a92fa2c189c94276d2ddd4341f16038.cl,512,A,Oclgrind,Oclgrind Simulator,256,12288,6.418176
# a9258b916a92fa2c189c94276d2ddd4341f16038.cl,512,A,Oclgrind,Oclgrind Simulator,256,12288,1.903104
# a9258b916a92fa2c189c94276d2ddd4341f16038.cl,512,A,Oclgrind,Oclgrind Simulator,256,12288,3.009792
# a9258b916a92fa2c189c94276d2ddd4341f16038.cl,512,A,Oclgrind,Oclgrind Simulator,256,12288,2.657024
# a9258b916a92fa2c189c94276d2ddd4341f16038.cl,512,A,Oclgrind,Oclgrind Simulator,256,12288,2.679808
# a9258b916a92fa2c189c94276d2ddd4341f16038.cl,512,A,Oclgrind,Oclgrind Simulator,256,12288,1.837056
# a9258b916a92fa2c189c94276d2ddd4341f16038.cl,512,A,Oclgrind,Oclgrind Simulator,256,12288,2.306048
#
# /home/cec/src/project_b/data/difftest/verified/b3b9b0bc3d558a92c7077cbe39e0e7b4e4f9a8f5.cl
# b3b9b0bc3d558a92c7077cbe39e0e7b4e4f9a8f5.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,34.766848
# b3b9b0bc3d558a92c7077cbe39e0e7b4e4f9a8f5.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,11.495168
# b3b9b0bc3d558a92c7077cbe39e0e7b4e4f9a8f5.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,9.399040
# b3b9b0bc3d558a92c7077cbe39e0e7b4e4f9a8f5.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,9.373696
# b3b9b0bc3d558a92c7077cbe39e0e7b4e4f9a8f5.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,9.232128
# b3b9b0bc3d558a92c7077cbe39e0e7b4e4f9a8f5.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,10.793216
# b3b9b0bc3d558a92c7077cbe39e0e7b4e4f9a8f5.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,9.199104
# b3b9b0bc3d558a92c7077cbe39e0e7b4e4f9a8f5.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,8.977152
# b3b9b0bc3d558a92c7077cbe39e0e7b4e4f9a8f5.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,9.105920
# b3b9b0bc3d558a92c7077cbe39e0e7b4e4f9a8f5.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,9.164800
#
# /home/cec/src/project_b/data/difftest/verified/c3931a439a77f4130dcdd8874840b9b126348a42.cl
# c3931a439a77f4130dcdd8874840b9b126348a42.cl,64,A,Oclgrind,Oclgrind Simulator,64,640,1.875968
# c3931a439a77f4130dcdd8874840b9b126348a42.cl,64,A,Oclgrind,Oclgrind Simulator,64,640,0.978176
# c3931a439a77f4130dcdd8874840b9b126348a42.cl,64,A,Oclgrind,Oclgrind Simulator,64,640,1.262848
# c3931a439a77f4130dcdd8874840b9b126348a42.cl,64,A,Oclgrind,Oclgrind Simulator,64,640,1.022976
# c3931a439a77f4130dcdd8874840b9b126348a42.cl,64,A,Oclgrind,Oclgrind Simulator,64,640,1.300224
# c3931a439a77f4130dcdd8874840b9b126348a42.cl,64,A,Oclgrind,Oclgrind Simulator,64,640,1.251072
# c3931a439a77f4130dcdd8874840b9b126348a42.cl,64,A,Oclgrind,Oclgrind Simulator,64,640,1.227008
# c3931a439a77f4130dcdd8874840b9b126348a42.cl,64,A,Oclgrind,Oclgrind Simulator,64,640,0.901888
# c3931a439a77f4130dcdd8874840b9b126348a42.cl,64,A,Oclgrind,Oclgrind Simulator,64,640,0.897024
# c3931a439a77f4130dcdd8874840b9b126348a42.cl,64,A,Oclgrind,Oclgrind Simulator,64,640,1.001984
#
# /home/cec/src/project_b/data/difftest/verified/c39bdd07980a3ea026aaf091a5108a4d787d5cb4.cl
# c39bdd07980a3ea026aaf091a5108a4d787d5cb4.cl,2048,A,Oclgrind,Oclgrind Simulator,256,65536,11.662080
# c39bdd07980a3ea026aaf091a5108a4d787d5cb4.cl,2048,A,Oclgrind,Oclgrind Simulator,256,65536,7.033856
# c39bdd07980a3ea026aaf091a5108a4d787d5cb4.cl,2048,A,Oclgrind,Oclgrind Simulator,256,65536,6.174976
# c39bdd07980a3ea026aaf091a5108a4d787d5cb4.cl,2048,A,Oclgrind,Oclgrind Simulator,256,65536,5.236992
# c39bdd07980a3ea026aaf091a5108a4d787d5cb4.cl,2048,A,Oclgrind,Oclgrind Simulator,256,65536,5.122048
# c39bdd07980a3ea026aaf091a5108a4d787d5cb4.cl,2048,A,Oclgrind,Oclgrind Simulator,256,65536,4.681216
# c39bdd07980a3ea026aaf091a5108a4d787d5cb4.cl,2048,A,Oclgrind,Oclgrind Simulator,256,65536,2.965248
# c39bdd07980a3ea026aaf091a5108a4d787d5cb4.cl,2048,A,Oclgrind,Oclgrind Simulator,256,65536,2.941184
# c39bdd07980a3ea026aaf091a5108a4d787d5cb4.cl,2048,A,Oclgrind,Oclgrind Simulator,256,65536,3.350784
# c39bdd07980a3ea026aaf091a5108a4d787d5cb4.cl,2048,A,Oclgrind,Oclgrind Simulator,256,65536,4.343296
#
# /home/cec/src/project_b/data/difftest/verified/c3a9bfc99018dbac0fb18ec041661d46d423dc00.cl
# c3a9bfc99018dbac0fb18ec041661d46d423dc00.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,30.616064
# c3a9bfc99018dbac0fb18ec041661d46d423dc00.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,10.839040
# c3a9bfc99018dbac0fb18ec041661d46d423dc00.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,9.455872
# c3a9bfc99018dbac0fb18ec041661d46d423dc00.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,11.582208
# c3a9bfc99018dbac0fb18ec041661d46d423dc00.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,9.202176
# c3a9bfc99018dbac0fb18ec041661d46d423dc00.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,9.219072
# c3a9bfc99018dbac0fb18ec041661d46d423dc00.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,9.138176
# c3a9bfc99018dbac0fb18ec041661d46d423dc00.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,8.864000
# c3a9bfc99018dbac0fb18ec041661d46d423dc00.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,9.183488
# c3a9bfc99018dbac0fb18ec041661d46d423dc00.cl,8192,A,Oclgrind,Oclgrind Simulator,256,98304,8.155904
#
# /home/cec/src/project_b/data/difftest/verified/c7a2276115e39e10e2f557c70c3e4f6274064e19.cl
# c7a2276115e39e10e2f557c70c3e4f6274064e19.cl,256,A,Oclgrind,Oclgrind Simulator,256,6656,2.309888
# c7a2276115e39e10e2f557c70c3e4f6274064e19.cl,256,A,Oclgrind,Oclgrind Simulator,256,6656,2.799104
# c7a2276115e39e10e2f557c70c3e4f6274064e19.cl,256,A,Oclgrind,Oclgrind Simulator,256,6656,2.825216
# c7a2276115e39e10e2f557c70c3e4f6274064e19.cl,256,A,Oclgrind,Oclgrind Simulator,256,6656,2.987008
# c7a2276115e39e10e2f557c70c3e4f6274064e19.cl,256,A,Oclgrind,Oclgrind Simulator,256,6656,2.174208
# c7a2276115e39e10e2f557c70c3e4f6274064e19.cl,256,A,Oclgrind,Oclgrind Simulator,256,6656,2.530048
# c7a2276115e39e10e2f557c70c3e4f6274064e19.cl,256,A,Oclgrind,Oclgrind Simulator,256,6656,2.524928
# c7a2276115e39e10e2f557c70c3e4f6274064e19.cl,256,A,Oclgrind,Oclgrind Simulator,256,6656,1.991936
# c7a2276115e39e10e2f557c70c3e4f6274064e19.cl,256,A,Oclgrind,Oclgrind Simulator,256,6656,2.257920
# c7a2276115e39e10e2f557c70c3e4f6274064e19.cl,256,A,Oclgrind,Oclgrind Simulator,256,6656,2.337792
#
# /home/cec/src/project_b/data/difftest/verified/d554f7034b79009041967428ec18bcfc633f149f.cl
# d554f7034b79009041967428ec18bcfc633f149f.cl,16,A,Oclgrind,Oclgrind Simulator,16,384,0.698112
# d554f7034b79009041967428ec18bcfc633f149f.cl,16,A,Oclgrind,Oclgrind Simulator,16,384,0.930816
# d554f7034b79009041967428ec18bcfc633f149f.cl,16,A,Oclgrind,Oclgrind Simulator,16,384,0.478720
# d554f7034b79009041967428ec18bcfc633f149f.cl,16,A,Oclgrind,Oclgrind Simulator,16,384,0.862720
# d554f7034b79009041967428ec18bcfc633f149f.cl,16,A,Oclgrind,Oclgrind Simulator,16,384,0.439552
# d554f7034b79009041967428ec18bcfc633f149f.cl,16,A,Oclgrind,Oclgrind Simulator,16,384,0.926976
# d554f7034b79009041967428ec18bcfc633f149f.cl,16,A,Oclgrind,Oclgrind Simulator,16,384,0.444160
# d554f7034b79009041967428ec18bcfc633f149f.cl,16,A,Oclgrind,Oclgrind Simulator,16,384,0.866048
# d554f7034b79009041967428ec18bcfc633f149f.cl,16,A,Oclgrind,Oclgrind Simulator,16,384,0.460288
# d554f7034b79009041967428ec18bcfc633f149f.cl,16,A,Oclgrind,Oclgrind Simulator,16,384,0.843008
#
# /home/cec/src/project_b/data/difftest/verified/d745ff1ac43d192305833d0eee51df7cb8471603.cl
# d745ff1ac43d192305833d0eee51df7cb8471603.cl,32,A,Oclgrind,Oclgrind Simulator,32,512,22.674944
# d745ff1ac43d192305833d0eee51df7cb8471603.cl,32,A,Oclgrind,Oclgrind Simulator,32,512,1.523712
# d745ff1ac43d192305833d0eee51df7cb8471603.cl,32,A,Oclgrind,Oclgrind Simulator,32,512,1.326080
# d745ff1ac43d192305833d0eee51df7cb8471603.cl,32,A,Oclgrind,Oclgrind Simulator,32,512,1.172992
# d745ff1ac43d192305833d0eee51df7cb8471603.cl,32,A,Oclgrind,Oclgrind Simulator,32,512,1.662976
# d745ff1ac43d192305833d0eee51df7cb8471603.cl,32,A,Oclgrind,Oclgrind Simulator,32,512,2.327040
# d745ff1ac43d192305833d0eee51df7cb8471603.cl,32,A,Oclgrind,Oclgrind Simulator,32,512,1.729024
# d745ff1ac43d192305833d0eee51df7cb8471603.cl,32,A,Oclgrind,Oclgrind Simulator,32,512,1.584640
# d745ff1ac43d192305833d0eee51df7cb8471603.cl,32,A,Oclgrind,Oclgrind Simulator,32,512,1.618944
# d745ff1ac43d192305833d0eee51df7cb8471603.cl,32,A,Oclgrind,Oclgrind Simulator,32,512,1.668864
#
# /home/cec/src/project_b/data/difftest/verified/ea4b51a499933c2586b1fff6109cb8061e989680.cl
# ea4b51a499933c2586b1fff6109cb8061e989680.cl,1024,A,Oclgrind,Oclgrind Simulator,256,32768,6.300160
# ea4b51a499933c2586b1fff6109cb8061e989680.cl,1024,A,Oclgrind,Oclgrind Simulator,256,32768,6.699008
# ea4b51a499933c2586b1fff6109cb8061e989680.cl,1024,A,Oclgrind,Oclgrind Simulator,256,32768,4.482816
# ea4b51a499933c2586b1fff6109cb8061e989680.cl,1024,A,Oclgrind,Oclgrind Simulator,256,32768,4.807936
# ea4b51a499933c2586b1fff6109cb8061e989680.cl,1024,A,Oclgrind,Oclgrind Simulator,256,32768,5.096960
# ea4b51a499933c2586b1fff6109cb8061e989680.cl,1024,A,Oclgrind,Oclgrind Simulator,256,32768,3.088896
# ea4b51a499933c2586b1fff6109cb8061e989680.cl,1024,A,Oclgrind,Oclgrind Simulator,256,32768,3.067648
# ea4b51a499933c2586b1fff6109cb8061e989680.cl,1024,A,Oclgrind,Oclgrind Simulator,256,32768,3.042048
# ea4b51a499933c2586b1fff6109cb8061e989680.cl,1024,A,Oclgrind,Oclgrind Simulator,256,32768,2.886144
# ea4b51a499933c2586b1fff6109cb8061e989680.cl,1024,A,Oclgrind,Oclgrind Simulator,256,32768,2.774016
#
# /home/cec/src/project_b/data/difftest/verified/ee8a2e6632acc975c3f31b0779cded670bcc0c48.cl
# ee8a2e6632acc975c3f31b0779cded670bcc0c48.cl,512,A,Oclgrind,Oclgrind Simulator,256,11264,5.331200
# ee8a2e6632acc975c3f31b0779cded670bcc0c48.cl,512,A,Oclgrind,Oclgrind Simulator,256,11264,3.579904
# ee8a2e6632acc975c3f31b0779cded670bcc0c48.cl,512,A,Oclgrind,Oclgrind Simulator,256,11264,3.675648
# ee8a2e6632acc975c3f31b0779cded670bcc0c48.cl,512,A,Oclgrind,Oclgrind Simulator,256,11264,3.385088
# ee8a2e6632acc975c3f31b0779cded670bcc0c48.cl,512,A,Oclgrind,Oclgrind Simulator,256,11264,3.646976
# ee8a2e6632acc975c3f31b0779cded670bcc0c48.cl,512,A,Oclgrind,Oclgrind Simulator,256,11264,3.132928
# ee8a2e6632acc975c3f31b0779cded670bcc0c48.cl,512,A,Oclgrind,Oclgrind Simulator,256,11264,3.055104
# ee8a2e6632acc975c3f31b0779cded670bcc0c48.cl,512,A,Oclgrind,Oclgrind Simulator,256,11264,2.889984
# ee8a2e6632acc975c3f31b0779cded670bcc0c48.cl,512,A,Oclgrind,Oclgrind Simulator,256,11264,2.860032
# ee8a2e6632acc975c3f31b0779cded670bcc0c48.cl,512,A,Oclgrind,Oclgrind Simulator,256,11264,3.083008
#
# /home/cec/src/project_b/data/difftest/verified/fb4547b1c0e4b251a6d3fb9d30d90a9b95fe2555.cl
# fb4547b1c0e4b251a6d3fb9d30d90a9b95fe2555.cl,16,A,Oclgrind,Oclgrind Simulator,16,384,0.732928
# fb4547b1c0e4b251a6d3fb9d30d90a9b95fe2555.cl,16,A,Oclgrind,Oclgrind Simulator,16,384,0.514048
# fb4547b1c0e4b251a6d3fb9d30d90a9b95fe2555.cl,16,A,Oclgrind,Oclgrind Simulator,16,384,0.396032
# fb4547b1c0e4b251a6d3fb9d30d90a9b95fe2555.cl,16,A,Oclgrind,Oclgrind Simulator,16,384,0.782080
# fb4547b1c0e4b251a6d3fb9d30d90a9b95fe2555.cl,16,A,Oclgrind,Oclgrind Simulator,16,384,0.353792
# fb4547b1c0e4b251a6d3fb9d30d90a9b95fe2555.cl,16,A,Oclgrind,Oclgrind Simulator,16,384,0.702976
# fb4547b1c0e4b251a6d3fb9d30d90a9b95fe2555.cl,16,A,Oclgrind,Oclgrind Simulator,16,384,0.384000
# fb4547b1c0e4b251a6d3fb9d30d90a9b95fe2555.cl,16,A,Oclgrind,Oclgrind Simulator,16,384,0.683008
# fb4547b1c0e4b251a6d3fb9d30d90a9b95fe2555.cl,16,A,Oclgrind,Oclgrind Simulator,16,384,0.343040
# fb4547b1c0e4b251a6d3fb9d30d90a9b95fe2555.cl,16,A,Oclgrind,Oclgrind Simulator,16,384,0.690944
#
# /home/cec/src/project_b/data/difftest/verified/fd3f74620c0042b5187e0b4bdc62ef02147f9dbe.cl
# fd3f74620c0042b5187e0b4bdc62ef02147f9dbe.cl,256,A,Oclgrind,Oclgrind Simulator,256,5120,2.256896
# fd3f74620c0042b5187e0b4bdc62ef02147f9dbe.cl,256,A,Oclgrind,Oclgrind Simulator,256,5120,2.337024
# fd3f74620c0042b5187e0b4bdc62ef02147f9dbe.cl,256,A,Oclgrind,Oclgrind Simulator,256,5120,3.272960
# fd3f74620c0042b5187e0b4bdc62ef02147f9dbe.cl,256,A,Oclgrind,Oclgrind Simulator,256,5120,3.257088
# fd3f74620c0042b5187e0b4bdc62ef02147f9dbe.cl,256,A,Oclgrind,Oclgrind Simulator,256,5120,3.279104
# fd3f74620c0042b5187e0b4bdc62ef02147f9dbe.cl,256,A,Oclgrind,Oclgrind Simulator,256,5120,3.050240
# fd3f74620c0042b5187e0b4bdc62ef02147f9dbe.cl,256,A,Oclgrind,Oclgrind Simulator,256,5120,3.233024
# fd3f74620c0042b5187e0b4bdc62ef02147f9dbe.cl,256,A,Oclgrind,Oclgrind Simulator,256,5120,1.966848
# fd3f74620c0042b5187e0b4bdc62ef02147f9dbe.cl,256,A,Oclgrind,Oclgrind Simulator,256,5120,1.809152
# fd3f74620c0042b5187e0b4bdc62ef02147f9dbe.cl,256,A,Oclgrind,Oclgrind Simulator,256,5120,1.769216
