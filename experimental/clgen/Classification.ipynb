# %% [markdown]
# # DNN Classification

# %%
# preamble
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import time

from collections import Counter

from labm8.py import fs
from labm8.py import viz

from keras.models import Sequential
from keras.layers import Input, Dropout, Embedding, merge, LSTM, Dense
from keras.models import Model
from keras.layers.normalization import BatchNormalization
from keras.wrappers.scikit_learn import KerasClassifier
from keras.preprocessing.sequence import pad_sequences

from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier

from scipy.stats import percentileofscore
from scipy.stats.mstats import gmean

from IPython.display import SVG
from keras.utils.visualize_util import model_to_dot

import clgen
from clgen import clutil
from clgen.atomizer import CharacterAtomizer, GreedyAtomizer
# Out:
# Using TensorFlow backend.

# %%
seed = 7
np.random.seed(seed)

# %% [markdown]
# Methods for wrangling data:

# %%
def get_2(D):
    """ return np array of shape (len(D), nb_features)"""
    return np.array([
        D["transfer"].values,
        D["wgsize"].values,
    ]).T

def get_4(D):
    """ return np array of shape (len(D), nb_features)"""
    return np.array([
        (D["transfer"].values / (D["comp"].values + D["mem"].values)),  # F1
        (D["coalesced"].values / D["mem"].values),  # F2
        ((D["localmem"].values / D["mem"].values) * D["wgsize"].values),  # F3
        (D["comp"].values / D["mem"].values),  # F4
    ]).T
    
def get_11(D):
    """ return np array of shape (len(D), nb_features)"""
    return np.array([
        D["comp"].values,
        D["rational"].values,
        D["mem"].values,
        D["localmem"].values,
        D["coalesced"].values,
        D["transfer"].values,
        D["wgsize"].values,
        (D["transfer"].values / (D["comp"].values + D["mem"].values)),  # F1
        (D["coalesced"].values / D["mem"].values),  # F2
        ((D["localmem"].values / D["mem"].values) * D["wgsize"].values),  # F3
        (D["comp"].values / D["mem"].values),  # F4
    ]).T

def get_sequences(D, max_seq_len):
    """ return np array of shape (len(D), max_seq_len) """
    for row in D["seq"].values:
        assert(len(row) == max_seq_len)
    data = np.array(D["seq"].values)
    return np.vstack([np.expand_dims(x, axis=0) for x in data])

def get_labels(D):
    """ cpu/gpu to int, return np array of shape (len(D), 1) """
    return np.vstack([np.expand_dims(x, axis=0) for x in D["oracle_enc"]])

def get_y2(D):
    l2 = [x[0] for x in get_labels(D)]
    l1 = [not x for x in l2]
    return np.array(list(zip(l1, l2)), dtype=np.int32)

def get_train_validation_test_splits(D, split=(.6, .2, .2), seed=1):
    """ split dataframe into 3 frames for training, validation, and testing """
    if round(sum(split), 3) != 1.000:  # FIXME
        print(round(sum(split), 3))
    assert(round(sum(split), 3) == 1.000)
    train_split, validation_split, test_split = split
    
    num_synthetic = sum(D["synthetic"].values)
    
    np.random.seed(seed)
    train_msk = np.random.rand(len(D)) < train_split
    
    train = D[train_msk]
    other = D[~train_msk]
    
    test_msk = np.random.rand(len(other)) < split[2] / sum(split[1:])
    test = other[test_msk]
    validation = other[~test_msk]
 
    np.random.seed()  # re-seed RNG
    return train, validation, test

def get_train_validation_test_splits(D, split=(.6, .2, .2), seed=1):
    """ split dataframe into 3 frames for training, validation, and testing.
    synthetics are exclusively for training """
    # TODO: balance benchmark suites in splits
    # TODO: balance labels in splits
    if round(sum(split), 3) != 1.000:  # FIXME
        print(round(sum(split), 3))
    assert(round(sum(split), 3) == 1.0)
    train_split, validation_split, test_split = split
    
    num_synthetic = sum(D["synthetic"].values)
    num_benchmarks = len(D) - num_synthetic
    
    np.random.seed(seed)
    
    if num_benchmarks:
        train_msk = np.logical_or(np.random.rand(len(D)) < train_split, D["synthetic"])
    else:
        train_msk = np.random.rand(len(D)) < train_split
    
    train = D[train_msk]
    other = D[~train_msk]
    
    test_msk = np.random.rand(len(other)) < split[2] / sum(split[1:])
    test = other[test_msk]
    validation = other[~test_msk]

    np.random.seed()  # re-seed RNG
    return train, validation, test

def load_dataframe(platform, source="B", max_seq_len=1000, atomizer=CharacterAtomizer):
    """ load experimental results """
    def escape_suite_name(g):
        """format benchmark suite name for display"""
        c = g.split('-')
        if (c[0] == "amd" or c[0] == "npb" or c[0] == "nvidia" or c[0] == "shoc"):
            return c[0].upper()
        else:
            return c[0].capitalize()
    
    def get_benchmarks(platform):
        B = pd.read_csv(fs.path("classification/{platform}-benchmarks.csv".format(**vars())))
        B["source"] = [escape_suite_name(x) for x in B["benchmark"]]
        B["synthetic"] = [0] * len(B)
        return B

    def get_npb_benchmarks(platform):
        B = get_benchmarks(platform)
        msk = B["source"] == "NPB"
        return B[msk]
    
    def get_synthetics(platform):
        S = pd.read_csv(fs.path("classification/{platform}-clgen.csv".format(**vars())))
        S["source"] = ["CLgen"] * len(S)
        S["synthetic"] = [1] * len(S)
        return S
    
    if source == "B":
        dataframe = get_benchmarks(platform)
    elif source == "S":
        dataframe = get_synthetics(platform)
    elif source == "BS":
        dataframe = pd.concat((get_benchmarks(platform), get_synthetics(platform)))
    elif source == "N":
        dataframe = get_npb_benchmarks(platform)
    elif source == "NS":
        dataframe = pd.concat((get_npb_benchmarks(platform), get_synthetics(platform)))
    else:
        raise Exception

    print("num instances {} ({} synthetic, {} benchmarks)".format(
        len(dataframe),
        sum(dataframe["synthetic"].values),
        len(dataframe) - sum(dataframe["synthetic"].values)))
        
    dataframe["oracle_enc"] = [1 if x == "GPU" else 0 for x in dataframe["oracle"].values]

    # load source code:
    source_dir = fs.path("classification/kernels")
    srcs = []
    for row in dataframe["benchmark"].values:
        inpath = fs.path(source_dir, row + ".cl")
        with open(inpath) as infile:
            src = infile.read()
        if not src.startswith("__kernel void A"):
            print(fs.basename(inpath))
            raise Exception(src)
        srcs.append(src)
        
    print("unique kernels", len(set(srcs)))
    dataframe["src"] = srcs
    dataframe["src_len"] = [len(s) for s in srcs]
    
    # encode and pad sequences:
    atomizer = atomizer.from_text(''.join(dataframe["src"].values))
    
    seqs = [atomizer.atomize(seq) for seq in dataframe["src"].values]
    seq_length = min(max(len(s) for s in seqs), max_seq_len)
    pad_val = atomizer.vocab_size + 1
    dataframe["seq_len"] = [len(s) for s in seqs]
    dataframe["seq"] = list(pad_sequences(seqs, maxlen=seq_length, value=pad_val))
    print("vocab size", atomizer.vocab_size + 1)
    print("pad val", pad_val)
    print("padded seq length", seq_length)
    
    return dataframe, seq_length, atomizer

def get_training_data(dataframe, seed, seq_length, *args, split=(.6, .2, .2), **kwargs):
    train, validation, test = get_train_validation_test_splits(dataframe, seed=seed, split=split)

    x_train_2 = get_2(train)
    x_train_4 = get_4(train)
    x_train_11 = get_11(train)
    x_train_seq = get_sequences(train, seq_length)
    y_train = get_labels(train)
    y2_train = get_y2(train)
    
    x_val_2 = get_2(validation)
    x_val_4 = get_4(validation)
    x_val_11 = get_11(validation)
    x_val_seq = get_sequences(validation, seq_length)
    y_val = get_labels(validation)
    y2_val = get_y2(validation)
    
    x_test_2 = get_2(test)
    x_test_4 = get_4(test)
    x_test_11 = get_11(test)
    x_test_seq = get_sequences(test, seq_length)
    y_test = get_labels(test)
    y2_test = get_y2(test)
    
    return (
        {"dataframe": train, "x_2": x_train_2, "x_4": x_train_4, "x_11": x_train_11, "x_seq": x_train_seq, "y": y_train, "y_2": y2_train},
        {"dataframe": validation, "x_2": x_val_2, "x_4": x_val_4, "x_11": x_val_11, "x_seq": x_val_seq, "y": y_val, "y_2": y2_val},
        {"dataframe": test, "x_2": x_test_2, "x_4": x_test_4, "x_11": x_test_11, "x_seq": x_test_seq, "y": y_test, "y_2": y2_test},
    )

# %% [markdown]
# Load dataset:

# %%
dataframe, seq_length, atomizer = load_dataframe(
    platform="amd",
    source="S",
    max_seq_len=1024, 
    atomizer=GreedyAtomizer
)

x_2 = get_2(dataframe)
x_4 = get_4(dataframe)
x_11 = get_11(dataframe)
x_seq = get_sequences(dataframe, seq_length)
y = get_labels(dataframe)

vocab_size = atomizer.vocab_size + 1  # +1 for pad value
# Out:
# num instances 15919 (15919 synthetic, 0 benchmarks)
# unique kernels 1000
# vocab size 100
# pad val 100
# padded seq length 519

# %% [markdown]
# ## Dataset exploration

# %%
ax = sns.countplot(x="oracle_enc", data=dataframe, hue="source")
plt.title("Number of optimal device mappings")
plt.xticks([0, 1], ["CPU", "GPU"])
plt.xlabel("")
plt.ylabel("#. optimal")

num_oracle_gpu = sum(dataframe["oracle_enc"])
num_oracle_cpu = len(dataframe) - num_oracle_gpu
zero_r = "CPU" if num_oracle_cpu > num_oracle_gpu else "GPU"
acc_zero_r = max(num_oracle_cpu, num_oracle_gpu) / len(dataframe)

print("Accuracy of Zero-R ({zero_r}): {acc_zero_r:.2%}".format(**vars()))

viz.finalise(figsize=(6, 4))
# Out:
# Accuracy of Zero-R (GPU): 56.91%

# %%
plt.subplot(1, 2, 1)
ax = sns.distplot(dataframe["src_len"], kde=None, bins=10)
plt.title("OpenCL kernel lengths")
plt.xlabel("#. characters")
plt.ylabel("#. kernels")

plt.subplot(1, 2, 2)
ax = sns.distplot(dataframe["seq_len"], kde=None, bins=10)
plt.title("Encoded sequence lengths (not padded)")
plt.xlabel("#. characters")
plt.ylabel("#. kernels")

print("min seq len", min(dataframe["seq_len"]))
print("max seq len", max(dataframe["seq_len"]))
print("mean seq len", int(round(np.mean(dataframe["seq_len"]))))
for p in [25, 50, 60, 75, 90]:
    print("{p}% percentile".format(p=p), int(np.percentile(dataframe["seq_len"], p)))
print("padded seq len", seq_length)
print("percentile of padded seq len {:.1f}%".format(
    percentileofscore(dataframe["seq_len"], seq_length, 'mean')))

viz.finalise(figsize=(9, 4))
# Out:
# min seq len 53
# max seq len 24604
# mean seq len 2650
# 25% percentile 290
# 50% percentile 538
# 60% percentile 724
# 75% percentile 1504
# 90% percentile 13449
# padded seq len 1024
# percentile of padded seq len 66.5%

# %%
plt.subplot(1, 2, 1)
ax = sns.distplot(dataframe["wgsize"], kde=None, bins=10)
plt.subplot(1, 2, 2)
ax = sns.distplot(dataframe["transfer"], kde=None, bins=10)
viz.finalise(figsize=(9, 4))

# %% [markdown]
# ## Source + dynamic props classification

# %%
def analyze(predictions, test):
    def enc2key(p):
        return "runtime_gpu" if p else "runtime_cpu"
    
    frame = test["dataframe"]
    oracle = np.array(frame["oracle_enc"], dtype=np.bool)
    incorrect = np.logical_xor(predictions, oracle)
    correct = np.logical_not(incorrect)

    zero_r = Counter(oracle).most_common(1)[0][0]
    zero_r_key = enc2key(zero_r)
    
    speedups = np.array([min(d["runtime_cpu"], d["runtime_gpu"]) / d[enc2key(p)]
                         for p,d in zip(predictions, frame.T.to_dict().values())])
    speedup_avg = speedups.mean()
    speedup_geo = gmean(speedups)
    
    accuracy = sum(correct) / len(test["dataframe"])
    
    confusion_matrix = np.zeros((2, 2), dtype="int32")
    confusion_matrix[0][0] = sum(np.logical_and(np.logical_not(predictions), np.logical_not(oracle)))
    confusion_matrix[0][1] = sum(np.logical_and(predictions, np.logical_not(oracle)))
    confusion_matrix[1][0] = sum(np.logical_and(np.logical_not(predictions), oracle))
    confusion_matrix[1][1] = sum(np.logical_and(predictions, oracle))
    
    assert(confusion_matrix.sum() == len(test["dataframe"]))
    assert(confusion_matrix[0][1] + confusion_matrix[1][1] == sum(predictions))
    assert(confusion_matrix[0][1] + confusion_matrix[1][0] == sum(incorrect))
    assert(confusion_matrix[0][0] + confusion_matrix[1][1] == sum(correct))
    print(confusion_matrix)
    
    return {
        "accuracy": accuracy,
        "confusion_matrix": confusion_matrix,
        # "speedups": speedups,
        "speedup_min": min(speedups),
        "speedup_max": max(speedups),
        "speedup_avg": speedup_avg,
        "speedup_geo": speedup_geo,
    }

# %%
def evaluate(dataframe, seq_length, create_model, train_fn, test_fn, seed=1, save_fn=None, split=(.6, .2, .2), n=5, quiet=False):
    """
    Arguments:
        create_model (function): Function with definition:
                create_model(seed, i) -> model
        train_fn (function): Function with definition:
                train_fn(seed, model, train_data, validation_data) -> {}
        save_fn (function): Function with definition:
                save_fn(seed, i, model) -> None
        test_fn (function): Function with definition:
                test_fn(seed, model, test_data) -> {}
        n (int): Number of repetitions
    
    Returns:
        list: list of length n, each element a pair of train_fn(), test_fn() return values
    """
    train_results = []
    test_results = []
    for i in range(n):
        j = i + 1
        # get training_data
        train, validation, test = get_training_data(dataframe, seed + i, seq_length, i=i, n=n, split=split)
        # create model
        model = create_model(i=i, seed=seed + i)
        # train model
        start = time.time()
        train_result = train_fn(model=model, train=train, validation=validation, i=i, seed=seed + i) or {}
        elapsed = time.time() - start
        train_result["time"] = elapsed
        m = len(train["y"])
        #if elapsed > 3:
        if not quiet:
            print("[{j:2} of {n}] training on {m} instances took {elapsed:.2f}s".format(**vars()))
        train_results.append(train_result)
        # save model
        if save_fn is not None:
            save_fn(model=model, i=i, n=n, seed=seed + i)
        # make predictions
        start = time.time()
        predictions = test_fn(model=model, test=test, i=i, seed=seed + i)
        elapsed = time.time() - start
        test_result = analyze(predictions, test)
        test_result["time"] = elapsed
        accuracy = test_result["accuracy"]
        geo_speedup = test_result["speedup_geo"]
        m = len(test["y"])
        
        if not quiet:
            print("[{j:2} of {n}] accuracy on {m} test instances: {accuracy:.2%}, speedup {geo_speedup:.2}x (elapsed {elapsed:.2f}s)".format(**vars()))
        test_results.append(test_result)

        del model
    
    # accuracy
    a = np.array([x["accuracy"] for x in test_results])
    mean_acc = a.mean()
    std = a.std()
    
    a = np.array([x["speedup_geo"] for x in test_results])
    geo_speedup = gmean(a)
    std_speedup = a.std()
    
    # times
    a = np.array([x["time"] for x in train_results])
    mean_train_time = a.mean()
    std_train_time = a.std()
    
    a = np.array([x["time"] for x in test_results])
    mean_eval_time = a.mean()
    std_eval_time = a.std()
    
    if not quiet:
        print()
    print("avg training time {mean_train_time:.2f}s, eval time {mean_eval_time:.2f}s".format(**vars()))
    print("avg accuracy {mean_acc:.2%} (std: {std:.2%}), oracle {geo_speedup:.2f}x (std: {std_speedup:.2%})".format(**vars()))
    return train_results, test_results

# %%
def run_experiments(platform, source, *args, **kwargs):
    print("PLATFORM", platform, "SOURCE", source)
    dataframe, seq_length, atomizer = load_dataframe(
        platform=platform,
        source=source,
        max_seq_len=1024, 
        # atomizer=GreedyAtomizer
        atomizer=CharacterAtomizer
    )

    x_2 = get_2(dataframe)
    x_4 = get_4(dataframe)
    x_11 = get_11(dataframe)
    x_seq = get_sequences(dataframe, seq_length)
    y = get_labels(dataframe)

    vocab_size = atomizer.vocab_size + 1  # +1 for pad value
    
    results = evaluate(dataframe, seq_length, *args, **kwargs)
    print()
    return (np.array([x["accuracy"] for x in results[1]]).mean(), gmean(np.array(
        [x["speedup_geo"] for x in results[1]])))

# %%
def experiments(*args, **kwargs):
    acc = []
    oracles = []
    a, o = run_experiments("amd", "N", *args, **kwargs)
    acc.append(a); oracles.append(o)
    a, o = run_experiments("amd", "B", *args, **kwargs)
    acc.append(a); oracles.append(o)
    a, o = run_experiments("amd", "S", *args, **kwargs)
    acc.append(a); oracles.append(o)
    a, o = run_experiments("amd", "BS", *args, **kwargs)
    acc.append(a); oracles.append(o)
    a, o = run_experiments("nvidia", "N", *args, **kwargs)
    acc.append(a); oracles.append(o)
    a, o = run_experiments("nvidia", "B", *args, **kwargs)
    acc.append(a); oracles.append(o)
    a, o = run_experiments("nvidia", "S", *args, **kwargs)
    acc.append(a); oracles.append(o)
    a, o = run_experiments("nvidia", "BS", *args, **kwargs)
    acc.append(a); oracles.append(o)

    print("************")
    print("            amd: [B, S, BS] nvidia: [B, S, BS]")
    print("Accuracies:", ", ".join(["{:.1%}".format(x) for x in acc]))
    print("Oracles:  ", ", ".join(["{:.2f}x".format(x) for x in oracles]))
    return acc, oracles

# %% [markdown]
# ### Zero-R

# %%
def create_model(seed=seed, **kwargs):
    np.random.seed(seed)
    return {}

def train_fn(model, train, validation, *args, **kwargs):
    np.random.seed(seed)
    model["zero_r"] = Counter(train["y"][:,0]).most_common(1)[0][0]
    return {}
    
def test_fn(model, test, seed, *args, **kwargs):
    np.random.seed(seed)
    return [model["zero_r"]] * len(test["y"])

# r = evaluate(dataframe, seq_length, create_model, train_fn, test_fn, split=(.6, .2, .2), seed=204, n=10)
r = experiments(create_model, train_fn, test_fn, split=(.6, .2, .2), seed=204, n=10, quiet=True)

# %% [markdown]
# ### CGO'13 model

# %%
def create_model(seed=seed, **kwargs):
    np.random.seed(seed)
    return DecisionTreeClassifier(random_state=seed, splitter="best", criterion="entropy")

def train_fn(model, train, validation, *args, **kwargs):
    np.random.seed(seed)
    model.fit(train["x_4"], train["y"])
    return {}
    
def test_fn(model, test, seed, *args, **kwargs):
    np.random.seed(seed)
    return model.predict(test["x_4"])

r = evaluate(dataframe, seq_length, create_model, train_fn, test_fn, split=(.6, .2, .2), seed=204, n=3)
# r = experiments(create_model, train_fn, test_fn, split=(.6, .2, .2), seed=204, n=10, quiet=True)
# Out:
# [ 1 of 3] training on 9553 instances took 0.01s
# [[1834  125]
#  [ 194 1019]]
# [ 1 of 3] accuracy on 3172 test instances: 89.94%, speedup 0.68x (elapsed 0.00s)
# [ 2 of 3] training on 9458 instances took 0.01s
# [[1840  118]
#  [ 182 1040]]
# [ 2 of 3] accuracy on 3180 test instances: 90.57%, speedup 0.68x (elapsed 0.00s)
# [ 3 of 3] training on 9540 instances took 0.01s
# [[1916  115]
#  [ 194 1050]]
# [ 3 of 3] accuracy on 3275 test instances: 90.56%, speedup 0.68x (elapsed 0.00s)
#
# avg training time 0.01s, eval time 0.00s
# avg accuracy 90.36% (std: 0.29%), oracle 0.68x (std: 0.12%)

# %% [markdown]
# ### CGO'13 Model (only dynprops)

# %%
def create_model(*args, seed=None, **kwargs):
    np.random.seed(seed)
    return DecisionTreeClassifier(random_state=seed, splitter="best", criterion="entropy")

def train_fn(model, train, validation, seed, *args, **kwargs):
    np.random.seed(seed)
    model.fit(train["x_2"], train["y"])
    return {}
    
def test_fn(model, test, *args, seed=None, **kwargs):
    np.random.seed(seed)
    return model.predict(test["x_2"])

r = evaluate(dataframe, seq_length, create_model, train_fn, test_fn, split=(.6, .2, .2), seed=204, n=3)
# r = experiments(create_model, train_fn, test_fn, split=(.6, .2, .2), seed=204, n=10, quiet=True)
# Out:
# [ 1 of 3] training on 9553 instances took 0.00s
# [[1871   88]
#  [ 166 1047]]
# [ 1 of 3] accuracy on 3172 test instances: 91.99%, speedup 0.68x (elapsed 0.00s)
# [ 2 of 3] training on 9458 instances took 0.00s
# [[1868   90]
#  [ 141 1081]]
# [ 2 of 3] accuracy on 3180 test instances: 92.74%, speedup 0.68x (elapsed 0.00s)
# [ 3 of 3] training on 9540 instances took 0.00s
# [[1942   89]
#  [ 154 1090]]
# [ 3 of 3] accuracy on 3275 test instances: 92.58%, speedup 0.68x (elapsed 0.00s)
#
# avg training time 0.00s, eval time 0.00s
# avg accuracy 92.44% (std: 0.32%), oracle 0.68x (std: 0.04%)

# %% [markdown]
# **Effect of split size on accuracy:**

# %%
# %%capture
splits = [(x, (1-x)/2, (1-x)/2) for x in np.arange(0.05,.975,0.025)]
results = list(zip(
    splits, [evaluate(dataframe, seq_length, create_model, train_fn, test_fn, split=split, seed=204, n=10) for split in splits]))

# %%
# TODO:
# y = [np.array([x["accuracy"] * 100 for x in r[1][1]]) for r in results]
# sns.tsplot(data=y)

x = [r[0][2] * 100 for r in results]
y = [np.array([x["accuracy"] * 100 for x in r[1][1]]).mean() for r in results]
err = [np.array([x["accuracy"] * 100 for x in r[1][1]]).std() for r in results]
plt.plot(x, y, color="b")
plt.errorbar(x, y, yerr=err, color="b", fmt='o', ecolor='k', capthick=1)

plt.xlabel("Ratio of unseen data (%)")
plt.ylabel("Accuracy (%)")

viz.finalise(figsize=(5, 5))

# %% [markdown]
# ### Baseline model (only dynprops)

# %%
# TODO: batch norm after merge, not before
# TODO: another layer of LSTM
# TODO: Dropout?
# TODO: activations: rely, sigmoid, softmax, tanh

def create_model(*args, seed=None, **kwargs):
    np.random.seed(seed)

    model = Sequential()
    # model.add(BatchNormalization(input_shape=(2,), name="dynprop_norm"))
    model.add(Dense(32, input_shape=(2,), init='normal', activation="relu"))
    model.add(Dropout(0.15))
    model.add(Dense(16, init='normal', activation="relu"))
#     model.add(Dropout(0.15))
#     model.add(Dense(16, init='normal', activation="relu"))
#     model.add(Dropout(0.15))
    model.add(Dense(2, init='normal', activation='softmax', name="output"))

    model.compile(loss='categorical_crossentropy',
                  optimizer='rmsprop',
                  metrics=['accuracy'])
    return model

def train_fn(model, train, validation, seed, *args, **kwargs):
    np.random.seed(seed)
    model.fit(train["x_2"].astype(np.int32), train["y_2"].astype(np.int32),
              nb_epoch=10,
              validation_data=(validation["x_2"].astype(np.int32), validation["y_2"].astype(np.int32)),
              verbose=0)
    return {}

def test_fn(model, test, seed, *args, **kwargs):
    np.random.seed(seed)
    predictions = model.predict(test["x_2"].astype(np.int32), verbose=0)
#     sns.distplot(predictions[:,0], kde=None)
#     viz.finalise()
#     sns.distplot(predictions[:,1], kde=None)
#     viz.finalise()

    clipped = np.array([np.argmax(x) for x in predictions], dtype=np.int32)
    # print(sum(clipped), len(clipped) - sum(clipped))
    return clipped

# r = evaluate(dataframe, seq_length, create_model, train_fn, test_fn, split=(.6, .2, .2), seed=204, n=10)
r = experiments(create_model, train_fn, test_fn, split=(.6, .2, .2), seed=204, n=10, quiet=True)

# %%
model = create_model()
model.summary()
SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))

# %%
# TEST ON NVIDIA B
def create_model(*args, seed=None, **kwargs):
    np.random.seed(seed)
    model = Sequential()
    model.add(BatchNormalization(input_shape=(2,), name="dynprop_norm"))
    model.add(Dense(4))
    model.add(Dense(2, name="output"))
    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    return model

def train_fn(model, train, validation, seed, *args, **kwargs):
    np.random.seed(seed)
    model.fit(train["x_2"], train["y_2"], validation_data=(validation["x_2"], validation["y_2"]),
              nb_epoch=10,
              verbose=0)
    return {}

def test_fn(model, test, seed, *args, **kwargs):
    np.random.seed(seed)
    predictions = model.predict(test["x_2"], verbose=0)
    clipped = np.array([np.argmax(x) for x in predictions], dtype=np.int32)
    return clipped

r = evaluate(dataframe, seq_length, create_model, train_fn, test_fn, split=(.6, .2, .2), seed=204, n=3)
# Out:
# [ 1 of 3] training on 397 instances took 2.87s
# [[25 31]
#  [56 33]]
# [ 1 of 3] accuracy on 145 test instances: 40.00%, speedup 0.6x (elapsed 1.17s)
# [ 2 of 3] training on 378 instances took 2.90s
# [[27 33]
#  [43 25]]
# [ 2 of 3] accuracy on 128 test instances: 40.62%, speedup 0.57x (elapsed 1.27s)
# [ 3 of 3] training on 420 instances took 2.97s
# [[31 27]
#  [37 36]]
# [ 3 of 3] accuracy on 131 test instances: 51.15%, speedup 0.66x (elapsed 1.24s)
#
# avg training time 2.91s, eval time 1.23s
# avg accuracy 43.92% (std: 5.11%), oracle 0.61x (std: 3.53%)

# %%
# TEST 3a, AMD S:
def create_model(*args, seed=None, **kwargs):
    np.random.seed(seed)
    model = Sequential()
    model.add(BatchNormalization(input_shape=(11,), name="dynprop_norm"))
    model.add(Dense(11, activation="relu"))
    model.add(Dense(2, activation="sigmoid", name="output"))
    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    return model

def train_fn(model, train, validation, seed, *args, **kwargs):
    np.random.seed(seed)
    model.fit(train["x_11"], train["y_2"], validation_data=(validation["x_11"], validation["y_2"]),
              nb_epoch=10,
              verbose=0)
    return {}

def test_fn(model, test, seed, *args, **kwargs):
    np.random.seed(seed)
    predictions = model.predict(test["x_11"], verbose=0)
    clipped = np.array([np.argmax(x) for x in predictions], dtype=np.int32)
    return clipped

dataframe, seq_length, atomizer = load_dataframe(
    platform="amd",
    source="S"
)
r = evaluate(dataframe, seq_length, create_model, train_fn, test_fn, split=(.6, .2, .2), seed=204, n=3)
# Out:
# [ 1 of 3] training on 9553 instances took 19.82s
# [[ 998  405]
#  [ 234 1535]]
# [ 1 of 3] accuracy on 3172 test instances: 79.85%, speedup 0.71x (elapsed 1.67s)
# [ 2 of 3] training on 9458 instances took 19.55s
# [[1056  376]
#  [ 214 1534]]
# [ 2 of 3] accuracy on 3180 test instances: 81.45%, speedup 0.7x (elapsed 1.62s)
# [ 3 of 3] training on 9540 instances took 19.57s
# [[1178  283]
#  [ 269 1545]]
# [ 3 of 3] accuracy on 3275 test instances: 83.15%, speedup 0.7x (elapsed 1.67s)
#
# avg training time 19.65s, eval time 1.65s
# avg accuracy 81.48% (std: 1.34%), oracle 0.70x (std: 0.32%)

# %%
# TEST 3b, NVIDIA S:
def create_model(*args, seed=None, **kwargs):
    np.random.seed(seed)
    model = Sequential()
    model.add(BatchNormalization(input_shape=(11,), name="dynprop_norm"))
    model.add(Dense(11, activation="relu"))
    model.add(Dense(2, activation="sigmoid", name="output"))
    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    return model

def train_fn(model, train, validation, seed, *args, **kwargs):
    np.random.seed(seed)
    model.fit(train["x_11"], train["y_2"], validation_data=(validation["x_11"], validation["y_2"]),
              nb_epoch=10,
              verbose=0)
    return {}

def test_fn(model, test, seed, *args, **kwargs):
    np.random.seed(seed)
    predictions = model.predict(test["x_11"], verbose=0)
    clipped = np.array([np.argmax(x) for x in predictions], dtype=np.int32)
    return clipped

dataframe, seq_length, atomizer = load_dataframe(
    platform="nvidia",
    source="S"
)
r = evaluate(dataframe, seq_length, create_model, train_fn, test_fn, split=(.6, .2, .2), seed=204, n=3)
# Out:
# num instances 15919 (15919 synthetic, 0 benchmarks)
# unique kernels 1000
# vocab size 69
# pad val 69
# padded seq length 658
# [ 1 of 3] training on 9553 instances took 20.32s
# [[1557  402]
#  [  97 1116]]
# [ 1 of 3] accuracy on 3172 test instances: 84.27%, speedup 0.67x (elapsed 1.80s)
# [ 2 of 3] training on 9458 instances took 20.10s
# [[1680  278]
#  [  95 1127]]
# [ 2 of 3] accuracy on 3180 test instances: 88.27%, speedup 0.67x (elapsed 1.80s)
# [ 3 of 3] training on 9540 instances took 20.34s
# [[1668  363]
#  [  84 1160]]
# [ 3 of 3] accuracy on 3275 test instances: 86.35%, speedup 0.67x (elapsed 1.88s)
#
# avg training time 20.25s, eval time 1.82s
# avg accuracy 86.30% (std: 1.63%), oracle 0.67x (std: 0.07%)

# %%
# TEST 3c, AMD B:
def create_model(*args, seed=None, **kwargs):
    np.random.seed(seed)
    model = Sequential()
    model.add(BatchNormalization(input_shape=(11,), name="dynprop_norm"))
    model.add(Dense(11, activation="relu"))
    model.add(Dense(2, activation="sigmoid", name="output"))
    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    return model

def train_fn(model, train, validation, seed, *args, **kwargs):
    np.random.seed(seed)
    model.fit(train["x_11"], train["y_2"], validation_data=(validation["x_11"], validation["y_2"]),
              nb_epoch=10,
              verbose=0)
    return {}

def test_fn(model, test, seed, *args, **kwargs):
    np.random.seed(seed)
    predictions = model.predict(test["x_11"], verbose=0)
    clipped = np.array([np.argmax(x) for x in predictions], dtype=np.int32)
    return clipped

dataframe, seq_length, atomizer = load_dataframe(
    platform="amd",
    source="B"
)
r = evaluate(dataframe, seq_length, create_model, train_fn, test_fn, split=(.6, .2, .2), seed=204, n=3)
# Out:
# num instances 680 (0 synthetic, 680 benchmarks)
# unique kernels 247
# vocab size 84
# pad val 84
# padded seq length 1000
# [ 1 of 3] training on 397 instances took 3.40s
# [[73  6]
#  [51 15]]
# [ 1 of 3] accuracy on 145 test instances: 60.69%, speedup 0.57x (elapsed 1.63s)
# [ 2 of 3] training on 378 instances took 3.41s
# [[66  7]
#  [25 30]]
# [ 2 of 3] accuracy on 128 test instances: 75.00%, speedup 0.53x (elapsed 1.64s)
# [ 3 of 3] training on 420 instances took 3.46s
# [[60 17]
#  [26 28]]
# [ 3 of 3] accuracy on 131 test instances: 67.18%, speedup 0.57x (elapsed 1.67s)
#
# avg training time 3.42s, eval time 1.65s
# avg accuracy 67.62% (std: 5.85%), oracle 0.56x (std: 1.84%)

# %%
# TEST 3d, NVIDIA B:
def create_model(*args, seed=None, **kwargs):
    np.random.seed(seed)
    model = Sequential()
    model.add(BatchNormalization(input_shape=(11,), name="dynprop_norm"))
    model.add(Dense(11, activation="relu"))
    model.add(Dense(2, activation="sigmoid", name="output"))
    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    return model

def train_fn(model, train, validation, seed, *args, **kwargs):
    np.random.seed(seed)
    model.fit(train["x_11"], train["y_2"], validation_data=(validation["x_11"], validation["y_2"]),
              nb_epoch=10,
              verbose=0)
    return {}

def test_fn(model, test, seed, *args, **kwargs):
    np.random.seed(seed)
    predictions = model.predict(test["x_11"], verbose=0)
    clipped = np.array([np.argmax(x) for x in predictions], dtype=np.int32)
    return clipped

dataframe, seq_length, atomizer = load_dataframe(
    platform="nvidia",
    source="B"
)
r = evaluate(dataframe, seq_length, create_model, train_fn, test_fn, split=(.6, .2, .2), seed=204, n=3)
# Out:
# num instances 680 (0 synthetic, 680 benchmarks)
# unique kernels 247
# vocab size 84
# pad val 84
# padded seq length 1000
# [ 1 of 3] training on 397 instances took 3.49s
# [[14 42]
#  [22 67]]
# [ 1 of 3] accuracy on 145 test instances: 55.86%, speedup 0.67x (elapsed 1.63s)
# [ 2 of 3] training on 378 instances took 3.49s
# [[14 46]
#  [ 2 66]]
# [ 2 of 3] accuracy on 128 test instances: 62.50%, speedup 0.61x (elapsed 1.65s)
# [ 3 of 3] training on 420 instances took 3.67s
# [[22 36]
#  [ 8 65]]
# [ 3 of 3] accuracy on 131 test instances: 66.41%, speedup 0.64x (elapsed 1.74s)
#
# avg training time 3.55s, eval time 1.67s
# avg accuracy 61.59% (std: 4.35%), oracle 0.64x (std: 2.17%)

# %%
# TEST 3e, AMD BS:
def create_model(*args, seed=None, **kwargs):
    np.random.seed(seed)
    model = Sequential()
    model.add(BatchNormalization(input_shape=(11,), name="dynprop_norm"))
    model.add(Dense(11, activation="relu"))
    model.add(Dense(2, activation="sigmoid", name="output"))
    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    return model

def train_fn(model, train, validation, seed, *args, **kwargs):
    np.random.seed(seed)
    model.fit(train["x_11"], train["y_2"], validation_data=(validation["x_11"], validation["y_2"]),
              nb_epoch=10,
              verbose=0)
    return {}

def test_fn(model, test, seed, *args, **kwargs):
    np.random.seed(seed)
    predictions = model.predict(test["x_11"], verbose=0)
    clipped = np.array([np.argmax(x) for x in predictions], dtype=np.int32)
    return clipped

dataframe, seq_length, atomizer = load_dataframe(
    platform="amd",
    source="BS"
)
r = evaluate(dataframe, seq_length, create_model, train_fn, test_fn, split=(.6, .2, .2), seed=204, n=3)
# Out:
# num instances 16599 (15919 synthetic, 680 benchmarks)
# unique kernels 1247
# vocab size 84
# pad val 84
# padded seq length 1000
# [ 1 of 3] training on 16316 instances took 28.95s
# [[67  9]
#  [39 24]]
# [ 1 of 3] accuracy on 139 test instances: 65.47%, speedup 0.52x (elapsed 1.73s)
# [ 2 of 3] training on 16297 instances took 28.74s
# [[72 15]
#  [22 35]]
# [ 2 of 3] accuracy on 144 test instances: 74.31%, speedup 0.53x (elapsed 1.67s)
# [ 3 of 3] training on 16339 instances took 30.20s
# [[52 19]
#  [25 32]]
# [ 3 of 3] accuracy on 128 test instances: 65.62%, speedup 0.54x (elapsed 1.67s)
#
# avg training time 29.30s, eval time 1.69s
# avg accuracy 68.47% (std: 4.13%), oracle 0.53x (std: 0.92%)

# %%
# TEST 3f, NVIDIA BS:
def create_model(*args, seed=None, **kwargs):
    np.random.seed(seed)
    model = Sequential()
    model.add(BatchNormalization(input_shape=(11,), name="dynprop_norm"))
    model.add(Dense(11, activation="relu"))
    model.add(Dense(2, activation="sigmoid", name="output"))
    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    return model

def train_fn(model, train, validation, seed, *args, **kwargs):
    np.random.seed(seed)
    model.fit(train["x_11"], train["y_2"], validation_data=(validation["x_11"], validation["y_2"]),
              nb_epoch=10,
              verbose=0)
    return {}

def test_fn(model, test, seed, *args, **kwargs):
    np.random.seed(seed)
    predictions = model.predict(test["x_11"], verbose=0)
    clipped = np.array([np.argmax(x) for x in predictions], dtype=np.int32)
    return clipped

dataframe, seq_length, atomizer = load_dataframe(
    platform="nvidia",
    source="BS"
)
r = evaluate(dataframe, seq_length, create_model, train_fn, test_fn, split=(.6, .2, .2), seed=204, n=3)
# Out:
# num instances 16599 (15919 synthetic, 680 benchmarks)
# unique kernels 1247
# vocab size 84
# pad val 84
# padded seq length 1000
# [ 1 of 3] training on 16316 instances took 29.10s
# [[36 14]
#  [68 21]]
# [ 1 of 3] accuracy on 139 test instances: 41.01%, speedup 0.48x (elapsed 1.81s)
# [ 2 of 3] training on 16297 instances took 29.09s
# [[57  0]
#  [84  3]]
# [ 2 of 3] accuracy on 144 test instances: 41.67%, speedup 0.45x (elapsed 1.71s)
# [ 3 of 3] training on 16339 instances took 29.22s
# [[43 15]
#  [53 17]]
# [ 3 of 3] accuracy on 128 test instances: 46.88%, speedup 0.58x (elapsed 1.80s)
#
# avg training time 29.14s, eval time 1.77s
# avg accuracy 43.18% (std: 2.62%), oracle 0.50x (std: 5.56%)

# %% [markdown]
# ### Tweaks

# %%
# TEST 4, CGO'13
def create_model(seed=seed, **kwargs):
    np.random.seed(seed)
    return DecisionTreeClassifier(random_state=seed, splitter="best", criterion="entropy")

def train_fn(model, train, validation, *args, **kwargs):
    np.random.seed(seed)
    model.fit(train["x_4"], train["y"])
    return {}
    
def test_fn(model, test, seed, *args, **kwargs):
    np.random.seed(seed)
    return model.predict(test["x_4"])

dataframe, seq_length, atomizer = load_dataframe(
    platform="amd",
    source="B"
)
r = evaluate(dataframe, seq_length, create_model, train_fn, test_fn, split=(.6, .2, .2), seed=204, n=3)
print()
dataframe, seq_length, atomizer = load_dataframe(
    platform="nvidia",
    source="B"
)
r = evaluate(dataframe, seq_length, create_model, train_fn, test_fn, split=(.6, .2, .2), seed=204, n=3)
# Out:
# num instances 680 (0 synthetic, 680 benchmarks)
# unique kernels 247
# vocab size 84
# pad val 84
# padded seq length 1000
# [ 1 of 3] training on 397 instances took 0.00s
# [[70  9]
#  [17 49]]
# [ 1 of 3] accuracy on 145 test instances: 82.07%, speedup 0.56x (elapsed 0.00s)
# [ 2 of 3] training on 378 instances took 0.00s
# [[56 17]
#  [13 42]]
# [ 2 of 3] accuracy on 128 test instances: 76.56%, speedup 0.5x (elapsed 0.00s)
# [ 3 of 3] training on 420 instances took 0.00s
# [[71  6]
#  [16 38]]
# [ 3 of 3] accuracy on 131 test instances: 83.21%, speedup 0.54x (elapsed 0.00s)
#
# avg training time 0.00s, eval time 0.00s
# avg accuracy 80.61% (std: 2.90%), oracle 0.53x (std: 2.32%)
# num instances 680 (0 synthetic, 680 benchmarks)
# unique kernels 247
# vocab size 84
# pad val 84
# padded seq length 1000
# [ 1 of 3] training on 397 instances took 0.00s
# [[48  8]
#  [16 73]]
# [ 1 of 3] accuracy on 145 test instances: 83.45%, speedup 0.58x (elapsed 0.00s)
# [ 2 of 3] training on 378 instances took 0.00s
# [[49 11]
#  [13 55]]
# [ 2 of 3] accuracy on 128 test instances: 81.25%, speedup 0.56x (elapsed 0.00s)
# [ 3 of 3] training on 420 instances took 0.00s
# [[43 15]
#  [18 55]]
# [ 3 of 3] accuracy on 131 test instances: 74.81%, speedup 0.58x (elapsed 0.00s)
#
# avg training time 0.00s, eval time 0.00s
# avg accuracy 79.84% (std: 3.67%), oracle 0.58x (std: 0.76%)

# %%
# TEST 4a, AMD B:
def create_model(*args, seed=None, **kwargs):
    np.random.seed(seed)
    model = Sequential()
    model.add(BatchNormalization(input_shape=(2,), name="dynprop_norm"))
    model.add(Dense(11, activation="relu"))
    model.add(Dense(2, activation="sigmoid", name="output"))
    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    return model

def train_fn(model, train, validation, seed, *args, **kwargs):
    np.random.seed(seed)
    model.fit(train["x_2"], train["y_2"], validation_data=(validation["x_2"], validation["y_2"]),
              nb_epoch=10,
              verbose=0)
    return {}

def test_fn(model, test, seed, *args, **kwargs):
    np.random.seed(seed)
    predictions = model.predict(test["x_2"], verbose=0)
    clipped = np.array([np.argmax(x) for x in predictions], dtype=np.int32)
    return clipped

dataframe, seq_length, atomizer = load_dataframe(
    platform="amd",
    source="B"
)
r = evaluate(dataframe, seq_length, create_model, train_fn, test_fn, split=(.6, .2, .2), seed=204, n=3)
print()
dataframe, seq_length, atomizer = load_dataframe(
    platform="nvidia",
    source="B"
)
r = evaluate(dataframe, seq_length, create_model, train_fn, test_fn, split=(.6, .2, .2), seed=204, n=3)
# Out:
# num instances 680 (0 synthetic, 680 benchmarks)
# unique kernels 247
# vocab size 84
# pad val 84
# padded seq length 1000
# [ 1 of 3] training on 397 instances took 5.45s
# [[72  7]
#  [42 24]]
# [ 1 of 3] accuracy on 145 test instances: 66.21%, speedup 0.57x (elapsed 2.03s)
# [ 2 of 3] training on 378 instances took 3.98s
# [[55 18]
#  [12 43]]
# [ 2 of 3] accuracy on 128 test instances: 76.56%, speedup 0.52x (elapsed 2.03s)
# [ 3 of 3] training on 420 instances took 4.13s
# [[62 15]
#  [13 41]]
# [ 3 of 3] accuracy on 131 test instances: 78.63%, speedup 0.51x (elapsed 2.12s)
#
# avg training time 4.52s, eval time 2.06s
# avg accuracy 73.80% (std: 5.43%), oracle 0.53x (std: 2.86%)
#
# num instances 680 (0 synthetic, 680 benchmarks)
# unique kernels 247
# vocab size 84
# pad val 84
# padded seq length 1000
# [ 1 of 3] training on 397 instances took 4.03s
# [[15 41]
#  [14 75]]
# [ 1 of 3] accuracy on 145 test instances: 62.07%, speedup 0.62x (elapsed 2.16s)
# [ 2 of 3] training on 378 instances took 4.07s
# [[ 0 60]
#  [ 0 68]]
# [ 2 of 3] accuracy on 128 test instances: 53.12%, speedup 0.72x (elapsed 2.16s)
# [ 3 of 3] training on 420 instances took 4.20s
# [[ 3 55]
#  [ 1 72]]
# [ 3 of 3] accuracy on 131 test instances: 57.25%, speedup 0.74x (elapsed 2.14s)
#
# avg training time 4.10s, eval time 2.16s
# avg accuracy 57.48% (std: 3.65%), oracle 0.69x (std: 5.32%)

# %%
# TEST 4a, AMD B:
def create_model(*args, seed=None, **kwargs):
    np.random.seed(seed)
    model = Sequential()
    model.add(BatchNormalization(input_shape=(4,), name="dynprop_norm"))
    model.add(Dense(11, activation="relu"))
    model.add(Dense(2, activation="sigmoid", name="output"))
    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    return model

def train_fn(model, train, validation, seed, *args, **kwargs):
    np.random.seed(seed)
    model.fit(train["x_4"], train["y_2"], validation_data=(validation["x_4"], validation["y_2"]),
              nb_epoch=10,
              verbose=0)
    return {}

def test_fn(model, test, seed, *args, **kwargs):
    np.random.seed(seed)
    predictions = model.predict(test["x_4"], verbose=0)
    clipped = np.array([np.argmax(x) for x in predictions], dtype=np.int32)
    return clipped

dataframe, seq_length, atomizer = load_dataframe(
    platform="amd",
    source="B"
)
r = evaluate(dataframe, seq_length, create_model, train_fn, test_fn, split=(.6, .2, .2), seed=204, n=3)
print()
dataframe, seq_length, atomizer = load_dataframe(
    platform="nvidia",
    source="B"
)
r = evaluate(dataframe, seq_length, create_model, train_fn, test_fn, split=(.6, .2, .2), seed=204, n=3)
# Out:
# num instances 680 (0 synthetic, 680 benchmarks)
# unique kernels 247
# vocab size 84
# pad val 84
# padded seq length 1000
# [ 1 of 3] training on 397 instances took 3.97s
# [[76  3]
#  [51 15]]
# [ 1 of 3] accuracy on 145 test instances: 62.76%, speedup 0.54x (elapsed 1.96s)
# [ 2 of 3] training on 378 instances took 3.96s
# [[56 17]
#  [37 18]]
# [ 2 of 3] accuracy on 128 test instances: 57.81%, speedup 0.56x (elapsed 1.93s)
# [ 3 of 3] training on 420 instances took 3.97s
# [[70  7]
#  [34 20]]
# [ 3 of 3] accuracy on 131 test instances: 68.70%, speedup 0.57x (elapsed 2.00s)
#
# avg training time 3.96s, eval time 1.96s
# avg accuracy 63.09% (std: 4.45%), oracle 0.56x (std: 1.17%)
#
# num instances 680 (0 synthetic, 680 benchmarks)
# unique kernels 247
# vocab size 84
# pad val 84
# padded seq length 1000
# [ 1 of 3] training on 397 instances took 3.96s
# [[10 46]
#  [18 71]]
# [ 1 of 3] accuracy on 145 test instances: 55.86%, speedup 0.73x (elapsed 1.98s)
# [ 2 of 3] training on 378 instances took 3.93s
# [[14 46]
#  [ 9 59]]
# [ 2 of 3] accuracy on 128 test instances: 57.03%, speedup 0.64x (elapsed 2.11s)
# [ 3 of 3] training on 420 instances took 4.01s
# [[ 5 53]
#  [ 5 68]]
# [ 3 of 3] accuracy on 131 test instances: 55.73%, speedup 0.67x (elapsed 2.03s)
#
# avg training time 3.97s, eval time 2.04s
# avg accuracy 56.21% (std: 0.59%), oracle 0.68x (std: 3.41%)

# %%
# TEST 4a, NN:
def create_model(*args, seed=None, **kwargs):
    np.random.seed(seed)
    model = Sequential()
    model.add(BatchNormalization(input_shape=(11,), name="dynprop_norm"))
    model.add(Dense(11, activation="relu"))
    model.add(Dense(2, activation="sigmoid", name="output"))
    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    return model

def train_fn(model, train, validation, seed, *args, **kwargs):
    np.random.seed(seed)
    model.fit(train["x_11"], train["y_2"], validation_data=(validation["x_11"], validation["y_2"]),
              nb_epoch=10,
              verbose=0)
    return {}

def test_fn(model, test, seed, *args, **kwargs):
    np.random.seed(seed)
    predictions = model.predict(test["x_11"], verbose=0)
    clipped = np.array([np.argmax(x) for x in predictions], dtype=np.int32)
    return clipped

dataframe, seq_length, atomizer = load_dataframe(
    platform="amd",
    source="B"
)
r = evaluate(dataframe, seq_length, create_model, train_fn, test_fn, split=(.6, .2, .2), seed=204, n=3)
print()
dataframe, seq_length, atomizer = load_dataframe(
    platform="nvidia",
    source="B"
)
r = evaluate(dataframe, seq_length, create_model, train_fn, test_fn, split=(.6, .2, .2), seed=204, n=3)
# Out:
# num instances 680 (0 synthetic, 680 benchmarks)
# unique kernels 247
# vocab size 84
# pad val 84
# padded seq length 1000
# [ 1 of 3] training on 397 instances took 3.74s
# [[73  6]
#  [51 15]]
# [ 1 of 3] accuracy on 145 test instances: 60.69%, speedup 0.57x (elapsed 1.86s)
# [ 2 of 3] training on 378 instances took 3.73s
# [[66  7]
#  [25 30]]
# [ 2 of 3] accuracy on 128 test instances: 75.00%, speedup 0.53x (elapsed 1.87s)
# [ 3 of 3] training on 420 instances took 3.90s
# [[60 17]
#  [26 28]]
# [ 3 of 3] accuracy on 131 test instances: 67.18%, speedup 0.57x (elapsed 1.94s)
#
# avg training time 3.79s, eval time 1.89s
# avg accuracy 67.62% (std: 5.85%), oracle 0.56x (std: 1.84%)
#
# num instances 680 (0 synthetic, 680 benchmarks)
# unique kernels 247
# vocab size 84
# pad val 84
# padded seq length 1000
# [ 1 of 3] training on 397 instances took 3.81s
# [[14 42]
#  [22 67]]
# [ 1 of 3] accuracy on 145 test instances: 55.86%, speedup 0.67x (elapsed 1.98s)
# [ 2 of 3] training on 378 instances took 3.94s
# [[14 46]
#  [ 2 66]]
# [ 2 of 3] accuracy on 128 test instances: 62.50%, speedup 0.61x (elapsed 1.93s)
# [ 3 of 3] training on 420 instances took 3.89s
# [[22 36]
#  [ 8 65]]
# [ 3 of 3] accuracy on 131 test instances: 66.41%, speedup 0.64x (elapsed 1.98s)
#
# avg training time 3.88s, eval time 1.96s
# avg accuracy 61.59% (std: 4.35%), oracle 0.64x (std: 2.17%)

# %% [markdown]
# ### Now we're getting somewhere!

# %%
batch_size = 64

def create_model(*args, seed=None, **kwargs):
    np.random.seed(seed)
    embedding_vector_length = 64 # 64

    dyn_inputs = Input(shape=(2,), name="dynprop_in")
    left = BatchNormalization(name="dynprop_norm")(dyn_inputs)

    seq_inputs = Input(shape=(seq_length,), dtype="int32", name="seq_in")
    right = Embedding(output_dim=embedding_vector_length, input_dim=vocab_size, input_length=seq_length)(seq_inputs)
    right = LSTM(16, consume_less="mem")(right)
    right = BatchNormalization(input_shape=(32,), name="lstm_norm")(right)

    aux_out = Dense(2, activation="sigmoid", name="aux_out")(right)

    x = merge([left, right], mode="concat")
    x = Dense(18, activation="relu")(x)
#     x = Dense(32, activation="relu")(x)
#     x = Dense(32, activation="relu")(x)
    out = Dense(2, activation="sigmoid", name="out")(x)

    model = Model(input=[dyn_inputs, seq_inputs], output=[out, aux_out])
    model.compile(optimizer="adam",
                  loss={"out": "categorical_crossentropy", "aux_out": "categorical_crossentropy"},
                  loss_weights={"out": 1., "aux_out": .2},
                  metrics=['accuracy'])
    return model

def train_fn(model, train, validation, seed, *args, **kwargs):
    np.random.seed(seed)
    model.fit({"dynprop_in": train["x_2"], "seq_in": train["x_seq"]},
          {"out": train["y_2"], "aux_out": train["y_2"]},
          nb_epoch=10,
          batch_size=batch_size,
          validation_data=({"dynprop_in": validation["x_2"], "seq_in": validation["x_seq"]},
                           {"out": validation["y_2"], "aux_out": validation["y_2"]}),
          verbose=1,
          shuffle=True
    )
    return {}

def save_fn(model, seed, i, *args, **kwargs):
    outpath = "classification/models/model-{i}-{seed}.h5".format(**vars())
    model.save(outpath)
    print("saved model", outpath)

def test_fn(model, test, seed, *args, **kwargs):
    np.random.seed(seed)
    predictions = np.array(model.predict({"dynprop_in": test["x_2"], "seq_in": test["x_seq"]},
                                         batch_size=batch_size, verbose=0))
    clipped = [np.argmax(x) for x in predictions[0]]
    return clipped

dataframe, seq_length, atomizer = load_dataframe(
    platform="amd",
    source="B"
)
r = evaluate(dataframe, seq_length, create_model, train_fn, test_fn, split=(.6, .2, .2), seed=204, n=3)
print()
dataframe, seq_length, atomizer = load_dataframe(
    platform="nvidia",
    source="B"
)
r = evaluate(dataframe, seq_length, create_model, train_fn, test_fn,
             split=(.6, .2, .2), save_fn=save_fn, seed=204, n=3)
# Out:
# num instances 680 (0 synthetic, 680 benchmarks)
# unique kernels 247
# vocab size 84
# pad val 84
# padded seq length 1000
# Train on 397 samples, validate on 138 samples
# Epoch 1/10
# 397/397 [==============================] - 16s - loss: 0.8079 - out_loss: 0.6702 - aux_out_loss: 0.6888 - out_acc: 0.6096 - aux_out_acc: 0.5038 - val_loss: 0.9848 - val_out_loss: 0.8469 - val_aux_out_loss: 0.6894 - val_out_acc: 0.4855 - val_aux_out_acc: 0.5507
# Epoch 2/10
# 397/397 [==============================] - 11s - loss: 0.7755 - out_loss: 0.6438 - aux_out_loss: 0.6587 - out_acc: 0.6171 - aux_out_acc: 0.5844 - val_loss: 0.9100 - val_out_loss: 0.7720 - val_aux_out_loss: 0.6897 - val_out_acc: 0.4855 - val_aux_out_acc: 0.5435
# Epoch 3/10
# 397/397 [==============================] - 11s - loss: 0.7348 - out_loss: 0.6112 - aux_out_loss: 0.6177 - out_acc: 0.6599 - aux_out_acc: 0.6146 - val_loss: 0.8825 - val_out_loss: 0.7441 - val_aux_out_loss: 0.6921 - val_out_acc: 0.4855 - val_aux_out_acc: 0.5217
# Epoch 4/10
# 397/397 [==============================] - 11s - loss: 0.7150 - out_loss: 0.5948 - aux_out_loss: 0.6010 - out_acc: 0.6725 - aux_out_acc: 0.6196 - val_loss: 0.8626 - val_out_loss: 0.7239 - val_aux_out_loss: 0.6935 - val_out_acc: 0.4855 - val_aux_out_acc: 0.5145
# Epoch 5/10
# 397/397 [==============================] - 10s - loss: 0.6845 - out_loss: 0.5696 - aux_out_loss: 0.5745 - out_acc: 0.6776 - aux_out_acc: 0.6423 - val_loss: 0.8501 - val_out_loss: 0.7114 - val_aux_out_loss: 0.6936 - val_out_acc: 0.4855 - val_aux_out_acc: 0.5507
# Epoch 6/10
# 397/397 [==============================] - 11s - loss: 0.6651 - out_loss: 0.5530 - aux_out_loss: 0.5608 - out_acc: 0.7028 - aux_out_acc: 0.6549 - val_loss: 0.8392 - val_out_loss: 0.7014 - val_aux_out_loss: 0.6893 - val_out_acc: 0.5725 - val_aux_out_acc: 0.5507
# Epoch 7/10
# 397/397 [==============================] - 11s - loss: 0.6512 - out_loss: 0.5408 - aux_out_loss: 0.5520 - out_acc: 0.7305 - aux_out_acc: 0.6751 - val_loss: 0.8252 - val_out_loss: 0.6877 - val_aux_out_loss: 0.6870 - val_out_acc: 0.6014 - val_aux_out_acc: 0.5507
# Epoch 8/10
# 397/397 [==============================] - 11s - loss: 0.6295 - out_loss: 0.5224 - aux_out_loss: 0.5354 - out_acc: 0.7380 - aux_out_acc: 0.6700 - val_loss: 0.8146 - val_out_loss: 0.6778 - val_aux_out_loss: 0.6844 - val_out_acc: 0.6522 - val_aux_out_acc: 0.5435
# Epoch 9/10
# 397/397 [==============================] - 11s - loss: 0.6115 - out_loss: 0.5059 - aux_out_loss: 0.5282 - out_acc: 0.7481 - aux_out_acc: 0.7280 - val_loss: 0.8062 - val_out_loss: 0.6695 - val_aux_out_loss: 0.6831 - val_out_acc: 0.6957 - val_aux_out_acc: 0.5725
# Epoch 10/10
# 397/397 [==============================] - 11s - loss: 0.6040 - out_loss: 0.4987 - aux_out_loss: 0.5267 - out_acc: 0.7557 - aux_out_acc: 0.7204 - val_loss: 0.7999 - val_out_loss: 0.6634 - val_aux_out_loss: 0.6823 - val_out_acc: 0.6812 - val_aux_out_acc: 0.5580
# [ 1 of 3] training on 397 instances took 118.63s
# [[72  7]
#  [40 26]]
# [ 1 of 3] accuracy on 145 test instances: 67.59%, speedup 0.53x (elapsed 4.43s)
# Train on 378 samples, validate on 174 samples
# Epoch 1/10
# 378/378 [==============================] - 15s - loss: 0.8066 - out_loss: 0.6690 - aux_out_loss: 0.6884 - out_acc: 0.5423 - aux_out_acc: 0.5503 - val_loss: 0.8438 - val_out_loss: 0.7055 - val_aux_out_loss: 0.6912 - val_out_acc: 0.6322 - val_aux_out_acc: 0.6092
# Epoch 2/10
# 378/378 [==============================] - 9s - loss: 0.7712 - out_loss: 0.6344 - aux_out_loss: 0.6843 - out_acc: 0.6746 - aux_out_acc: 0.6005 - val_loss: 0.8275 - val_out_loss: 0.6897 - val_aux_out_loss: 0.6890 - val_out_acc: 0.6494 - val_aux_out_acc: 0.6437
# Epoch 3/10
# 378/378 [==============================] - 9s - loss: 0.7440 - out_loss: 0.6081 - aux_out_loss: 0.6797 - out_acc: 0.7037 - aux_out_acc: 0.6032 - val_loss: 0.8161 - val_out_loss: 0.6789 - val_aux_out_loss: 0.6861 - val_out_acc: 0.6552 - val_aux_out_acc: 0.6264
# Epoch 4/10
# 378/378 [==============================] - 9s - loss: 0.7217 - out_loss: 0.5875 - aux_out_loss: 0.6707 - out_acc: 0.6905 - aux_out_acc: 0.6349 - val_loss: 0.8064 - val_out_loss: 0.6697 - val_aux_out_loss: 0.6835 - val_out_acc: 0.6724 - val_aux_out_acc: 0.6264
# Epoch 5/10
# 378/378 [==============================] - 9s - loss: 0.6927 - out_loss: 0.5607 - aux_out_loss: 0.6600 - out_acc: 0.7302 - aux_out_acc: 0.6640 - val_loss: 0.8023 - val_out_loss: 0.6658 - val_aux_out_loss: 0.6823 - val_out_acc: 0.6724 - val_aux_out_acc: 0.6264
# Epoch 6/10
# 378/378 [==============================] - 9s - loss: 0.6696 - out_loss: 0.5400 - aux_out_loss: 0.6483 - out_acc: 0.7275 - aux_out_acc: 0.6481 - val_loss: 0.7831 - val_out_loss: 0.6476 - val_aux_out_loss: 0.6774 - val_out_acc: 0.7069 - val_aux_out_acc: 0.6264
# Epoch 7/10
# 378/378 [==============================] - 9s - loss: 0.6583 - out_loss: 0.5304 - aux_out_loss: 0.6393 - out_acc: 0.7249 - aux_out_acc: 0.6958 - val_loss: 0.7532 - val_out_loss: 0.6189 - val_aux_out_loss: 0.6718 - val_out_acc: 0.7069 - val_aux_out_acc: 0.6264
# Epoch 8/10
# 378/378 [==============================] - 9s - loss: 0.6386 - out_loss: 0.5130 - aux_out_loss: 0.6280 - out_acc: 0.7593 - aux_out_acc: 0.6720 - val_loss: 0.7713 - val_out_loss: 0.6369 - val_aux_out_loss: 0.6720 - val_out_acc: 0.7471 - val_aux_out_acc: 0.6264
# Epoch 9/10
# 378/378 [==============================] - 9s - loss: 0.6415 - out_loss: 0.5182 - aux_out_loss: 0.6165 - out_acc: 0.7434 - aux_out_acc: 0.6852 - val_loss: 0.7869 - val_out_loss: 0.6515 - val_aux_out_loss: 0.6771 - val_out_acc: 0.7241 - val_aux_out_acc: 0.6322
# Epoch 10/10
# 378/378 [==============================] - 9s - loss: 0.6055 - out_loss: 0.4844 - aux_out_loss: 0.6057 - out_acc: 0.7698 - aux_out_acc: 0.6984 - val_loss: 0.7657 - val_out_loss: 0.6314 - val_aux_out_loss: 0.6716 - val_out_acc: 0.7586 - val_aux_out_acc: 0.6264
# [ 2 of 3] training on 378 instances took 103.37s
# [[60 13]
#  [10 45]]
# [ 2 of 3] accuracy on 128 test instances: 82.03%, speedup 0.52x (elapsed 4.26s)
# Train on 420 samples, validate on 129 samples
# Epoch 1/10
# 420/420 [==============================] - 16s - loss: 0.8307 - out_loss: 0.6906 - aux_out_loss: 0.7003 - out_acc: 0.5024 - aux_out_acc: 0.5643 - val_loss: 0.8301 - val_out_loss: 0.6929 - val_aux_out_loss: 0.6861 - val_out_acc: 0.6744 - val_aux_out_acc: 0.6279
# Epoch 2/10
# 420/420 [==============================] - 11s - loss: 0.8020 - out_loss: 0.6655 - aux_out_loss: 0.6823 - out_acc: 0.6452 - aux_out_acc: 0.5905 - val_loss: 0.8226 - val_out_loss: 0.6859 - val_aux_out_loss: 0.6837 - val_out_acc: 0.7054 - val_aux_out_acc: 0.6279
# Epoch 3/10
# 420/420 [==============================] - 11s - loss: 0.7784 - out_loss: 0.6462 - aux_out_loss: 0.6606 - out_acc: 0.6667 - aux_out_acc: 0.6238 - val_loss: 0.8184 - val_out_loss: 0.6819 - val_aux_out_loss: 0.6823 - val_out_acc: 0.6977 - val_aux_out_acc: 0.6279
# Epoch 4/10
# 420/420 [==============================] - 10s - loss: 0.7539 - out_loss: 0.6247 - aux_out_loss: 0.6461 - out_acc: 0.6905 - aux_out_acc: 0.6595 - val_loss: 0.8139 - val_out_loss: 0.6777 - val_aux_out_loss: 0.6812 - val_out_acc: 0.7364 - val_aux_out_acc: 0.6202
# Epoch 5/10
# 420/420 [==============================] - 11s - loss: 0.7215 - out_loss: 0.5963 - aux_out_loss: 0.6261 - out_acc: 0.7214 - aux_out_acc: 0.6786 - val_loss: 0.8110 - val_out_loss: 0.6748 - val_aux_out_loss: 0.6810 - val_out_acc: 0.6977 - val_aux_out_acc: 0.6202
# Epoch 6/10
# 420/420 [==============================] - 11s - loss: 0.6844 - out_loss: 0.5622 - aux_out_loss: 0.6109 - out_acc: 0.7738 - aux_out_acc: 0.6857 - val_loss: 0.8071 - val_out_loss: 0.6712 - val_aux_out_loss: 0.6797 - val_out_acc: 0.7132 - val_aux_out_acc: 0.6434
# Epoch 7/10
# 420/420 [==============================] - 11s - loss: 0.6469 - out_loss: 0.5297 - aux_out_loss: 0.5857 - out_acc: 0.7619 - aux_out_acc: 0.6976 - val_loss: 0.8037 - val_out_loss: 0.6681 - val_aux_out_loss: 0.6779 - val_out_acc: 0.7364 - val_aux_out_acc: 0.6512
# Epoch 8/10
# 420/420 [==============================] - 11s - loss: 0.6287 - out_loss: 0.5146 - aux_out_loss: 0.5707 - out_acc: 0.7714 - aux_out_acc: 0.7071 - val_loss: 0.7995 - val_out_loss: 0.6645 - val_aux_out_loss: 0.6755 - val_out_acc: 0.7442 - val_aux_out_acc: 0.6589
# Epoch 9/10
# 420/420 [==============================] - 11s - loss: 0.5972 - out_loss: 0.4872 - aux_out_loss: 0.5497 - out_acc: 0.7833 - aux_out_acc: 0.7071 - val_loss: 0.7975 - val_out_loss: 0.6626 - val_aux_out_loss: 0.6743 - val_out_acc: 0.7364 - val_aux_out_acc: 0.6667
# Epoch 10/10
# 420/420 [==============================] - 11s - loss: 0.5747 - out_loss: 0.4678 - aux_out_loss: 0.5347 - out_acc: 0.8024 - aux_out_acc: 0.7143 - val_loss: 0.7899 - val_out_loss: 0.6560 - val_aux_out_loss: 0.6696 - val_out_acc: 0.7442 - val_aux_out_acc: 0.6667
# [ 3 of 3] training on 420 instances took 119.05s
# [[57 20]
#  [ 7 47]]
# [ 3 of 3] accuracy on 131 test instances: 79.39%, speedup 0.48x (elapsed 4.56s)
#
# avg training time 113.68s, eval time 4.41s
# avg accuracy 76.34% (std: 6.28%), oracle 0.51x (std: 2.23%)
#
# num instances 680 (0 synthetic, 680 benchmarks)
# unique kernels 247
# vocab size 84
# pad val 84
# padded seq length 1000
# Train on 397 samples, validate on 138 samples
# Epoch 1/10
# 397/397 [==============================] - 17s - loss: 0.8288 - out_loss: 0.6914 - aux_out_loss: 0.6873 - out_acc: 0.5239 - aux_out_acc: 0.5466 - val_loss: 0.9833 - val_out_loss: 0.8455 - val_aux_out_loss: 0.6890 - val_out_acc: 0.3478 - val_aux_out_acc: 0.5870
# Epoch 2/10
# 397/397 [==============================] - 11s - loss: 0.7927 - out_loss: 0.6660 - aux_out_loss: 0.6335 - out_acc: 0.6171 - aux_out_acc: 0.6574 - val_loss: 0.9018 - val_out_loss: 0.7644 - val_aux_out_loss: 0.6869 - val_out_acc: 0.3478 - val_aux_out_acc: 0.7319
# Epoch 3/10
# 397/397 [==============================] - 11s - loss: 0.7592 - out_loss: 0.6411 - aux_out_loss: 0.5904 - out_acc: 0.6725 - aux_out_acc: 0.7179 - val_loss: 0.8743 - val_out_loss: 0.7372 - val_aux_out_loss: 0.6854 - val_out_acc: 0.4420 - val_aux_out_acc: 0.6522
# Epoch 4/10
# 397/397 [==============================] - 11s - loss: 0.7264 - out_loss: 0.6151 - aux_out_loss: 0.5564 - out_acc: 0.7280 - aux_out_acc: 0.7280 - val_loss: 0.8500 - val_out_loss: 0.7144 - val_aux_out_loss: 0.6782 - val_out_acc: 0.5362 - val_aux_out_acc: 0.7246
# Epoch 5/10
# 397/397 [==============================] - 11s - loss: 0.6779 - out_loss: 0.5736 - aux_out_loss: 0.5212 - out_acc: 0.7632 - aux_out_acc: 0.7657 - val_loss: 0.8248 - val_out_loss: 0.6920 - val_aux_out_loss: 0.6642 - val_out_acc: 0.5507 - val_aux_out_acc: 0.6957
# Epoch 6/10
# 397/397 [==============================] - 11s - loss: 0.6382 - out_loss: 0.5366 - aux_out_loss: 0.5082 - out_acc: 0.7733 - aux_out_acc: 0.7758 - val_loss: 0.8067 - val_out_loss: 0.6758 - val_aux_out_loss: 0.6549 - val_out_acc: 0.6377 - val_aux_out_acc: 0.7319
# Epoch 7/10
# 397/397 [==============================] - 11s - loss: 0.5986 - out_loss: 0.4997 - aux_out_loss: 0.4942 - out_acc: 0.7960 - aux_out_acc: 0.7884 - val_loss: 0.7852 - val_out_loss: 0.6563 - val_aux_out_loss: 0.6447 - val_out_acc: 0.6377 - val_aux_out_acc: 0.6449
# Epoch 8/10
# 397/397 [==============================] - 11s - loss: 0.5746 - out_loss: 0.4794 - aux_out_loss: 0.4760 - out_acc: 0.8111 - aux_out_acc: 0.8010 - val_loss: 0.7852 - val_out_loss: 0.6560 - val_aux_out_loss: 0.6459 - val_out_acc: 0.7174 - val_aux_out_acc: 0.7609
# Epoch 9/10
# 397/397 [==============================] - 11s - loss: 0.5466 - out_loss: 0.4543 - aux_out_loss: 0.4615 - out_acc: 0.8035 - aux_out_acc: 0.8010 - val_loss: 0.7690 - val_out_loss: 0.6420 - val_aux_out_loss: 0.6348 - val_out_acc: 0.7029 - val_aux_out_acc: 0.6667
# Epoch 10/10
# 397/397 [==============================] - 11s - loss: 0.5384 - out_loss: 0.4491 - aux_out_loss: 0.4462 - out_acc: 0.8111 - aux_out_acc: 0.8161 - val_loss: 0.7631 - val_out_loss: 0.6364 - val_aux_out_loss: 0.6336 - val_out_acc: 0.7246 - val_aux_out_acc: 0.6812
# [ 1 of 3] training on 397 instances took 122.65s
# saved model classification/models/model-0-204.h5
# [[28 28]
#  [10 79]]
# [ 1 of 3] accuracy on 145 test instances: 73.79%, speedup 0.63x (elapsed 4.73s)
# Train on 378 samples, validate on 174 samples
# Epoch 1/10
# 378/378 [==============================] - 15s - loss: 0.8099 - out_loss: 0.6740 - aux_out_loss: 0.6797 - out_acc: 0.5820 - aux_out_acc: 0.5899 - val_loss: 0.8722 - val_out_loss: 0.7339 - val_aux_out_loss: 0.6914 - val_out_acc: 0.3506 - val_aux_out_acc: 0.6034
# Epoch 2/10
# 378/378 [==============================] - 9s - loss: 0.7442 - out_loss: 0.6131 - aux_out_loss: 0.6557 - out_acc: 0.6587 - aux_out_acc: 0.6296 - val_loss: 0.8432 - val_out_loss: 0.7050 - val_aux_out_loss: 0.6908 - val_out_acc: 0.4310 - val_aux_out_acc: 0.5920
# Epoch 3/10
# 378/378 [==============================] - 9s - loss: 0.6877 - out_loss: 0.5602 - aux_out_loss: 0.6375 - out_acc: 0.7196 - aux_out_acc: 0.6799 - val_loss: 0.8311 - val_out_loss: 0.6935 - val_aux_out_loss: 0.6882 - val_out_acc: 0.5517 - val_aux_out_acc: 0.6609
# Epoch 4/10
# 378/378 [==============================] - 9s - loss: 0.6337 - out_loss: 0.5118 - aux_out_loss: 0.6097 - out_acc: 0.7487 - aux_out_acc: 0.7249 - val_loss: 0.8239 - val_out_loss: 0.6866 - val_aux_out_loss: 0.6863 - val_out_acc: 0.5977 - val_aux_out_acc: 0.6954
# Epoch 5/10
# 378/378 [==============================] - 9s - loss: 0.5889 - out_loss: 0.4730 - aux_out_loss: 0.5795 - out_acc: 0.7725 - aux_out_acc: 0.7434 - val_loss: 0.8215 - val_out_loss: 0.6842 - val_aux_out_loss: 0.6865 - val_out_acc: 0.5517 - val_aux_out_acc: 0.6552
# Epoch 6/10
# 378/378 [==============================] - 9s - loss: 0.5682 - out_loss: 0.4576 - aux_out_loss: 0.5530 - out_acc: 0.7804 - aux_out_acc: 0.7593 - val_loss: 0.8149 - val_out_loss: 0.6786 - val_aux_out_loss: 0.6817 - val_out_acc: 0.6264 - val_aux_out_acc: 0.6724
# Epoch 7/10
# 378/378 [==============================] - 9s - loss: 0.5396 - out_loss: 0.4346 - aux_out_loss: 0.5249 - out_acc: 0.7857 - aux_out_acc: 0.7857 - val_loss: 0.8094 - val_out_loss: 0.6738 - val_aux_out_loss: 0.6785 - val_out_acc: 0.6667 - val_aux_out_acc: 0.7586
# Epoch 8/10
# 378/378 [==============================] - 9s - loss: 0.5249 - out_loss: 0.4242 - aux_out_loss: 0.5035 - out_acc: 0.7910 - aux_out_acc: 0.7963 - val_loss: 0.8044 - val_out_loss: 0.6694 - val_aux_out_loss: 0.6748 - val_out_acc: 0.6954 - val_aux_out_acc: 0.7356
# Epoch 9/10
# 378/378 [==============================] - 9s - loss: 0.5153 - out_loss: 0.4177 - aux_out_loss: 0.4878 - out_acc: 0.7857 - aux_out_acc: 0.7910 - val_loss: 0.8003 - val_out_loss: 0.6660 - val_aux_out_loss: 0.6713 - val_out_acc: 0.7184 - val_aux_out_acc: 0.7529
# Epoch 10/10
# 378/378 [==============================] - 9s - loss: 0.5025 - out_loss: 0.4077 - aux_out_loss: 0.4740 - out_acc: 0.8042 - aux_out_acc: 0.7989 - val_loss: 0.7929 - val_out_loss: 0.6597 - val_aux_out_loss: 0.6663 - val_out_acc: 0.7471 - val_aux_out_acc: 0.7414
# [ 2 of 3] training on 378 instances took 104.43s
# saved model classification/models/model-1-205.h5
# [[46 14]
#  [24 44]]
# [ 2 of 3] accuracy on 128 test instances: 70.31%, speedup 0.53x (elapsed 4.46s)
# Train on 420 samples, validate on 129 samples
# Epoch 1/10
# 420/420 [==============================] - 17s - loss: 0.8058 - out_loss: 0.6595 - aux_out_loss: 0.7316 - out_acc: 0.5643 - aux_out_acc: 0.4452 - val_loss: 0.8487 - val_out_loss: 0.7099 - val_aux_out_loss: 0.6944 - val_out_acc: 0.5736 - val_aux_out_acc: 0.5194
# Epoch 2/10
# 420/420 [==============================] - 11s - loss: 0.7622 - out_loss: 0.6254 - aux_out_loss: 0.6840 - out_acc: 0.6048 - aux_out_acc: 0.5524 - val_loss: 0.8341 - val_out_loss: 0.6956 - val_aux_out_loss: 0.6927 - val_out_acc: 0.5659 - val_aux_out_acc: 0.5271
# Epoch 3/10
# 420/420 [==============================] - 11s - loss: 0.7379 - out_loss: 0.6068 - aux_out_loss: 0.6558 - out_acc: 0.6095 - aux_out_acc: 0.6238 - val_loss: 0.8294 - val_out_loss: 0.6912 - val_aux_out_loss: 0.6909 - val_out_acc: 0.5581 - val_aux_out_acc: 0.5116
# Epoch 4/10
# 420/420 [==============================] - 11s - loss: 0.7134 - out_loss: 0.5884 - aux_out_loss: 0.6253 - out_acc: 0.6381 - aux_out_acc: 0.6571 - val_loss: 0.8243 - val_out_loss: 0.6868 - val_aux_out_loss: 0.6877 - val_out_acc: 0.5426 - val_aux_out_acc: 0.5504
# Epoch 5/10
# 420/420 [==============================] - 11s - loss: 0.6909 - out_loss: 0.5726 - aux_out_loss: 0.5911 - out_acc: 0.6667 - aux_out_acc: 0.7024 - val_loss: 0.8192 - val_out_loss: 0.6825 - val_aux_out_loss: 0.6835 - val_out_acc: 0.5349 - val_aux_out_acc: 0.5271
# Epoch 6/10
# 420/420 [==============================] - 11s - loss: 0.6753 - out_loss: 0.5612 - aux_out_loss: 0.5703 - out_acc: 0.6833 - aux_out_acc: 0.7190 - val_loss: 0.8155 - val_out_loss: 0.6792 - val_aux_out_loss: 0.6813 - val_out_acc: 0.5194 - val_aux_out_acc: 0.5271
# Epoch 7/10
# 420/420 [==============================] - 11s - loss: 0.6526 - out_loss: 0.5436 - aux_out_loss: 0.5451 - out_acc: 0.7238 - aux_out_acc: 0.7310 - val_loss: 0.8088 - val_out_loss: 0.6735 - val_aux_out_loss: 0.6764 - val_out_acc: 0.5349 - val_aux_out_acc: 0.5426
# Epoch 8/10
# 420/420 [==============================] - 11s - loss: 0.6369 - out_loss: 0.5323 - aux_out_loss: 0.5227 - out_acc: 0.7500 - aux_out_acc: 0.7857 - val_loss: 0.8031 - val_out_loss: 0.6686 - val_aux_out_loss: 0.6728 - val_out_acc: 0.6047 - val_aux_out_acc: 0.5969
# Epoch 9/10
# 420/420 [==============================] - 11s - loss: 0.6128 - out_loss: 0.5103 - aux_out_loss: 0.5128 - out_acc: 0.7810 - aux_out_acc: 0.7786 - val_loss: 0.7952 - val_out_loss: 0.6617 - val_aux_out_loss: 0.6680 - val_out_acc: 0.6667 - val_aux_out_acc: 0.5969
# Epoch 10/10
# 420/420 [==============================] - 11s - loss: 0.5799 - out_loss: 0.4828 - aux_out_loss: 0.4856 - out_acc: 0.8095 - aux_out_acc: 0.8048 - val_loss: 0.7862 - val_out_loss: 0.6535 - val_aux_out_loss: 0.6636 - val_out_acc: 0.6667 - val_aux_out_acc: 0.5969
# [ 3 of 3] training on 420 instances took 120.54s
# saved model classification/models/model-2-206.h5
# [[27 31]
#  [ 6 67]]
# [ 3 of 3] accuracy on 131 test instances: 71.76%, speedup 0.64x (elapsed 4.79s)
#
# avg training time 115.88s, eval time 4.66s
# avg accuracy 71.95% (std: 1.43%), oracle 0.60x (std: 5.11%)

# %%
# Multi-input model (10 epoch, 32 embedding vector)
batch_size = 64

def create_model(*args, seed=None, **kwargs):
    np.random.seed(seed)
    embedding_vector_length = 32

    dyn_inputs = Input(shape=(2,), name="dynprop_in")
    left = BatchNormalization(name="dynprop_norm")(dyn_inputs)

    seq_inputs = Input(shape=(seq_length,), dtype="int32", name="seq_in")
    right = Embedding(output_dim=embedding_vector_length, input_dim=vocab_size, input_length=seq_length)(seq_inputs)
    right = LSTM(16, consume_less="mem")(right)
    right = BatchNormalization(input_shape=(32,), name="lstm_norm")(right)

    aux_out = Dense(2, activation="sigmoid", name="aux_out")(right)

    x = merge([left, right], mode="concat")
    x = Dense(18, activation="relu")(x)
    out = Dense(2, activation="sigmoid", name="out")(x)

    model = Model(input=[dyn_inputs, seq_inputs], output=[out, aux_out])
    model.compile(optimizer="adam",
                  loss={"out": "categorical_crossentropy", "aux_out": "categorical_crossentropy"},
                  loss_weights={"out": 1., "aux_out": .2},
                  metrics=['accuracy'])
    return model

def train_fn(model, train, validation, seed, *args, **kwargs):
    np.random.seed(seed)
    model.fit({"dynprop_in": train["x_2"], "seq_in": train["x_seq"]},
          {"out": train["y_2"], "aux_out": train["y_2"]},
          nb_epoch=10,
          batch_size=batch_size,
          validation_data=({"dynprop_in": validation["x_2"], "seq_in": validation["x_seq"]},
                           {"out": validation["y_2"], "aux_out": validation["y_2"]}),
          verbose=1,
          shuffle=True
    )
    return {}

def save_fn(model, seed, i, *args, **kwargs):
    outpath = "classification/models/model-{i}-{seed}.h5".format(**vars())
    model.save(outpath)
    print("saved model", outpath)

def test_fn(model, test, seed, *args, **kwargs):
    np.random.seed(seed)
    predictions = np.array(model.predict({"dynprop_in": test["x_2"], "seq_in": test["x_seq"]},
                                         batch_size=batch_size, verbose=0))
    clipped = [np.argmax(x) for x in predictions[0]]
    return clipped

dataframe, seq_length, atomizer = load_dataframe(
    platform="amd",
    source="B",
    max_seq_len=1024, 
    atomizer=GreedyAtomizer
)
r = evaluate(dataframe, seq_length, create_model, train_fn, test_fn, split=(.6, .2, .2), seed=204, n=3)
print()
dataframe, seq_length, atomizer = load_dataframe(
    platform="nvidia",
    source="B",
    max_seq_len=1024, 
    atomizer=GreedyAtomizer
)
r = evaluate(dataframe, seq_length, create_model, train_fn, test_fn,
             split=(.6, .2, .2), save_fn=save_fn, seed=204, n=3)
# Out:
# num instances 680 (0 synthetic, 680 benchmarks)
# unique kernels 247
# vocab size 84
# pad val 84
# padded seq length 1000
# Train on 397 samples, validate on 138 samples
# Epoch 1/10
# 397/397 [==============================] - 17s - loss: 0.8101 - out_loss: 0.6751 - aux_out_loss: 0.6752 - out_acc: 0.5668 - aux_out_acc: 0.5743 - val_loss: 0.9976 - val_out_loss: 0.8594 - val_aux_out_loss: 0.6909 - val_out_acc: 0.4855 - val_aux_out_acc: 0.5652
# Epoch 2/10
# 397/397 [==============================] - 11s - loss: 0.7742 - out_loss: 0.6435 - aux_out_loss: 0.6531 - out_acc: 0.6071 - aux_out_acc: 0.5718 - val_loss: 0.9158 - val_out_loss: 0.7779 - val_aux_out_loss: 0.6897 - val_out_acc: 0.4855 - val_aux_out_acc: 0.5435
# Epoch 3/10
# 397/397 [==============================] - 10s - loss: 0.7496 - out_loss: 0.6227 - aux_out_loss: 0.6346 - out_acc: 0.6322 - aux_out_acc: 0.5793 - val_loss: 0.8858 - val_out_loss: 0.7479 - val_aux_out_loss: 0.6896 - val_out_acc: 0.4855 - val_aux_out_acc: 0.5580
# Epoch 4/10
# 397/397 [==============================] - 10s - loss: 0.7387 - out_loss: 0.6108 - aux_out_loss: 0.6392 - out_acc: 0.6398 - aux_out_acc: 0.5869 - val_loss: 0.8660 - val_out_loss: 0.7281 - val_aux_out_loss: 0.6893 - val_out_acc: 0.4855 - val_aux_out_acc: 0.5435
# Epoch 5/10
# 397/397 [==============================] - 10s - loss: 0.7196 - out_loss: 0.5974 - aux_out_loss: 0.6111 - out_acc: 0.6574 - aux_out_acc: 0.6474 - val_loss: 0.8532 - val_out_loss: 0.7152 - val_aux_out_loss: 0.6898 - val_out_acc: 0.4855 - val_aux_out_acc: 0.5507
# Epoch 6/10
# 397/397 [==============================] - 11s - loss: 0.7006 - out_loss: 0.5818 - aux_out_loss: 0.5941 - out_acc: 0.6574 - aux_out_acc: 0.6700 - val_loss: 0.8398 - val_out_loss: 0.7021 - val_aux_out_loss: 0.6888 - val_out_acc: 0.4855 - val_aux_out_acc: 0.5797
# Epoch 7/10
# 397/397 [==============================] - 10s - loss: 0.6849 - out_loss: 0.5687 - aux_out_loss: 0.5809 - out_acc: 0.6826 - aux_out_acc: 0.6373 - val_loss: 0.8322 - val_out_loss: 0.6946 - val_aux_out_loss: 0.6881 - val_out_acc: 0.5725 - val_aux_out_acc: 0.5580
# Epoch 8/10
# 397/397 [==============================] - 10s - loss: 0.6541 - out_loss: 0.5433 - aux_out_loss: 0.5542 - out_acc: 0.7204 - aux_out_acc: 0.6751 - val_loss: 0.8233 - val_out_loss: 0.6864 - val_aux_out_loss: 0.6844 - val_out_acc: 0.6739 - val_aux_out_acc: 0.5870
# Epoch 9/10
# 397/397 [==============================] - 11s - loss: 0.6287 - out_loss: 0.5208 - aux_out_loss: 0.5398 - out_acc: 0.7431 - aux_out_acc: 0.6801 - val_loss: 0.8115 - val_out_loss: 0.6749 - val_aux_out_loss: 0.6831 - val_out_acc: 0.6594 - val_aux_out_acc: 0.5725
# Epoch 10/10
# 397/397 [==============================] - 11s - loss: 0.6099 - out_loss: 0.5040 - aux_out_loss: 0.5294 - out_acc: 0.7582 - aux_out_acc: 0.6751 - val_loss: 0.8018 - val_out_loss: 0.6661 - val_aux_out_loss: 0.6786 - val_out_acc: 0.6594 - val_aux_out_acc: 0.6014
# [ 1 of 3] training on 397 instances took 117.95s
# [[74  5]
#  [45 21]]
# [ 1 of 3] accuracy on 145 test instances: 65.52%, speedup 0.55x (elapsed 4.88s)
# Train on 378 samples, validate on 174 samples
# Epoch 1/10
# 378/378 [==============================] - 15s - loss: 0.8184 - out_loss: 0.6813 - aux_out_loss: 0.6855 - out_acc: 0.5317 - aux_out_acc: 0.5529 - val_loss: 0.8429 - val_out_loss: 0.7043 - val_aux_out_loss: 0.6932 - val_out_acc: 0.6264 - val_aux_out_acc: 0.4713
# Epoch 2/10
# 378/378 [==============================] - 9s - loss: 0.7844 - out_loss: 0.6486 - aux_out_loss: 0.6791 - out_acc: 0.6164 - aux_out_acc: 0.6058 - val_loss: 0.8260 - val_out_loss: 0.6878 - val_aux_out_loss: 0.6908 - val_out_acc: 0.6437 - val_aux_out_acc: 0.6437
# Epoch 3/10
# 378/378 [==============================] - 9s - loss: 0.7631 - out_loss: 0.6280 - aux_out_loss: 0.6758 - out_acc: 0.6587 - aux_out_acc: 0.6190 - val_loss: 0.8138 - val_out_loss: 0.6762 - val_aux_out_loss: 0.6877 - val_out_acc: 0.6552 - val_aux_out_acc: 0.6264
# Epoch 4/10
# 378/378 [==============================] - 9s - loss: 0.7432 - out_loss: 0.6092 - aux_out_loss: 0.6697 - out_acc: 0.6693 - aux_out_acc: 0.6058 - val_loss: 0.7996 - val_out_loss: 0.6628 - val_aux_out_loss: 0.6837 - val_out_acc: 0.6667 - val_aux_out_acc: 0.6264
# Epoch 5/10
# 378/378 [==============================] - 9s - loss: 0.7078 - out_loss: 0.5761 - aux_out_loss: 0.6586 - out_acc: 0.7196 - aux_out_acc: 0.6693 - val_loss: 0.8001 - val_out_loss: 0.6635 - val_aux_out_loss: 0.6830 - val_out_acc: 0.6782 - val_aux_out_acc: 0.6264
# Epoch 6/10
# 378/378 [==============================] - 9s - loss: 0.6799 - out_loss: 0.5509 - aux_out_loss: 0.6452 - out_acc: 0.7302 - aux_out_acc: 0.6534 - val_loss: 0.7860 - val_out_loss: 0.6503 - val_aux_out_loss: 0.6787 - val_out_acc: 0.7011 - val_aux_out_acc: 0.6264
# Epoch 7/10
# 378/378 [==============================] - 9s - loss: 0.6618 - out_loss: 0.5354 - aux_out_loss: 0.6323 - out_acc: 0.7275 - aux_out_acc: 0.6931 - val_loss: 0.7873 - val_out_loss: 0.6517 - val_aux_out_loss: 0.6777 - val_out_acc: 0.7471 - val_aux_out_acc: 0.6264
# Epoch 8/10
# 378/378 [==============================] - 9s - loss: 0.6526 - out_loss: 0.5285 - aux_out_loss: 0.6206 - out_acc: 0.7460 - aux_out_acc: 0.6561 - val_loss: 0.7819 - val_out_loss: 0.6465 - val_aux_out_loss: 0.6772 - val_out_acc: 0.7356 - val_aux_out_acc: 0.6264
# Epoch 9/10
# 378/378 [==============================] - 9s - loss: 0.6405 - out_loss: 0.5165 - aux_out_loss: 0.6201 - out_acc: 0.7540 - aux_out_acc: 0.6852 - val_loss: 0.7555 - val_out_loss: 0.6213 - val_aux_out_loss: 0.6711 - val_out_acc: 0.7126 - val_aux_out_acc: 0.6264
# Epoch 10/10
# 378/378 [==============================] - 9s - loss: 0.6085 - out_loss: 0.4872 - aux_out_loss: 0.6062 - out_acc: 0.7778 - aux_out_acc: 0.7143 - val_loss: 0.7531 - val_out_loss: 0.6191 - val_aux_out_loss: 0.6697 - val_out_acc: 0.7356 - val_aux_out_acc: 0.6264
# [ 2 of 3] training on 378 instances took 105.58s
# [[65  8]
#  [20 35]]
# [ 2 of 3] accuracy on 128 test instances: 78.12%, speedup 0.51x (elapsed 4.57s)
# Train on 420 samples, validate on 129 samples
# Epoch 1/10
# 420/420 [==============================] - 17s - loss: 0.8295 - out_loss: 0.6891 - aux_out_loss: 0.7020 - out_acc: 0.4976 - aux_out_acc: 0.5452 - val_loss: 0.8284 - val_out_loss: 0.6904 - val_aux_out_loss: 0.6900 - val_out_acc: 0.6589 - val_aux_out_acc: 0.6279
# Epoch 2/10
# 420/420 [==============================] - 11s - loss: 0.8068 - out_loss: 0.6685 - aux_out_loss: 0.6912 - out_acc: 0.6595 - aux_out_acc: 0.5595 - val_loss: 0.8221 - val_out_loss: 0.6847 - val_aux_out_loss: 0.6869 - val_out_acc: 0.6512 - val_aux_out_acc: 0.6279
# Epoch 3/10
# 420/420 [==============================] - 11s - loss: 0.7861 - out_loss: 0.6504 - aux_out_loss: 0.6781 - out_acc: 0.6905 - aux_out_acc: 0.5905 - val_loss: 0.8187 - val_out_loss: 0.6818 - val_aux_out_loss: 0.6843 - val_out_acc: 0.6744 - val_aux_out_acc: 0.6279
# Epoch 4/10
# 420/420 [==============================] - 11s - loss: 0.7573 - out_loss: 0.6252 - aux_out_loss: 0.6609 - out_acc: 0.7786 - aux_out_acc: 0.6476 - val_loss: 0.8150 - val_out_loss: 0.6785 - val_aux_out_loss: 0.6825 - val_out_acc: 0.7132 - val_aux_out_acc: 0.6279
# Epoch 5/10
# 420/420 [==============================] - 11s - loss: 0.7248 - out_loss: 0.5962 - aux_out_loss: 0.6428 - out_acc: 0.7762 - aux_out_acc: 0.6571 - val_loss: 0.8079 - val_out_loss: 0.6721 - val_aux_out_loss: 0.6791 - val_out_acc: 0.7054 - val_aux_out_acc: 0.6279
# Epoch 6/10
# 420/420 [==============================] - 11s - loss: 0.7032 - out_loss: 0.5774 - aux_out_loss: 0.6290 - out_acc: 0.7357 - aux_out_acc: 0.7286 - val_loss: 0.8047 - val_out_loss: 0.6690 - val_aux_out_loss: 0.6782 - val_out_acc: 0.7132 - val_aux_out_acc: 0.6279
# Epoch 7/10
# 420/420 [==============================] - 11s - loss: 0.6707 - out_loss: 0.5486 - aux_out_loss: 0.6101 - out_acc: 0.7405 - aux_out_acc: 0.7238 - val_loss: 0.7999 - val_out_loss: 0.6650 - val_aux_out_loss: 0.6742 - val_out_acc: 0.7054 - val_aux_out_acc: 0.6279
# Epoch 8/10
# 420/420 [==============================] - 11s - loss: 0.6467 - out_loss: 0.5260 - aux_out_loss: 0.6035 - out_acc: 0.7738 - aux_out_acc: 0.7262 - val_loss: 0.7988 - val_out_loss: 0.6635 - val_aux_out_loss: 0.6764 - val_out_acc: 0.6977 - val_aux_out_acc: 0.6279
# Epoch 9/10
# 420/420 [==============================] - 11s - loss: 0.6135 - out_loss: 0.4975 - aux_out_loss: 0.5797 - out_acc: 0.8024 - aux_out_acc: 0.7143 - val_loss: 0.7942 - val_out_loss: 0.6596 - val_aux_out_loss: 0.6734 - val_out_acc: 0.7054 - val_aux_out_acc: 0.6667
# Epoch 10/10
# 420/420 [==============================] - 11s - loss: 0.5877 - out_loss: 0.4750 - aux_out_loss: 0.5637 - out_acc: 0.7976 - aux_out_acc: 0.7286 - val_loss: 0.7963 - val_out_loss: 0.6613 - val_aux_out_loss: 0.6745 - val_out_acc: 0.6977 - val_aux_out_acc: 0.6589
# [ 3 of 3] training on 420 instances took 123.46s
# [[60 17]
#  [12 42]]
# [ 3 of 3] accuracy on 131 test instances: 77.86%, speedup 0.53x (elapsed 4.92s)
#
# avg training time 115.67s, eval time 4.79s
# avg accuracy 73.83% (std: 5.88%), oracle 0.53x (std: 1.38%)
#
# num instances 680 (0 synthetic, 680 benchmarks)
# unique kernels 247
# vocab size 84
# pad val 84
# padded seq length 1000
# Train on 397 samples, validate on 138 samples
# Epoch 1/10
# 397/397 [==============================] - 17s - loss: 0.8416 - out_loss: 0.7007 - aux_out_loss: 0.7047 - out_acc: 0.4484 - aux_out_acc: 0.4962 - val_loss: 0.9925 - val_out_loss: 0.8537 - val_aux_out_loss: 0.6938 - val_out_acc: 0.3696 - val_aux_out_acc: 0.4348
# Epoch 2/10
# 397/397 [==============================] - 11s - loss: 0.8079 - out_loss: 0.6790 - aux_out_loss: 0.6448 - out_acc: 0.5466 - aux_out_acc: 0.6297 - val_loss: 0.9106 - val_out_loss: 0.7729 - val_aux_out_loss: 0.6885 - val_out_acc: 0.3406 - val_aux_out_acc: 0.6377
# Epoch 3/10
# 397/397 [==============================] - 11s - loss: 0.7767 - out_loss: 0.6566 - aux_out_loss: 0.6008 - out_acc: 0.5718 - aux_out_acc: 0.6826 - val_loss: 0.8780 - val_out_loss: 0.7412 - val_aux_out_loss: 0.6836 - val_out_acc: 0.3768 - val_aux_out_acc: 0.6377
# Epoch 4/10
# 397/397 [==============================] - 11s - loss: 0.7587 - out_loss: 0.6382 - aux_out_loss: 0.6027 - out_acc: 0.6524 - aux_out_acc: 0.6927 - val_loss: 0.8523 - val_out_loss: 0.7172 - val_aux_out_loss: 0.6755 - val_out_acc: 0.4203 - val_aux_out_acc: 0.6667
# Epoch 5/10
# 397/397 [==============================] - 11s - loss: 0.7193 - out_loss: 0.6110 - aux_out_loss: 0.5413 - out_acc: 0.7003 - aux_out_acc: 0.7179 - val_loss: 0.8370 - val_out_loss: 0.7030 - val_aux_out_loss: 0.6700 - val_out_acc: 0.5217 - val_aux_out_acc: 0.6812
# Epoch 6/10
# 397/397 [==============================] - 11s - loss: 0.6867 - out_loss: 0.5807 - aux_out_loss: 0.5302 - out_acc: 0.7305 - aux_out_acc: 0.7380 - val_loss: 0.8220 - val_out_loss: 0.6902 - val_aux_out_loss: 0.6591 - val_out_acc: 0.5725 - val_aux_out_acc: 0.7319
# Epoch 7/10
# 397/397 [==============================] - 11s - loss: 0.6412 - out_loss: 0.5412 - aux_out_loss: 0.5002 - out_acc: 0.7607 - aux_out_acc: 0.7758 - val_loss: 0.8058 - val_out_loss: 0.6756 - val_aux_out_loss: 0.6511 - val_out_acc: 0.5507 - val_aux_out_acc: 0.6232
# Epoch 8/10
# 397/397 [==============================] - 11s - loss: 0.6027 - out_loss: 0.5058 - aux_out_loss: 0.4845 - out_acc: 0.8060 - aux_out_acc: 0.8010 - val_loss: 0.7885 - val_out_loss: 0.6608 - val_aux_out_loss: 0.6387 - val_out_acc: 0.6159 - val_aux_out_acc: 0.6739
# Epoch 9/10
# 397/397 [==============================] - 11s - loss: 0.5606 - out_loss: 0.4706 - aux_out_loss: 0.4502 - out_acc: 0.8111 - aux_out_acc: 0.8086 - val_loss: 0.7803 - val_out_loss: 0.6529 - val_aux_out_loss: 0.6371 - val_out_acc: 0.6522 - val_aux_out_acc: 0.6232
# Epoch 10/10
# 397/397 [==============================] - 11s - loss: 0.5404 - out_loss: 0.4524 - aux_out_loss: 0.4399 - out_acc: 0.8186 - aux_out_acc: 0.8136 - val_loss: 0.7545 - val_out_loss: 0.6312 - val_aux_out_loss: 0.6163 - val_out_acc: 0.6739 - val_aux_out_acc: 0.6667
# [ 1 of 3] training on 397 instances took 122.54s
# saved model classification/models/model-0-204.h5
# [[17 39]
#  [ 5 84]]
# [ 1 of 3] accuracy on 145 test instances: 69.66%, speedup 0.68x (elapsed 4.91s)
# Train on 378 samples, validate on 174 samples
# Epoch 1/10
# 378/378 [==============================] - 16s - loss: 0.8435 - out_loss: 0.7038 - aux_out_loss: 0.6985 - out_acc: 0.4974 - aux_out_acc: 0.5079 - val_loss: 0.8725 - val_out_loss: 0.7344 - val_aux_out_loss: 0.6904 - val_out_acc: 0.3448 - val_aux_out_acc: 0.6207
# Epoch 2/10
# 378/378 [==============================] - 9s - loss: 0.7990 - out_loss: 0.6626 - aux_out_loss: 0.6820 - out_acc: 0.5899 - aux_out_acc: 0.5767 - val_loss: 0.8452 - val_out_loss: 0.7073 - val_aux_out_loss: 0.6893 - val_out_acc: 0.4943 - val_aux_out_acc: 0.6207
# Epoch 3/10
# 378/378 [==============================] - 9s - loss: 0.7659 - out_loss: 0.6319 - aux_out_loss: 0.6701 - out_acc: 0.6217 - aux_out_acc: 0.6190 - val_loss: 0.8343 - val_out_loss: 0.6967 - val_aux_out_loss: 0.6882 - val_out_acc: 0.5575 - val_aux_out_acc: 0.6207
# Epoch 4/10
# 378/378 [==============================] - 9s - loss: 0.7174 - out_loss: 0.5875 - aux_out_loss: 0.6496 - out_acc: 0.6799 - aux_out_acc: 0.6614 - val_loss: 0.8265 - val_out_loss: 0.6891 - val_aux_out_loss: 0.6869 - val_out_acc: 0.6034 - val_aux_out_acc: 0.6494
# Epoch 5/10
# 378/378 [==============================] - 9s - loss: 0.6579 - out_loss: 0.5325 - aux_out_loss: 0.6268 - out_acc: 0.7222 - aux_out_acc: 0.7196 - val_loss: 0.8216 - val_out_loss: 0.6843 - val_aux_out_loss: 0.6866 - val_out_acc: 0.5805 - val_aux_out_acc: 0.7356
# Epoch 6/10
# 378/378 [==============================] - 9s - loss: 0.6373 - out_loss: 0.5163 - aux_out_loss: 0.6052 - out_acc: 0.7354 - aux_out_acc: 0.7407 - val_loss: 0.8127 - val_out_loss: 0.6764 - val_aux_out_loss: 0.6815 - val_out_acc: 0.6782 - val_aux_out_acc: 0.7184
# Epoch 7/10
# 378/378 [==============================] - 9s - loss: 0.5993 - out_loss: 0.4847 - aux_out_loss: 0.5731 - out_acc: 0.7751 - aux_out_acc: 0.7751 - val_loss: 0.8108 - val_out_loss: 0.6748 - val_aux_out_loss: 0.6798 - val_out_acc: 0.6954 - val_aux_out_acc: 0.6839
# Epoch 8/10
# 378/378 [==============================] - 9s - loss: 0.5714 - out_loss: 0.4616 - aux_out_loss: 0.5491 - out_acc: 0.7831 - aux_out_acc: 0.7884 - val_loss: 0.7990 - val_out_loss: 0.6643 - val_aux_out_loss: 0.6735 - val_out_acc: 0.7471 - val_aux_out_acc: 0.6724
# Epoch 9/10
# 378/378 [==============================] - 9s - loss: 0.5634 - out_loss: 0.4576 - aux_out_loss: 0.5291 - out_acc: 0.7646 - aux_out_acc: 0.7751 - val_loss: 0.7987 - val_out_loss: 0.6642 - val_aux_out_loss: 0.6723 - val_out_acc: 0.6954 - val_aux_out_acc: 0.7184
# Epoch 10/10
# 378/378 [==============================] - 9s - loss: 0.5402 - out_loss: 0.4374 - aux_out_loss: 0.5139 - out_acc: 0.7804 - aux_out_acc: 0.7804 - val_loss: 0.7994 - val_out_loss: 0.6651 - val_aux_out_loss: 0.6718 - val_out_acc: 0.6954 - val_aux_out_acc: 0.7241
# [ 2 of 3] training on 378 instances took 104.95s
# saved model classification/models/model-1-205.h5
# [[40 20]
#  [20 48]]
# [ 2 of 3] accuracy on 128 test instances: 68.75%, speedup 0.53x (elapsed 4.94s)
# Train on 420 samples, validate on 129 samples
# Epoch 1/10
# 420/420 [==============================] - 17s - loss: 0.8164 - out_loss: 0.6746 - aux_out_loss: 0.7089 - out_acc: 0.5619 - aux_out_acc: 0.4667 - val_loss: 0.8517 - val_out_loss: 0.7128 - val_aux_out_loss: 0.6941 - val_out_acc: 0.5581 - val_aux_out_acc: 0.4496
# Epoch 2/10
# 420/420 [==============================] - 10s - loss: 0.7657 - out_loss: 0.6272 - aux_out_loss: 0.6927 - out_acc: 0.5976 - aux_out_acc: 0.5429 - val_loss: 0.8371 - val_out_loss: 0.6985 - val_aux_out_loss: 0.6930 - val_out_acc: 0.5969 - val_aux_out_acc: 0.4729
# Epoch 3/10
# 420/420 [==============================] - 10s - loss: 0.7313 - out_loss: 0.5976 - aux_out_loss: 0.6689 - out_acc: 0.6548 - aux_out_acc: 0.6048 - val_loss: 0.8313 - val_out_loss: 0.6931 - val_aux_out_loss: 0.6910 - val_out_acc: 0.5194 - val_aux_out_acc: 0.5194
# Epoch 4/10
# 420/420 [==============================] - 11s - loss: 0.7032 - out_loss: 0.5763 - aux_out_loss: 0.6344 - out_acc: 0.6619 - aux_out_acc: 0.6310 - val_loss: 0.8266 - val_out_loss: 0.6889 - val_aux_out_loss: 0.6883 - val_out_acc: 0.5271 - val_aux_out_acc: 0.5659
# Epoch 5/10
# 420/420 [==============================] - 11s - loss: 0.6798 - out_loss: 0.5586 - aux_out_loss: 0.6061 - out_acc: 0.6548 - aux_out_acc: 0.6762 - val_loss: 0.8231 - val_out_loss: 0.6859 - val_aux_out_loss: 0.6858 - val_out_acc: 0.5581 - val_aux_out_acc: 0.5659
# Epoch 6/10
# 420/420 [==============================] - 11s - loss: 0.6644 - out_loss: 0.5469 - aux_out_loss: 0.5874 - out_acc: 0.6714 - aux_out_acc: 0.6810 - val_loss: 0.8196 - val_out_loss: 0.6829 - val_aux_out_loss: 0.6837 - val_out_acc: 0.5736 - val_aux_out_acc: 0.5349
# Epoch 7/10
# 420/420 [==============================] - 11s - loss: 0.6427 - out_loss: 0.5313 - aux_out_loss: 0.5567 - out_acc: 0.7000 - aux_out_acc: 0.7405 - val_loss: 0.8122 - val_out_loss: 0.6764 - val_aux_out_loss: 0.6790 - val_out_acc: 0.5659 - val_aux_out_acc: 0.5426
# Epoch 8/10
# 420/420 [==============================] - 10s - loss: 0.6247 - out_loss: 0.5177 - aux_out_loss: 0.5349 - out_acc: 0.7000 - aux_out_acc: 0.7524 - val_loss: 0.8060 - val_out_loss: 0.6709 - val_aux_out_loss: 0.6754 - val_out_acc: 0.5426 - val_aux_out_acc: 0.5504
# Epoch 9/10
# 420/420 [==============================] - 10s - loss: 0.5987 - out_loss: 0.4953 - aux_out_loss: 0.5168 - out_acc: 0.7524 - aux_out_acc: 0.7619 - val_loss: 0.7987 - val_out_loss: 0.6644 - val_aux_out_loss: 0.6716 - val_out_acc: 0.5814 - val_aux_out_acc: 0.5504
# Epoch 10/10
# 420/420 [==============================] - 10s - loss: 0.5747 - out_loss: 0.4740 - aux_out_loss: 0.5034 - out_acc: 0.7810 - aux_out_acc: 0.7833 - val_loss: 0.7838 - val_out_loss: 0.6514 - val_aux_out_loss: 0.6617 - val_out_acc: 0.6667 - val_aux_out_acc: 0.5814
# [ 3 of 3] training on 420 instances took 118.42s
# saved model classification/models/model-2-206.h5
# [[19 39]
#  [ 9 64]]
# [ 3 of 3] accuracy on 131 test instances: 63.36%, speedup 0.66x (elapsed 5.14s)
#
# avg training time 115.30s, eval time 5.00s
# avg accuracy 67.25% (std: 2.78%), oracle 0.62x (std: 6.85%)

# %%
# Multi-input model (50 epoch)
# Multi-input model (10 epoch, 32 embedding vector)
batch_size = 64

def create_model(*args, seed=None, **kwargs):
    np.random.seed(seed)
    embedding_vector_length = 32

    dyn_inputs = Input(shape=(2,), name="data_in")
    left = BatchNormalization(name="dynprop_norm")(dyn_inputs)

    seq_inputs = Input(shape=(seq_length,), dtype="int32", name="code_in")
    right = Embedding(output_dim=embedding_vector_length, input_dim=vocab_size, input_length=seq_length)(seq_inputs)
    right = LSTM(16, consume_less="mem")(right)
    right = BatchNormalization(input_shape=(32,), name="lstm_norm")(right)

    aux_out = Dense(2, activation="sigmoid", name="aux_out")(right)

    x = merge([left, right], mode="concat")
    x = Dense(18, activation="relu")(x)
    out = Dense(2, activation="sigmoid", name="out")(x)

    model = Model(input=[dyn_inputs, seq_inputs], output=[out, aux_out])
    model.compile(optimizer="adam",
                  loss={"out": "categorical_crossentropy", "aux_out": "categorical_crossentropy"},
                  loss_weights={"out": 1., "aux_out": .2},
                  metrics=['accuracy'])
    return model

def train_fn(model, train, validation, seed, *args, **kwargs):
    np.random.seed(seed)
    model.fit({"data_in": train["x_2"], "code_in": train["x_seq"]},
          {"out": train["y_2"], "aux_out": train["y_2"]},
          nb_epoch=50,
          batch_size=batch_size,
          validation_data=({"data_in": validation["x_2"], "code_in": validation["x_seq"]},
                           {"out": validation["y_2"], "aux_out": validation["y_2"]}),
          verbose=0,
          shuffle=True
    )
    return {}

def save_fn(model, seed, i, *args, **kwargs):
    outpath = "classification/models/model-{i}-{seed}.h5".format(**vars())
    model.save(outpath)
    print("saved model", outpath)

def test_fn(model, test, seed, *args, **kwargs):
    np.random.seed(seed)
    predictions = np.array(model.predict({"dynprop_in": test["x_2"], "seq_in": test["x_seq"]},
                                         batch_size=batch_size, verbose=0))
    clipped = [np.argmax(x) for x in predictions[0]]
    return clipped

dataframe, seq_length, atomizer = load_dataframe(
    platform="amd",
    source="B",
    max_seq_len=1024, 
    atomizer=GreedyAtomizer
)
r = evaluate(dataframe, seq_length, create_model, train_fn, test_fn, split=(.6, .2, .2), seed=204, n=3)
print()
dataframe, seq_length, atomizer = load_dataframe(
    platform="nvidia",
    source="B",
    max_seq_len=1024, 
    atomizer=GreedyAtomizer
)
r = evaluate(dataframe, seq_length, create_model, train_fn, test_fn,
             split=(.6, .2, .2), save_fn=save_fn, seed=204, n=3)
# Out:
# num instances 680 (0 synthetic, 680 benchmarks)
# unique kernels 247

# %%
model = create_model()
model.summary()
SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# seq_in (InputLayer)              (None, 1000)          0
# ____________________________________________________________________________________________________
# embedding_35 (Embedding)         (None, 1000, 32)      3200        seq_in[0][0]
# ____________________________________________________________________________________________________
# dynprop_in (InputLayer)          (None, 2)             0
# ____________________________________________________________________________________________________
# lstm_35 (LSTM)                   (None, 16)            3136        embedding_35[0][0]
# ____________________________________________________________________________________________________
# dynprop_norm (BatchNormalization (None, 2)             8           dynprop_in[0][0]
# ____________________________________________________________________________________________________
# lstm_norm (BatchNormalization)   (None, 16)            64          lstm_35[0][0]
# ____________________________________________________________________________________________________
# merge_35 (Merge)                 (None, 18)            0           dynprop_norm[0][0]
#                                                                    lstm_norm[0][0]
# ____________________________________________________________________________________________________
# dense_260 (Dense)                (None, 18)            342         merge_35[0][0]
# ____________________________________________________________________________________________________
# out (Dense)                      (None, 2)             38          dense_260[0][0]
# ____________________________________________________________________________________________________
# aux_out (Dense)                  (None, 2)             34          lstm_norm[0][0]
# ====================================================================================================
# Total params: 6,822
# Trainable params: 6,786
# Non-trainable params: 36
# ____________________________________________________________________________________________________
