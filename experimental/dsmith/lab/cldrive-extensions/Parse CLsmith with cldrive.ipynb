# %%
from lib.labm8 import fs
import cldrive

# %%
src = fs.read_file("~/src/CLSmith/build/CLProg.c")
pp = cldrive.preprocess(src, include_dirs=["~/src/CLSmith/runtime"])
print(pp)
# Out:
# # 1 "<stdin>"
# # 1 "<built-in>"
# # 1 "<command-line>"
# # 1 "/usr/include/stdc-predef.h" 1 3 4
# # 1 "<command-line>" 2
# # 1 "<stdin>"
# # 54 "<stdin>"
# # 1 "/home/cec/src/CLSmith/runtime/CLSmith.h" 1
#
#
#
# # 1 "/home/cec/src/CLSmith/runtime/cl_safe_math_macros.h" 1
# # 5 "/home/cec/src/CLSmith/runtime/CLSmith.h" 2
# # 1 "/home/cec/src/CLSmith/runtime/safe_math_macros.h" 1
# # 6 "/home/cec/src/CLSmith/runtime/CLSmith.h" 2
# # 19 "/home/cec/src/CLSmith/runtime/CLSmith.h"
# inline __attribute__((always_inline)) void
# transparent_crc_no_string (ulong *crc64_context, ulong val)
# {
#   *crc64_context += val;
# }
#
#
#
# inline __attribute__((always_inline)) uint
# get_linear_group_id (void)
# {
#   return (get_group_id(2) * get_num_groups(1) + get_group_id(1)) *
#     get_num_groups(0) + get_group_id(0);
# }
#
# inline __attribute__((always_inline)) uint
# get_linear_global_id (void)
# {
#   return (get_global_id(2) * get_global_size(1) + get_global_id(1)) *
# ...

# %%
ast = cldrive.parse(pp)
# Out:
# ---------------------------------------------------------------------------
# ParseError                                Traceback (most recent call last)
# /home/cec/src/cldrive/cldrive/args.py in parse(src)
#     267     try:
# --> 268         ast = __parser.parse(src)
#     269         # strip preprocesor line objects and rebuild the AST.
#
# /home/cec/clgen/lib/python3.6/site-packages/pycparserext-2016.2-py3.6.egg/pycparserext/ext_c_parser.py in parse(self, text, filename, debuglevel, initial_type_symbols)
#      63         else:
# ---> 64             return self.cparser.parse(text, lexer=self.clex, debug=debuglevel)
#      65
#
# /home/cec/clgen/lib/python3.6/site-packages/pycparser/ply/yacc.py in parse(self, input, lexer, debug, tracking, tokenfunc)
#     330         else:
# --> 331             return self.parseopt_notrack(input, lexer, debug, tracking, tokenfunc)
#     332
#
# ...
