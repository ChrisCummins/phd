# %%
# preamble
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %run lib/preamble.py
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Models

# %%
# %run lib/models.py
d = load_data_desc("amd", source="B", max_seq_len=1024, atomizer=CharacterAtomizer)
m = bruno()["create_model"](data_desc=d)
# Out:
# num instances 680 (0 synthetic, 680 benchmarks)
# unique kernels 247
# vocab size 84
# pad val 84
# padded seq length 1024

# %%
m.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# code_in (InputLayer)             (None, 1024)          0
# ____________________________________________________________________________________________________
# embedding_3 (Embedding)          (None, 1024, 64)      5376        code_in[0][0]
# ____________________________________________________________________________________________________
# lstm_5 (LSTM)                    (None, 1024, 64)      33024       embedding_3[0][0]
# ____________________________________________________________________________________________________
# data_in (InputLayer)             (None, 2)             0
# ____________________________________________________________________________________________________
# lstm_6 (LSTM)                    (None, 64)            33024       lstm_5[0][0]
# ____________________________________________________________________________________________________
# merge_3 (Merge)                  (None, 66)            0           data_in[0][0]
#                                                                    lstm_6[0][0]
# ____________________________________________________________________________________________________
# norm (BatchNormalization)        (None, 66)            264         merge_3[0][0]
# ____________________________________________________________________________________________________
# dense_3 (Dense)                  (None, 32)            2144        norm[0][0]
# ____________________________________________________________________________________________________
# out (Dense)                      (None, 2)             66          dense_3[0][0]
# ____________________________________________________________________________________________________
# aux_out (Dense)                  (None, 2)             130         lstm_6[0][0]
# ====================================================================================================
# Total params: 74,028
# Trainable params: 73,896
# Non-trainable params: 132
# ____________________________________________________________________________________________________

# %%
SVG(model_to_dot(m, show_shapes=True).create(prog='dot', format='svg'))

# %% [markdown]
# # Evaluate

# %%
# %run lib/preamble.py
# %run lib/models.py

def model2str(m):
    if m == "zero_r":
        return "Static mapping"
    elif m == "cgo13":
        return "CGO'13"
    elif m == "bruno":
        return "DeepTune"
    else:
        return m.title()

models = ["zero_r", "cgo13", "karl", "sally", "barry", "turner", "rupert", "fred", "bruno", "brandon", "janet"]
platforms = ["amd", "nvidia"]
sources = ["B"]#, "BS"]
atomizers = ["GreedyAtomizer"]#, "CharacterAtomizer"]
n_splits = 10
splits = range(n_splits)
seed = 204

data = None

for model, platform, source, atomizer, split_i in product(models, platforms, sources, atomizers, splits):
    result = load_result(globals().get(model)(), platform, source, 
                         atomizer=atomizer, maxlen=1024, seed=seed,
                         n_splits=n_splits, split_i=split_i)
    if not result:
        continue

    frame = result["dataframe"]
    frame["correct"] = result["correct"]
    frame["acc"] = result["correct"] * 100
    frame["p_oracle"] = result["speedups"]
    frame["p_oracle_perc"] = result["speedups"] * 100
    frame["model"] = [model] * len(frame)
    frame["platform"] = [platform] * len(frame)
    frame["atomizer"] = [atomizer] * len(frame)
    frame["model_name"] = model2str(model)
    frame["benchmark_name"] = [escape_benchmark_name(b) for b in frame["benchmark"].values]
    
    zero_r_dev = "runtime_cpu" if platform == "amd" else "runtime_gpu"
    frame["p_speedup"] = np.array(
        [r[zero_r_dev] / r[enc2key(p)]
        for p, r in zip(result["predictions"], frame.to_dict('records'))])
    
    if data is None:
        data = frame
    else:
        data = pd.concat((data, frame))
        
model_names = sorted(set(data["model_name"]))
suite_names = sorted(set(data["source"]))
benchmark_names = sorted(set(data["benchmark_name"]))

d = data.copy()

# Append aggregate "Average" rows:
for platform, atomizer in product(platforms, atomizers):
    # TODO: source B, BS
    msk = (data["platform"] == platform) & (data["atomizer"] == atomizer)
    r = data[msk].groupby('model_name').mean()
    r["source"] = ["Average"] * len(r)
    r["platform"] = [platform] * len(r)
    r["atomizer"] = [atomizer] * len(r)
    r["model_name"] = model_names
    d = d.append(r)

assert(len(d[d["source"] == "Average"]) == len(list(product(platforms, sources, atomizers))) * len(model_names))
data
# Out:
#                                              benchmark  dataset  comp  \
# 9      amd-app-sdk-3.0-ScanLargeArrays-ScanLargeArrays  default    32
# 11           amd-app-sdk-3.0-ScanLargeArrays-prefixSum  default    31
# 25                             npb-3.3-BT-compute_rhs2        B    27
# 26                             npb-3.3-BT-compute_rhs2        S    27
# 27                             npb-3.3-BT-compute_rhs2        W    27
# 36                             npb-3.3-BT-compute_rhs5        A  1260
# 42                             npb-3.3-BT-compute_rhs6        S    16
# 55                               npb-3.3-BT-exact_rhs2        W   340
# 69                              npb-3.3-BT-initialize1        B    12
# 74                              npb-3.3-BT-initialize2        S   116
# 75                              npb-3.3-BT-initialize2        W   116
# 84                              npb-3.3-BT-initialize5        A    67
# 102                                npb-3.3-BT-x_solve2        S    15
# 116                                npb-3.3-BT-y_solve2        A    15
# 123                                npb-3.3-BT-y_solve3        W   372
# 128                                npb-3.3-BT-z_solve1        A   172
# 136                                npb-3.3-BT-z_solve3        A   372
# 140                             npb-3.3-CG-conj_grad_0        A     1
# 154                              npb-3.3-CG-init_mem_1        W     0
# 165                                  npb-3.3-CG-main_2        A     0
# 199                                 npb-3.3-CG-makea_5        W     2
# 201                                 npb-3.3-CG-makea_6        B     5
# 206                                 npb-3.3-CG-makea_7        B     4
# 212                                   npb-3.3-EP-embar        C   133
# 232                        npb-3.3-FT-compute_indexmap        S    43
# 239                                  npb-3.3-FT-evolve        B    11
# 261                                   npb-3.3-LU-erhs2        A   296
# 268                                   npb-3.3-LU-erhs3        C   296
# 273                                   npb-3.3-LU-erhs4        C   296
# 281                                  npb-3.3-LU-l2norm        A    19
# ..                                                 ...      ...   ...
# 392                            npb-3.3-MG-kernel_rprj3        W   176
# 409                          npb-3.3-MG-kernel_zran3_3        B     6
# 422                            npb-3.3-SP-compute_rhs1        W   127
# 427                            npb-3.3-SP-compute_rhs2        W    27
# 437                            npb-3.3-SP-compute_rhs4        W  1257
# 445                            npb-3.3-SP-compute_rhs6        C    16
# 454                              npb-3.3-SP-exact_rhs1        B    12
# 458                              npb-3.3-SP-exact_rhs2        A   340
# 459                              npb-3.3-SP-exact_rhs2        B   340
# 487                             npb-3.3-SP-initialize2        W   116
# 489                             npb-3.3-SP-initialize3        B    67
# 491                             npb-3.3-SP-initialize3        S    67
# 501                             npb-3.3-SP-initialize5        S    67
# 525                                  npb-3.3-SP-tzetar        C   129
# 531                                 npb-3.3-SP-x_solve        S   829
# 542                                 npb-3.3-SP-z_solve        W   828
# 554                     nvidia-4.2-VectorAdd-VectorAdd  default     1
# 560  parboil-0.2-cutcp-opencl_cutoff_potential_lattice    small   102
# 568                        parboil-0.2-sad-mb_sad_calc    large    55
# 579                  polybench-gpu-1.0-3mm-mm3_kernel2  default     7
# 580                  polybench-gpu-1.0-3mm-mm3_kernel3  default     7
# 590           polybench-gpu-1.0-covariance-mean_kernel  default     6
# 604                              rodinia-3.1-bfs-BFS_2  default     0
# 619                       rodinia-3.1-lud-lud_diagonal  default    33
# 627  rodinia-3.1-particlefilter-normalize_weights_k...  default    11
# 635                          shoc-1.1.5-FFT-ifft1D_512  default   571
# 641                             shoc-1.1.5-S3D-gr_base  default   167
# 644                        shoc-1.1.5-S3D-qssab_kernel  default  2206
# 653                        shoc-1.1.5-S3D-ratt9_kernel  default   746
# 679                             shoc-1.1.5-Triad-Triad  default     2
#
#      rational  mem  localmem  coalesced  atomic    transfer  wgsize  \
# 9           3   21        14          4       0      263168     128
# 11          3   19        13          3       0      263168      64
# 25          4    2         0          2       0  1313675032      32
# 26          4    2         0          2       0     1807992      60
# 27          4    2         0          2       0    15948384      48
# 36         23    8         0         87       0   320457304      62
# 42          4    1         0          2       0     1807992      60
# 55         26    5         0        112       0    15948384      44
# 69          4    1         0          1       0  1313675032      32
# 74         10    7         0         40       0     1807992      60
# 75         10    7         0         40       0    15948384      48
# 84          6    5         0         28       0   320454224      64
# 102         5    1         0          5       0     1807992      60
# 116         5    1         0          5       0   320454224      64
# 123         3    3         0        203       0    15948384      44
# 128         3    5         0         61       0   320457304      64
# 136         3    3         0        203       0   320454224      62
# 140         1    5         0          5       0    51143900     128
# 154         1    1         0          1       0    14742140     256
# 165         1    4         0          4       0    51143900     128
# 199         5    4         0          6       0    14742140      32
# 201         3    8         0         10       0   369331132     128
# 206         1    3         0          4       0   369331132     128
# 212        16   16        13          2       0       98304      64
# 232         3    1         0          0       0    10652176      64
# 239         3   13         0         13       0  1344811536      64
# 261        11    3         0        101       0    47333288      62
# 268        11    3         0        101       0   755866968      64
# 273        11    3         0         88       0   755866968      64
# 281         9   11         8          3       0    47333288       4
# ..        ...  ...       ...        ...     ...         ...     ...
# 392         1    8         6          9       0    61898192      22
# 409         3    1         0          0       0   477315888      64
# 422         3    8         0         12       0    20402112      36
# 427         4    2         0          2       0    20402112      36
# 437        23    8         0        107       0    20402112      34
# 445         4    1         0          2       0  1815065192      64
# 454         4    1         0          1       0   454882552      32
# 458        26    5         0        112       0   113095432      62
# 459        26    5         0        112       0   454882552      32
# 487        10    7         0         40       0    20402112      36
# 489         6    5         0         28       0   454882552      32
# 491         6    5         0         28       0      804152      60
# 501         6    5         0         28       0      804152      60
# 525         3    7         0         16       0  1815065192      64
# 531       135    9         0        232       0      804152      60
# 542       135    9         0        232       0    20401432      34
# 554         1    3         0          3       0   137339904     256
# 560         8   14         6          2       0     3376052     128
# 568         6    3         0          1       0  1449258240      61
# 579         3    3         0          0       0     7340032     256
# 580         3    3         0          0       0     7340032     256
# 590         3    4         0          3       0    33595404     256
# 604         1    5         0          4       0    38999881     256
# 619         7   12        10          0       0     4194304      16
# 627         6   21         0         14       0   126564393     512
# 635        13   22        16          0       0     6291464      64
# 641         1   48         0          0       0    57594120     128
# 644         0  384         0          0       0    57594120     128
# 653         0  189         0          0       0    57594120     128
# 679         0    3         0          3       0   117440512     128
#
#        ...                                                    seq  correct  \
# 9      ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 11     ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 25     ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...    False
# 26     ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 27     ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 36     ...      [1, 113, 51, 18, 52, 8, 1, 10, 1, 7, 7, 7, 15,...    False
# 42     ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 55     ...      [8, 8, 1, 9, 1, 7, 20, 13, 15, 1, 9, 1, 123, 5...     True
# 69     ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...    False
# 74     ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 75     ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 84     ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 102    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 116    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 123    ...      [0, 2, 102, 51, 89, 52, 51, 17, 52, 51, 18, 52...     True
# 128    ...      [51, 16, 52, 51, 15, 52, 1, 28, 1, 15, 13, 15,...    False
# 136    ...      [16, 52, 26, 0, 2, 102, 51, 90, 52, 51, 17, 52...     True
# 140    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 154    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 165    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 199    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 201    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 206    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 212    ...      [2, 81, 1, 7, 94, 1, 28, 1, 15, 26, 1, 94, 1, ...    False
# 232    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...    False
# 239    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...    False
# 261    ...      [7, 16, 13, 15, 1, 14, 1, 7, 16, 17, 1, 12, 1,...     True
# 268    ...      [7, 16, 13, 15, 1, 14, 1, 7, 16, 17, 1, 12, 1,...     True
# 273    ...      [7, 16, 13, 15, 1, 14, 1, 7, 16, 17, 1, 12, 1,...     True
# 281    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# ..     ...                                                    ...      ...
# 392    ...      [75, 9, 1, 122, 1, 28, 1, 63, 1, 10, 1, 89, 26...     True
# 409    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 422    ...      [16, 17, 1, 14, 1, 17, 1, 9, 1, 17, 8, 1, 10, ...     True
# 427    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 437    ...      [16, 8, 8, 1, 9, 1, 7, 16, 13, 15, 1, 14, 1, 7...     True
# 445    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 454    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 458    ...      [8, 8, 1, 9, 1, 7, 20, 13, 15, 1, 9, 1, 123, 5...    False
# 459    ...      [8, 8, 1, 9, 1, 7, 20, 13, 15, 1, 9, 1, 123, 5...     True
# 487    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 489    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 491    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 501    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...    False
# 525    ...      [1, 16, 52, 1, 28, 1, 7, 58, 1, 75, 7, 9, 8, 5...     True
# 531    ...      [51, 17, 52, 26, 0, 2, 63, 73, 51, 18, 52, 1, ...     True
# 542    ...      [63, 76, 51, 17, 52, 26, 0, 2, 63, 73, 51, 18,...     True
# 554    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...    False
# 560    ...      [90, 73, 7, 15, 8, 1, 29, 29, 1, 17, 8, 1, 10,...     True
# 568    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 579    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 580    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 590    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 604    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 619    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 627    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     True
# 635    ...      [7, 90, 11, 1, 9, 5, 82, 51, 22, 52, 8, 26, 0,...     True
# 641    ...      [95, 1, 28, 1, 7, 69, 51, 7, 7, 7, 16, 19, 8, ...     True
# 644    ...      [1, 10, 1, 15, 8, 8, 1, 12, 1, 16, 8, 1, 9, 1,...     True
# 653    ...      [7, 73, 51, 7, 7, 7, 19, 8, 1, 12, 1, 16, 8, 1...     True
# 679    ...      [129, 129, 129, 129, 129, 129, 129, 129, 129, ...    False
#
#      acc  p_oracle p_oracle_perc   model  platform        atomizer  \
# 9    100  0.505803     50.580324  zero_r       amd  GreedyAtomizer
# 11   100  0.701699     70.169912  zero_r       amd  GreedyAtomizer
# 25     0  1.000000    100.000000  zero_r       amd  GreedyAtomizer
# 26   100  0.790205     79.020479  zero_r       amd  GreedyAtomizer
# 27   100  1.000000    100.000000  zero_r       amd  GreedyAtomizer
# 36     0  1.000000    100.000000  zero_r       amd  GreedyAtomizer
# 42   100  1.000000    100.000000  zero_r       amd  GreedyAtomizer
# 55   100  1.000000    100.000000  zero_r       amd  GreedyAtomizer
# 69     0  1.000000    100.000000  zero_r       amd  GreedyAtomizer
# 74   100  1.000000    100.000000  zero_r       amd  GreedyAtomizer
# 75   100  0.182895     18.289543  zero_r       amd  GreedyAtomizer
# 84   100  0.387305     38.730475  zero_r       amd  GreedyAtomizer
# 102  100  0.192886     19.288642  zero_r       amd  GreedyAtomizer
# 116  100  1.000000    100.000000  zero_r       amd  GreedyAtomizer
# 123  100  1.000000    100.000000  zero_r       amd  GreedyAtomizer
# 128    0  1.000000    100.000000  zero_r       amd  GreedyAtomizer
# 136  100  1.000000    100.000000  zero_r       amd  GreedyAtomizer
# 140  100  1.000000    100.000000  zero_r       amd  GreedyAtomizer
# 154  100  0.192715     19.271508  zero_r       amd  GreedyAtomizer
# 165  100  1.000000    100.000000  zero_r       amd  GreedyAtomizer
# 199  100  1.000000    100.000000  zero_r       amd  GreedyAtomizer
# 201  100  0.218990     21.899018  zero_r       amd  GreedyAtomizer
# 206  100  1.000000    100.000000  zero_r       amd  GreedyAtomizer
# 212    0  1.000000    100.000000  zero_r       amd  GreedyAtomizer
# 232    0  0.135629     13.562912  zero_r       amd  GreedyAtomizer
# 239    0  1.000000    100.000000  zero_r       amd  GreedyAtomizer
# 261  100  1.000000    100.000000  zero_r       amd  GreedyAtomizer
# 268  100  1.000000    100.000000  zero_r       amd  GreedyAtomizer
# 273  100  1.000000    100.000000  zero_r       amd  GreedyAtomizer
# 281  100  1.000000    100.000000  zero_r       amd  GreedyAtomizer
# ..   ...       ...           ...     ...       ...             ...
# 392  100  0.113604     11.360384   janet    nvidia  GreedyAtomizer
# 409  100  0.175736     17.573580   janet    nvidia  GreedyAtomizer
# 422  100  1.000000    100.000000   janet    nvidia  GreedyAtomizer
# 427  100  1.000000    100.000000   janet    nvidia  GreedyAtomizer
# 437  100  1.000000    100.000000   janet    nvidia  GreedyAtomizer
# 445  100  1.000000    100.000000   janet    nvidia  GreedyAtomizer
# 454  100  1.000000    100.000000   janet    nvidia  GreedyAtomizer
# 458    0  0.864541     86.454102   janet    nvidia  GreedyAtomizer
# 459  100  0.720175     72.017512   janet    nvidia  GreedyAtomizer
# 487  100  1.000000    100.000000   janet    nvidia  GreedyAtomizer
# 489  100  1.000000    100.000000   janet    nvidia  GreedyAtomizer
# 491  100  0.376841     37.684125   janet    nvidia  GreedyAtomizer
# 501    0  0.970051     97.005083   janet    nvidia  GreedyAtomizer
# 525  100  1.000000    100.000000   janet    nvidia  GreedyAtomizer
# 531  100  0.530515     53.051462   janet    nvidia  GreedyAtomizer
# 542  100  1.000000    100.000000   janet    nvidia  GreedyAtomizer
# 554    0  1.000000    100.000000   janet    nvidia  GreedyAtomizer
# 560  100  1.000000    100.000000   janet    nvidia  GreedyAtomizer
# 568  100  0.257145     25.714540   janet    nvidia  GreedyAtomizer
# 579  100  1.000000    100.000000   janet    nvidia  GreedyAtomizer
# 580  100  1.000000    100.000000   janet    nvidia  GreedyAtomizer
# 590  100  0.162930     16.292984   janet    nvidia  GreedyAtomizer
# 604  100  1.000000    100.000000   janet    nvidia  GreedyAtomizer
# 619  100  1.000000    100.000000   janet    nvidia  GreedyAtomizer
# 627  100  0.048370      4.836985   janet    nvidia  GreedyAtomizer
# 635  100  1.000000    100.000000   janet    nvidia  GreedyAtomizer
# 641  100  1.000000    100.000000   janet    nvidia  GreedyAtomizer
# 644  100  0.609531     60.953112   janet    nvidia  GreedyAtomizer
# 653  100  1.000000    100.000000   janet    nvidia  GreedyAtomizer
# 679    0  0.511229     51.122861   janet    nvidia  GreedyAtomizer
#
#          model_name  p_speedup
# 9    Static mapping   1.000000
# 11   Static mapping   1.000000
# 25   Static mapping   1.000000
# 26   Static mapping   1.000000
# 27   Static mapping   1.000000
# 36   Static mapping   1.000000
# 42   Static mapping   1.000000
# 55   Static mapping   1.000000
# 69   Static mapping   1.000000
# 74   Static mapping   1.000000
# 75   Static mapping   1.000000
# 84   Static mapping   1.000000
# 102  Static mapping   1.000000
# 116  Static mapping   1.000000
# 123  Static mapping   1.000000
# 128  Static mapping   1.000000
# 136  Static mapping   1.000000
# 140  Static mapping   1.000000
# 154  Static mapping   1.000000
# 165  Static mapping   1.000000
# 199  Static mapping   1.000000
# 201  Static mapping   1.000000
# 206  Static mapping   1.000000
# 212  Static mapping   1.000000
# 232  Static mapping   1.000000
# 239  Static mapping   1.000000
# 261  Static mapping   1.000000
# 268  Static mapping   1.000000
# 273  Static mapping   1.000000
# 281  Static mapping   1.000000
# ..              ...        ...
# 392           Janet   3.831966
# 409           Janet   2.486271
# 422           Janet   1.000000
# 427           Janet   1.000000
# 437           Janet   1.000000
# 445           Janet   1.000000
# 454           Janet   1.000000
# 458           Janet   0.787952
# 459           Janet   1.000000
# 487           Janet   1.000000
# 489           Janet   1.000000
# 491           Janet   1.000000
# 501           Janet   1.000000
# 525           Janet   1.000000
# 531           Janet   1.654284
# 542           Janet   1.187349
# 554           Janet   1.000000
# 560           Janet   1.000000
# 568           Janet   1.000000
# 579           Janet   1.000000
# 580           Janet   1.000000
# 590           Janet   1.388551
# 604           Janet   2.653637
# 619           Janet   1.479282
# 627           Janet   7.588750
# 635           Janet   1.676578
# 641           Janet   1.956072
# 644           Janet   1.827704
# 653           Janet   2.124855
# 679           Janet   1.000000
#
# [14960 rows x 37 columns]

# %%
# print model accuracy and speedup (per-platform)
amd_msk = (data["platform"] == "amd") & (data["atomizer"] == "GreedyAtomizer")
nvidia_msk = (data["platform"] == "nvidia") & (data["atomizer"] == "GreedyAtomizer")

def table(D, sortby='acc'):
    print(D[["model_name", "acc", "p_oracle", "p_speedup"]].groupby(
          "model_name").mean().sort_values(sortby, ascending=False))
    
table(data, sortby="p_speedup")
print("\nAMD:")
table(data[amd_msk], sortby="p_speedup")
print("\nNVIDIA:")
table(data[nvidia_msk], sortby="p_speedup")
# Out:
#                       acc  p_oracle  p_speedup
# model_name
# Brandon         83.308824  0.721009   2.450857
# DeepTune        83.823529  0.723524   2.423378
# Fred            82.058824  0.717209   2.390579
# Turner          81.470588  0.729473   2.381664
# Sally           81.397059  0.729643   2.350925
# Karl            82.205882  0.726738   2.324546
# Barry           81.397059  0.728680   2.288556
# Janet           81.617647  0.720708   2.242471
# CGO'13          73.161765  0.734061   2.085312
# Rupert          63.455882  0.769345   1.760893
# Static mapping  57.867647  0.788421   1.000000
#
# AMD:
#                       acc  p_oracle  p_speedup
# model_name
# Brandon         84.852941  0.698338   3.481695
# DeepTune        86.029412  0.705724   3.425412
# Fred            83.235294  0.698506   3.384694
# Turner          82.647059  0.713623   3.357451
# Sally           83.382353  0.721539   3.301438
# Karl            85.735294  0.704323   3.263103
# Barry           84.117647  0.722663   3.169435
# Janet           82.941176  0.694439   3.083999
# CGO'13          73.382353  0.705625   2.905822
# Rupert          69.411765  0.728865   2.504302
# Static mapping  58.823529  0.764933   1.000000
#
# NVIDIA:
#                       acc  p_oracle  p_speedup
# model_name
# DeepTune        81.617647  0.741324   1.421344
# Brandon         81.764706  0.743680   1.420019
# Barry           78.676471  0.734697   1.407677
# Turner          80.294118  0.745323   1.405878
# Janet           80.294118  0.746978   1.400942
# Sally           79.411765  0.737747   1.400412
# Fred            80.882353  0.735912   1.396465
# Karl            78.676471  0.749154   1.385989
# CGO'13          72.941176  0.762496   1.264801
# Rupert          57.500000  0.809825   1.017485
# Static mapping  56.911765  0.811910   1.000000

# %%
order = ["AMD", "NPB", "NVIDIA", "Parboil", "Polybench", "Rodinia", "SHOC", "Average"]

def plot_ex1_graph(x="source", y="acc", hue="model_name", order=order, n_palette=len(model_names),
                   data=data, atomizer="CharacterAtomizer", ylabel="Accuracy (%)", ci=None,
                   ylim=[(0, 100), (0, 100)], yaxis_fmt="%d%%"):
    palette = sns.cubehelix_palette(n_palette, rot=1.8, light=.85, dark=.35)

    if y == "p_speedup":
        d = data[data["model_name"] != "Static mapping"]
    else:
        d = data
    
    for i, platform in enumerate(["amd", "nvidia"]):
        plt.subplot(1, 2, i + 1)
        msk = (d["platform"] == platform) & (d["atomizer"] == atomizer)
        ax = sns.barplot(x=x, y=y, hue=hue, order=order, palette=palette,
                         data=d[msk], ci=ci, errwidth=1, capsize=.08)

        plt.ylim(ylim[i])
        plt.xlabel("")
        
        # vertical divider for "Average" column
        plt.axvline(x=plt.xlim()[1] - 1, color="k", lw=1, linestyle="--")
        
        if not i:
            # first plot
            plt.ylabel(ylabel)
            ax.legend().set_visible(False)
        else:     
            # second plot
            plt.ylabel("")
            plt.legend(loc='upper left', bbox_to_anchor=(1,1))
            ax.get_legend().set_title("")  # no legend title
            ax.get_legend().draw_frame(True)
            
        if y == "p_speedup":
            plt.axhline(y=1, color="k", lw=1)  # speedup line
            
        from matplotlib.ticker import FormatStrFormatter
        if yaxis_fmt:
            plt.gca().yaxis.set_major_formatter(FormatStrFormatter(yaxis_fmt))
        
        plt.title(platform2str(platform))

    viz.finalise(figsize=(9,2.6))

# %%
for atomizer in atomizers:
    print("Atomizer:", atomizer)
    plot_ex1_graph(x="source", order=suite_names + ["Average"], y="acc", data=d, atomizer=atomizer)
    
for atomizer in atomizers:
    print("Atomizer:", atomizer)
    plot_ex1_graph(x="source", order=suite_names + ["Average"], y="p_speedup",
                   data=d, atomizer=atomizer, ylabel="Speedup", ylim=[(0, 15), (0, 2)], yaxis_fmt="%dx")
# Out:
# Atomizer: GreedyAtomizer
# Atomizer: GreedyAtomizer

# %% [markdown]
# ### Accuracy & Performance

# %%
_d = d[
    (d["model_name"] == "CGO'13") | 
    (d["model_name"] == "DeepTune") |
    (d["model_name"] == "Janet")
]
for atomizer in atomizers:
    print("Atomizer:", atomizer)
    plot_ex1_graph(x="source", order=suite_names + ["Average"], y="acc", data=_d, n_palette=3, atomizer=atomizer)
    plot_ex1_graph(x="source", order=suite_names + ["Average"], y="p_speedup", n_palette=3, 
                   data=_d, atomizer=atomizer, ylabel="Speedup", ylim=[(0, 15), (0, 2)], yaxis_fmt="%.1fx")
# Out:
# Atomizer: GreedyAtomizer
