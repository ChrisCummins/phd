# %%
# preamble
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %run lib/preamble.py
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Models

# %%
def zero_r():
    def train_fn(model, train, *args, platform=None, **kwargs):
        """ train a model """
        if platform == "amd":
            model["zero_r"] = 0
        elif platform == "nvidia":
            model["zero_r"] = 1

    def test_fn(model, test, seed, *args, **kwargs):
        """ make predictions for test data """
        return [model["zero_r"]] * len(test["y"])

    def save_fn(outpath, model):
        """ save a trained model """
        with open(outpath, "wb") as outfile:
            pickle.dump(model, outfile)
    
    def load_fn(inpath):
        """ load a trained model """
        with open(inpath, "rb") as infile:
            model = pickle.load(infile)
        return model

    return {
        "name": "zero_r",
        "train_fn": train_fn,
        "test_fn": test_fn,
        "save_fn": save_fn,
        "load_fn": load_fn
    }

# %%
def cgo13():
    def create_model(seed=204, **kwargs):
        """ instantiate a model """ 
        return DecisionTreeClassifier(random_state=seed, splitter="best", criterion="entropy")

    def train_fn(model, train, validation, *args, **kwargs):
        """ train a model """
        np.random.seed(seed)
        model.fit(train["x_4"], train["y"])
        return {}

    def test_fn(model, test, seed, *args, **kwargs):
        """ make predictions for test data """
        np.random.seed(seed)
        return model.predict(test["x_4"])
    
    def save_fn(outpath, model):
        """ save a trained model """
        with open(outpath, "wb") as outfile:
            pickle.dump(model, outfile)
    
    def load_fn(inpath):
        """ load a trained model """
        with open(inpath, "rb") as infile:
            model = pickle.load(infile)
        return model
        
    return {
        "name": "cgo13",
        "create_model": create_model,
        "train_fn": train_fn,
        "test_fn": test_fn,
        "save_fn": save_fn,
        "load_fn": load_fn
    }

# %%
def harry():
    BATCH_SIZE = 64
    EMBEDDING_VECTOR_LEN = 64
    
    def create_model(*args, data_desc=None, **kwargs):
        """ instantiate a model """ 
        atomizer = data_desc["atomizer"]
        seq_length = data_desc["seq_length"]
        vocab_size = atomizer.vocab_size + 1

        dyn_inputs = Input(shape=(2,), name="data_in")
        left = BatchNormalization(name="dynprop_norm")(dyn_inputs)

        seq_inputs = Input(shape=(seq_length,), dtype="int32", name="code_in")
        right = Embedding(output_dim=EMBEDDING_VECTOR_LEN, input_dim=vocab_size, input_length=seq_length)(seq_inputs)
        right = LSTM(16, consume_less="mem")(right)
        right = BatchNormalization(input_shape=(32,), name="lstm_norm")(right)

        aux_out = Dense(2, activation="sigmoid", name="aux_out")(right)

        x = merge([left, right], mode="concat")
        x = Dense(18, activation="relu")(x)
        out = Dense(2, activation="sigmoid", name="out")(x)

        model = Model(input=[dyn_inputs, seq_inputs], output=[out, aux_out])
        model.compile(optimizer="adam",
                      loss={"out": "categorical_crossentropy", "aux_out": "categorical_crossentropy"},
                      loss_weights={"out": 1., "aux_out": .2},
                      metrics=['accuracy'])
        return model
    
    def train_fn(model, train, *args, validation=None, **kwargs):
        """ train a model """
        model.fit({"data_in": train["x_2"], "code_in": train["x_seq"]},
                  {"out": train["y_2"], "aux_out": train["y_2"]},
                  nb_epoch=1,
                  batch_size=BATCH_SIZE,
                  validation_data=({"data_in": validation["x_2"], "code_in": validation["x_seq"]},
                                   {"out": validation["y_2"], "aux_out": validation["y_2"]}),
                  verbose=1,
                  shuffle=True)

    def test_fn(model, test, seed, *args, **kwargs):
        """ make predictions for test data """
        predictions = np.array(model.predict({"data_in": test["x_2"], "code_in": test["x_seq"]},
                                             batch_size=BATCH_SIZE, verbose=0))
        clipped = [np.argmax(x) for x in predictions[0]]
        return clipped

    def save_fn(outpath, model):
        """ save a trained model """
        model.save(outpath)
    
    def load_fn(inpath):
        """ load a trained model """
        return load_model(inpath)

    return {
        "name": "harry",
        "create_model": create_model,
        "train_fn": train_fn,
        "test_fn": test_fn,
        "save_fn": save_fn,
        "load_fn": load_fn
    }

# %%
def sally():
    BATCH_SIZE = 64
    EMBEDDING_VECTOR_LEN = 64
    
    def create_model(*args, data_desc=None, **kwargs):
        """ instantiate a model """ 
        atomizer = data_desc["atomizer"]
        seq_length = data_desc["seq_length"]
        vocab_size = atomizer.vocab_size + 1

        dyn_inputs = Input(shape=(2,), name="data_in")
        left = BatchNormalization(name="dynprop_norm")(dyn_inputs)

        seq_inputs = Input(shape=(seq_length,), dtype="int32", name="code_in")
        right = Embedding(output_dim=EMBEDDING_VECTOR_LEN, input_dim=vocab_size, input_length=seq_length)(seq_inputs)
        right = LSTM(32, consume_less="mem", return_sequences=True)(right)
        right = LSTM(32, consume_less="mem")(right)
        right = BatchNormalization(input_shape=(32,), name="lstm_norm")(right)

        aux_out = Dense(2, activation="sigmoid", name="aux_out")(right)

        x = merge([left, right], mode="concat")
        x = Dense(34, activation="relu")(x)
        x = Dense(34, activation="relu")(x)
        out = Dense(2, activation="sigmoid", name="out")(x)

        model = Model(input=[dyn_inputs, seq_inputs], output=[out, aux_out])
        model.compile(optimizer="adam",
                      loss={"out": "categorical_crossentropy", "aux_out": "categorical_crossentropy"},
                      loss_weights={"out": 1., "aux_out": .2},
                      metrics=['accuracy'])
        return model
    
    def train_fn(model, train, *args, validation=None, **kwargs):
        """ train a model """
        model.fit({"data_in": train["x_2"], "code_in": train["x_seq"]},
                  {"out": train["y_2"], "aux_out": train["y_2"]},
                  nb_epoch=1,
                  batch_size=BATCH_SIZE,
                  validation_data=({"data_in": validation["x_2"], "code_in": validation["x_seq"]},
                                   {"out": validation["y_2"], "aux_out": validation["y_2"]}),
                  verbose=1,
                  shuffle=True)

    def test_fn(model, test, seed, *args, **kwargs):
        """ make predictions for test data """
        predictions = np.array(model.predict({"data_in": test["x_2"], "code_in": test["x_seq"]},
                                             batch_size=BATCH_SIZE, verbose=0))
        clipped = [np.argmax(x) for x in predictions[0]]
        return clipped

    def save_fn(outpath, model):
        """ save a trained model """
        model.save(outpath)
    
    def load_fn(inpath):
        """ load a trained model """
        return load_model(inpath)

    return {
        "name": "sally",
        "create_model": create_model,
        "train_fn": train_fn,
        "test_fn": test_fn,
        "save_fn": save_fn,
        "load_fn": load_fn
    }

# %%
def karl():
    BATCH_SIZE = 64
    EMBEDDING_VECTOR_LEN = 64
    
    def create_model(*args, data_desc=None, **kwargs):
        """ instantiate a model """ 
        atomizer = data_desc["atomizer"]
        seq_length = data_desc["seq_length"]
        vocab_size = atomizer.vocab_size + 1

        data_in = Input(shape=(2,), name="data_in")

        code_in = Input(shape=(seq_length,), dtype="int32", name="code_in")
        right = Embedding(output_dim=EMBEDDING_VECTOR_LEN, input_dim=vocab_size, input_length=seq_length)(code_in)
        right = LSTM(16, consume_less="mem")(right)

        aux_out = Dense(2, activation="sigmoid", name="aux_out")(right)

        x = merge([data_in, right], mode="concat")
        x = BatchNormalization(name="norm")(x)
        x = Dense(18, activation="relu")(x)
        out = Dense(2, activation="sigmoid", name="out")(x)

        model = Model(input=[data_in, code_in], output=[out, aux_out])
        model.compile(optimizer="adam",
                      loss={"out": "categorical_crossentropy", "aux_out": "categorical_crossentropy"},
                      loss_weights={"out": 1., "aux_out": .2},
                      metrics=['accuracy'])
        return model
    
    def train_fn(model, train, *args, validation=None, **kwargs):
        """ train a model """
        model.fit({"data_in": train["x_2"], "code_in": train["x_seq"]},
                  {"out": train["y_2"], "aux_out": train["y_2"]},
                  nb_epoch=1,
                  batch_size=BATCH_SIZE,
                  validation_data=({"data_in": validation["x_2"], "code_in": validation["x_seq"]},
                                   {"out": validation["y_2"], "aux_out": validation["y_2"]}),
                  verbose=1,
                  shuffle=True)

    def test_fn(model, test, seed, *args, **kwargs):
        """ make predictions for test data """
        predictions = np.array(model.predict({"data_in": test["x_2"], "code_in": test["x_seq"]},
                                             batch_size=BATCH_SIZE, verbose=0))
        clipped = [np.argmax(x) for x in predictions[0]]
        return clipped

    def save_fn(outpath, model):
        """ save a trained model """
        model.save(outpath)
    
    def load_fn(inpath):
        """ load a trained model """
        return load_model(inpath)

    return {
        "name": "karl",
        "create_model": create_model,
        "train_fn": train_fn,
        "test_fn": test_fn,
        "save_fn": save_fn,
        "load_fn": load_fn
    }

# %% [markdown]
# ### Model description

# %%
d = load_data_desc(platform, source="B", max_seq_len=1024, atomizer=GreedyAtomizer)
m = harry()["create_model"](data_desc=d)
# Out:
# num instances 680 (0 synthetic, 680 benchmarks)
# unique kernels 247
# vocab size 129
# pad val 129
# padded seq length 1024

# %%
m.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# code_in (InputLayer)             (None, 1024)          0
# ____________________________________________________________________________________________________
# embedding_8 (Embedding)          (None, 1024, 64)      8256        code_in[0][0]
# ____________________________________________________________________________________________________
# data_in (InputLayer)             (None, 2)             0
# ____________________________________________________________________________________________________
# lstm_9 (LSTM)                    (None, 16)            5184        embedding_8[0][0]
# ____________________________________________________________________________________________________
# dynprop_norm (BatchNormalization (None, 2)             8           data_in[0][0]
# ____________________________________________________________________________________________________
# lstm_norm (BatchNormalization)   (None, 16)            64          lstm_9[0][0]
# ____________________________________________________________________________________________________
# merge_7 (Merge)                  (None, 18)            0           dynprop_norm[0][0]
#                                                                    lstm_norm[0][0]
# ____________________________________________________________________________________________________
# dense_8 (Dense)                  (None, 18)            342         merge_7[0][0]
# ____________________________________________________________________________________________________
# out (Dense)                      (None, 2)             38          dense_8[0][0]
# ____________________________________________________________________________________________________
# aux_out (Dense)                  (None, 2)             34          lstm_norm[0][0]
# ====================================================================================================
# Total params: 13,926
# Trainable params: 13,890
# Non-trainable params: 36
# ____________________________________________________________________________________________________

# %%
SVG(model_to_dot(m, show_shapes=True).create(prog='dot', format='svg'))

# %% [markdown]
# # Evaluate

# %%
from itertools import product

def source2str(s):
    if s == "B":
        return "Benchmarks"
    elif s == "S":
        return "CLgen"
    elif s == "BS":
        return "w. CLgen"
    else:
        raise Exception
        
def model2str(m):
    if m == "zero_r":
        return "Zero-R"
    elif m == "cgo13":
        return "CGO'13"
    else:
        return m.title()

# %% [markdown]
# ### Load Data

# %%
# %run lib/preamble.py

models = ["zero_r", "cgo13", "harry"]#, "karl"]
platforms = ["amd", "nvidia"]
sources = ["B"]
atomizers = ["GreedyAtomizer"]#, "CharacterAtomizer"]
seeds = list(range(204, 214))
split = (.6, .2, .2)

data = None

for model, platform, source, atomizer, seed in product(models, platforms, sources, atomizers, seeds):
    result = load_and_test(globals().get(model)(), platform, source, 
                           split=split, atomizer=atomizer, maxlen=1024, seed=204)
    if not result:
        continue
    
    frame = result["dataframe"]
    frame["correct"] = result["correct"]
    frame["acc"] = result["correct"] * 100
    frame["p_speedup"] = result["speedups"]
    frame["p_speedup_perc"] = frame["p_speedup"] * 100
    frame["model"] = [model] * len(frame)
    frame["platform"] = [platform] * len(frame)
    frame["atomizer"] = [atomizer] * len(frame)
    frame["model_name"] = model2str(model)

    if data is None:
        data = frame
    else:
        data = pd.concat((data, frame))
        
keys = sorted(set(data["model_name"]))
benchmark_names = sorted(set(data["benchmark_name"]))

d = data.copy()

# Append aggregate "Average" rows:
for platform, atomizer in product(platforms, atomizers):
    # TODO: source B, BS
    msk = (data["platform"] == platform) & (data["atomizer"] == atomizer)
    r = data[msk].groupby('model_name').mean()
    r["source"] = ["Average"] * len(r)
    r["platform"] = [platform] * len(r)
    r["atomizer"] = [atomizer] * len(r)
    r["model_name"] = keys
    d = d.append(r)

assert(len(d[d["source"] == "Average"]) == len(list(product(platforms, sources, atomizers))) * len(keys))

# %%
# print model accuracy and speedup (per-platform)
amd_msk = (data["platform"] == "amd") & (data["atomizer"] == "GreedyAtomizer")
nvidia_msk = (data["platform"] == "nvidia") & (data["atomizer"] == "GreedyAtomizer")

print(data[["model_name", "source", "acc", "p_speedup"]].groupby("model_name").mean())
print("\nAMD:")
print(data[amd_msk][["model_name", "source", "acc", "p_speedup"]].groupby("model_name").mean())
print("\nNVIDIA:")
print(data[nvidia_msk][["model_name", "source", "acc", "p_speedup"]].groupby("model_name").mean())
# Out:
#                   acc  p_speedup
# model_name
# CGO'13      69.444444   0.830316
# Harry       78.968254   0.912409
# Zero-R      58.333333   0.793359
#
# AMD:
#                   acc  p_speedup
# model_name
# CGO'13      70.078740   0.829736
# Harry       80.314961   0.907435
# Zero-R      59.842520   0.761453
#
# NVIDIA:
#              acc  p_speedup
# model_name
# CGO'13      68.8   0.830904
# Harry       77.6   0.917463
# Zero-R      56.8   0.825776

# %%
data
# Out:
#      F1:transfer/(comp+mem)  F2:coalesced/mem  F3:(localmem/mem)*avgws  \
# 0              3.076783e+05             0.333                 0.000000
# 1              1.116878e+04             5.600                 0.000000
# 2              2.157508e+03            25.900                 0.000000
# 3              8.694247e+04             2.200                 0.000000
# 4              2.437447e+04            25.800                 0.000000
# 5              9.967740e+05             5.000                 0.000000
# 6              1.318499e+06            22.400                 0.000000
# 7              9.546236e+06             1.000                 0.000000
# 8              3.698244e+06             5.710                 0.000000
# 9              4.252902e+04            67.700                 0.000000
# 10             3.509676e+06             0.136                18.000000
# 11             4.099218e+05             1.270                 0.000000
# 12             1.349580e+05            25.800                 0.000000
# 13             4.551338e+05             0.136                10.363636
# 14             7.281778e+03             1.000                 0.000000
# 15             9.582499e+08             1.000                 0.000000
# 16             2.366664e+06             2.000                 0.000000
# 17             1.226799e+06             1.000                 0.000000
# 18             1.874807e+02            41.200                 0.000000
# 19             4.055080e+05            41.200                 0.000000
# 20             1.434835e+06            13.400                 0.000000
# 21             1.905422e+04            25.800                 0.000000
# 22             2.002858e+07             5.000                 0.000000
# 23             7.231559e+04             1.000                 0.000000
# 24             1.586700e+05             6.000                 0.000000
# 25             1.568566e+07             1.000                 0.000000
# 26             3.934146e+06             1.250                 0.000000
# 27             6.579200e+04             0.500               128.000000
# 28             2.457023e+06             1.000                 0.000000
# 29             1.570762e+06             5.600                 0.000000
# ..                      ...               ...                      ...
# 95             1.649396e+02             0.125                52.000000
# 96             4.529909e+07             1.000                 0.000000
# 97             2.115600e+05             0.273                 1.454545
# 98             1.842768e+06             1.000                 0.000000
# 99             7.498456e+07             1.000                 0.000000
# 100            7.340073e+07             1.000                 0.000000
# 101            1.113516e+05             5.000                 0.000000
# 102            2.833627e+05             5.600                 0.000000
# 103            7.498197e+05             0.000                 0.000000
# 104            8.545446e+05            67.700                 0.000000
# 105            9.489733e+06             2.000                 0.000000
# 106            8.438870e+04            10.200                 0.000000
# 107            1.597083e+08             1.000                 0.000000
# 108            1.134011e+06             1.250                 0.000000
# 109            9.968415e+05             5.000                 0.000000
# 110            1.158462e+06             0.000                 0.000000
# 111            5.428187e+05            25.900                 0.000000
# 112            9.968415e+05             5.000                 0.000000
# 113            1.390763e+05             1.000                 0.000000
# 114            2.457023e+06             1.500                 0.000000
# 115            8.123289e+04             0.000                 0.000000
# 116            1.318500e+06            22.400                 0.000000
# 117            1.027835e+04             1.500                 0.000000
# 118            1.064722e+08             1.000                 0.000000
# 119            1.421506e+07             0.182                 7.272727
# 120            7.799976e+06             0.800                 0.000000
# 121            1.351200e+05            25.800                 0.000000
# 122            1.168776e+03            33.700                 0.000000
# 123            7.046149e+06             1.000                 0.000000
# 124            6.568368e+07             2.000                 0.000000
#
#      F4:comp/mem  acc  atomic        atomizer  \
# 0         18.300    0       0  GreedyAtomizer
# 1         13.400  100       0  GreedyAtomizer
# 2         92.100  100       0  GreedyAtomizer
# 3         13.600  100       0  GreedyAtomizer
# 4         92.000  100       0  GreedyAtomizer
# 5         15.000  100       0  GreedyAtomizer
# 6         68.000  100       0  GreedyAtomizer
# 7         15.700    0       0  GreedyAtomizer
# 8         16.600    0       0  GreedyAtomizer
# 9        124.000  100       0  GreedyAtomizer
# 10         5.180    0       0  GreedyAtomizer
# 11         0.961  100       0  GreedyAtomizer
# 12        92.100  100       0  GreedyAtomizer
# 13         5.180  100       0  GreedyAtomizer
# 14         2.000  100       0  GreedyAtomizer
# 15         0.000    0       0  GreedyAtomizer
# 16        19.000  100       0  GreedyAtomizer
# 17        12.000  100       0  GreedyAtomizer
# 18       465.000  100       0  GreedyAtomizer
# 19       465.000  100       0  GreedyAtomizer
# 20       157.000    0       0  GreedyAtomizer
# 21        92.000  100       0  GreedyAtomizer
# 22        15.000    0       0  GreedyAtomizer
# 23         6.250    0       0  GreedyAtomizer
# 24        12.300  100       0  GreedyAtomizer
# 25        13.500    0       0  GreedyAtomizer
# 26         0.625  100       0  GreedyAtomizer
# 27         0.000  100       0  GreedyAtomizer
# 28         0.200  100       0  GreedyAtomizer
# 29        13.400  100       0  GreedyAtomizer
# ..           ...  ...     ...             ...
# 95         8.310  100       0  GreedyAtomizer
# 96        13.500  100       0  GreedyAtomizer
# 97         1.730  100       0  GreedyAtomizer
# 98         1.000  100       0  GreedyAtomizer
# 99        15.700  100       0  GreedyAtomizer
# 100        1.000  100       0  GreedyAtomizer
# 101       18.000  100       0  GreedyAtomizer
# 102       13.400  100       0  GreedyAtomizer
# 103        9.530  100       0  GreedyAtomizer
# 104      124.000  100       0  GreedyAtomizer
# 105       19.000    0       0  GreedyAtomizer
# 106       30.500  100       0  GreedyAtomizer
# 107        0.200  100       0  GreedyAtomizer
# 108        0.625  100       0  GreedyAtomizer
# 109       15.000  100       0  GreedyAtomizer
# 110        3.830  100       0  GreedyAtomizer
# 111       92.100  100       0  GreedyAtomizer
# 112       15.000    0       0  GreedyAtomizer
# 113       12.000  100       0  GreedyAtomizer
# 114        0.500  100       0  GreedyAtomizer
# 115        3.960  100       0  GreedyAtomizer
# 116       68.000    0       0  GreedyAtomizer
# 117       16.000  100       0  GreedyAtomizer
# 118        0.800  100       0  GreedyAtomizer
# 119        1.910  100       0  GreedyAtomizer
# 120        0.000    0       0  GreedyAtomizer
# 121       92.000    0       0  GreedyAtomizer
# 122       98.700  100       0  GreedyAtomizer
# 123        0.000  100       0  GreedyAtomizer
# 124       19.000  100       0  GreedyAtomizer
#
#                                              benchmark  \
# 0                          parboil-0.2-sad-mb_sad_calc
# 1                               npb-3.3-SP-initialize3
# 2                                   npb-3.3-BT-y_solve
# 3                                       npb-3.3-LU-rhs
# 4                                   npb-3.3-SP-z_solve
# 5                                  npb-3.3-BT-y_solve2
# 6                                npb-3.3-SP-exact_rhs3
# 7                            npb-3.3-MG-kernel_zran3_1
# 8                               npb-3.3-SP-initialize2
# 9                                  npb-3.3-BT-x_solve3
# 10                             npb-3.3-MG-kernel_psinv
# 11                           npb-3.3-MG-kernel_zran3_2
# 12                                  npb-3.3-SP-x_solve
# 13                             npb-3.3-MG-kernel_psinv
# 14             amd-app-sdk-3.0-BitonicSort-bitonicSort
# 15                               npb-3.3-CG-init_mem_1
# 16                                    npb-3.3-LU-ssor2
# 17                               npb-3.3-BT-exact_rhs1
# 18                                     npb-3.3-LU-blts
# 19                                     npb-3.3-LU-blts
# 20                             npb-3.3-SP-compute_rhs4
# 21                                  npb-3.3-BT-z_solve
# 22                                 npb-3.3-BT-x_solve2
# 23                    parboil-0.2-stencil-naive_kernel
# 24                                  npb-3.3-LU-pintgr1
# 25                             npb-3.3-SP-compute_rhs2
# 26                                  npb-3.3-CG-makea_6
# 27       amd-app-sdk-3.0-ScanLargeArrays-blockAddition
# 28                              npb-3.3-CG-conj_grad_0
# 29                              npb-3.3-SP-initialize3
# ..                                                 ...
# 95                                    npb-3.3-EP-embar
# 96                             npb-3.3-BT-compute_rhs2
# 97                                   npb-3.3-LU-l2norm
# 98                                   npb-3.3-CG-main_0
# 99                           npb-3.3-MG-kernel_zran3_1
# 100         nvidia-4.2-MatVecMul-MatVecMulUncoalesced1
# 101                                   npb-3.3-LU-erhs1
# 102                             npb-3.3-SP-initialize5
# 103  polybench-gpu-1.0-3DConvolution-Convolution3D_...
# 104                                npb-3.3-BT-y_solve3
# 105                                   npb-3.3-LU-ssor2
# 106                                npb-3.3-BT-y_solve1
# 107                             npb-3.3-CG-conj_grad_0
# 108                                 npb-3.3-CG-makea_6
# 109                                npb-3.3-BT-x_solve2
# 110          polybench-gpu-1.0-covariance-covar_kernel
# 111                                 npb-3.3-SP-y_solve
# 112                                npb-3.3-BT-z_solve2
# 113                             npb-3.3-BT-initialize1
# 114                                 npb-3.3-CG-makea_5
# 115                        shoc-1.1.5-S3D-ratt4_kernel
# 116                              npb-3.3-SP-exact_rhs2
# 117                                   npb-3.3-LU-ssor3
# 118                                 npb-3.3-CG-makea_2
# 119                                npb-3.3-SP-rhs_norm
# 120                              rodinia-3.1-bfs-BFS_2
# 121                                 npb-3.3-SP-z_solve
# 122                                   npb-3.3-LU-erhs3
# 123                                 npb-3.3-FT-init_ui
# 124                              npb-3.3-BT-exact_rhs5
#
#               benchmark_name  coalesced   ...    runtime_gpu  \
# 0                Parboil.sad          1   ...      11.152674
# 1                     NPB.SP         28   ...       0.688001
# 2                     NPB.BT        233   ...      10.234726
# 3                     NPB.LU         11   ...       0.986529
# 4                     NPB.SP        232   ...       0.968433
# 5                     NPB.BT          5   ...       0.573194
# 6                     NPB.SP        112   ...      31.711105
# 7                     NPB.MG          3   ...     186.010002
# 8                     NPB.SP         40   ...       3.589209
# 9                     NPB.BT        203   ...       1.502929
# 10                    NPB.MG          3   ...     163.812356
# 11                    NPB.MG         98   ...      57.828688
# 12                    NPB.SP        232   ...       6.511391
# 13                    NPB.MG          3   ...      42.666478
# 14           AMD.BitonicSort          6   ...       0.279521
# 15                    NPB.CG          1   ...       0.702439
# 16                    NPB.LU          2   ...       1.267649
# 17                    NPB.BT          1   ...       0.778053
# 18                    NPB.LU        165   ...       0.728075
# 19                    NPB.LU        165   ...       1.908393
# 20                    NPB.SP        107   ...       6.887197
# 21                    NPB.BT        232   ...       1.231435
# 22                    NPB.BT          5   ...       1.109938
# 23           Parboil.stencil          8   ...       4.350399
# 24                    NPB.LU         18   ...       1.122311
# 25                    NPB.SP          2   ...       1.415713
# 26                    NPB.CG         10   ...       5.085740
# 27       AMD.ScanLargeArrays          2   ...       0.434674
# 28                    NPB.CG          5   ...       0.565011
# 29                    NPB.SP         28   ...       1.003805
# ..                       ...        ...   ...            ...
# 95                    NPB.EP          2   ...    1652.365248
# 96                    NPB.BT          2   ...       0.744014
# 97                    NPB.LU          3   ...       0.685822
# 98                    NPB.CG          4   ...       0.082490
# 99                    NPB.MG          3   ...    7292.702125
# 100         NVIDIA.MatVecMul          3   ...     306.494944
# 101                   NPB.LU         15   ...       0.279309
# 102                   NPB.SP         28   ...       0.091546
# 103  Polybench.3DConvolution          0   ...     130.420241
# 104                   NPB.BT        203   ...      29.463351
# 105                   NPB.LU          2   ...       0.876705
# 106                   NPB.BT         61   ...       0.301511
# 107                   NPB.CG          5   ...       0.079238
# 108                   NPB.CG         10   ...       1.218061
# 109                   NPB.BT          5   ...       0.089388
# 110     Polybench.covariance          0   ...    2185.144691
# 111                   NPB.SP        233   ...      24.087671
# 112                   NPB.BT          5   ...       0.089533
# 113                   NPB.BT          1   ...       0.084941
# 114                   NPB.CG          6   ...       0.100998
# 115                 SHOC.S3D          0   ...      13.741799
# 116                   NPB.SP        112   ...      41.020762
# 117                   NPB.LU          3   ...       0.161327
# 118                   NPB.CG          5   ...       0.160998
# 119                   NPB.SP          2   ...       5.600954
# 120              Rodinia.bfs          4   ...      33.588006
# 121                   NPB.SP        232   ...       4.111482
# 122                   NPB.LU        101   ...       0.273395
# 123                   NPB.FT          3   ...       0.290554
# 124                   NPB.BT          2   ...       0.856083
#
#                                                    seq seq_len     source  \
# 0    [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     785    Parboil
# 1    [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     475        NPB
# 2    [102, 51, 20, 52, 51, 20, 52, 11, 1, 103, 51, ...    1123        NPB
# 3    [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     853        NPB
# 4    [63, 76, 51, 17, 52, 26, 0, 2, 63, 73, 51, 18,...   16387        NPB
# 5    [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     425        NPB
# 6    [8, 8, 1, 9, 1, 7, 20, 13, 15, 1, 9, 1, 123, 5...    4071        NPB
# 7    [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     261        NPB
# 8    [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     818        NPB
# 9    [0, 2, 102, 51, 82, 52, 51, 17, 52, 51, 18, 52...    4648        NPB
# 10   [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     787        NPB
# 11   [129, 129, 129, 129, 129, 129, 129, 129, 129, ...    1010        NPB
# 12   [51, 17, 52, 26, 0, 2, 63, 73, 51, 18, 52, 1, ...   16587        NPB
# 13   [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     787        NPB
# 14   [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     363        AMD
# 15   [129, 129, 129, 129, 129, 129, 129, 129, 129, ...      65        NPB
# 16   [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     316        NPB
# 17   [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     259        NPB
# 18   [51, 16, 52, 1, 9, 1, 117, 26, 0, 0, 2, 117, 1...   17366        NPB
# 19   [51, 16, 52, 1, 9, 1, 117, 26, 0, 0, 2, 117, 1...   17366        NPB
# 20   [16, 8, 8, 1, 9, 1, 7, 16, 13, 15, 1, 14, 1, 7...   14291        NPB
# 21   [75, 1, 102, 51, 20, 52, 51, 20, 52, 11, 1, 10...    1121        NPB
# 22   [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     425        NPB
# 23   [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     422    Parboil
# 24   [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     646        NPB
# 25   [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     406        NPB
# 26   [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     281        NPB
# 27   [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     143        AMD
# 28   [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     149        NPB
# 29   [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     475        NPB
# ..                                                 ...     ...        ...
# 95   [2, 81, 1, 7, 94, 1, 28, 1, 15, 26, 1, 94, 1, ...    1218        NPB
# 96   [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     375        NPB
# 97   [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     653        NPB
# 98   [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     159        NPB
# 99   [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     261        NPB
# 100  [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     182     NVIDIA
# 101  [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     701        NPB
# 102  [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     475        NPB
# 103  [1, 10, 17, 26, 0, 2, 96, 1, 28, 1, 10, 20, 26...    1129  Polybench
# 104  [0, 2, 102, 51, 89, 52, 51, 17, 52, 51, 18, 52...    4648        NPB
# 105  [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     316        NPB
# 106  [52, 51, 15, 52, 1, 28, 1, 15, 13, 15, 26, 0, ...    2651        NPB
# 107  [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     149        NPB
# 108  [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     281        NPB
# 109  [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     425        NPB
# 110  [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     312  Polybench
# 111  [51, 18, 52, 1, 28, 1, 65, 65, 51, 103, 52, 51...   16597        NPB
# 112  [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     425        NPB
# 113  [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     273        NPB
# 114  [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     282        NPB
# 115  [7, 22, 16, 8, 1, 12, 1, 16, 8, 1, 9, 1, 7, 23...    6048       SHOC
# 116  [8, 8, 1, 9, 1, 7, 20, 13, 15, 1, 9, 1, 123, 5...    4072        NPB
# 117  [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     436        NPB
# 118  [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     265        NPB
# 119  [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     650        NPB
# 120  [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     131    Rodinia
# 121  [63, 76, 51, 17, 52, 26, 0, 2, 63, 73, 51, 18,...   16387        NPB
# 122  [7, 16, 13, 15, 1, 14, 1, 7, 16, 17, 1, 12, 1,...    3762        NPB
# 123  [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     114        NPB
# 124  [129, 129, 129, 129, 129, 129, 129, 129, 129, ...     303        NPB
#
#      speedup                                                src src_len  \
# 0       4.72  __kernel void A(__global unsigned short* a, __...    1029
# 1       6.89  __kernel void A(__global double* a, __global d...     624
# 2      44.81  __kernel void A(__global double* a, __global d...    1347
# 3       3.91  __kernel void A(__global double* a, __global d...    1125
# 4       1.79  __kernel void A(__global double* a, __global d...   17654
# 5       3.89  __kernel void A(__global double* a, int b, int...     560
# 6       1.76  __kernel void A(__global double* a, __global d...    4605
# 7       1.35  __kernel void A(__global double* a, __global d...     368
# 8      11.15  __kernel void A(__global double* a, __global d...    1024
# 9       1.84  __kernel void A(__global double* a, __global d...    4931
# 10      1.31  __kernel void A(__global double* a, __global d...     935
# 11      1.88  __kernel void A(__global double* a, __global d...    1321
# 12      1.25  __kernel void A(__global double* a, __global d...   17854
# 13      1.37  __kernel void A(__global double* a, __global d...     935
# 14      2.29  __kernel void A(__global uint* a, const uint b...     494
# 15     42.12  __kernel void A(__global double* a, int b) {\n...     114
# 16      1.74  __kernel void A(__global double* a, double b, ...     432
# 17      3.78  __kernel void A(__global double* a, int b, int...     375
# 18      6.89  __kernel void A(__global double* a, __global d...   17872
# 19      2.72  __kernel void A(__global double* a, __global d...   17872
# 20     11.61  __kernel void A(__global const double* a, __gl...   15764
# 21      1.29  __kernel void A(__global double* a, __global d...    1345
# 22      1.01  __kernel void A(__global double* a, int b, int...     560
# 23      1.11  __kernel void A(float a, float b, __global flo...     518
# 24      8.70  __kernel void A(__global double* a, __global d...     821
# 25      5.08  __kernel void A(__global const double* a, __gl...     557
# 26      1.25  __kernel void A(__global double* a, __global d...     408
# 27      2.95  __kernel void A(__global float* a, __global fl...     231
# 28      4.76  __kernel void A(__global double* a, __global d...     253
# 29      7.33  __kernel void A(__global double* a, __global d...     624
# ..       ...                                                ...     ...
# 95      8.08  __kernel void A(__local double* a, __local dou...    1615
# 96     10.09  __kernel void A(__global const double* a, __gl...     526
# 97      3.87  __kernel void A(__global double* a, __global d...     892
# 98      8.16  __kernel void A(__global int* a, __global int*...     236
# 99      3.16  __kernel void A(__global double* a, __global d...     368
# 100     2.05  __kernel void A(const __global float* a, const...     307
# 101     2.51  __kernel void A(__global double* a, __global d...     911
# 102     1.02  __kernel void A(__global double* a, __global d...     624
# 103     2.12  __kernel void A(__global float* a, __global fl...    1240
# 104     1.36  __kernel void A(__global double* a, __global d...    4931
# 105     5.20  __kernel void A(__global double* a, double b, ...     432
# 106     1.92  __kernel void A(__global double* a, __global d...    3016
# 107     3.03  __kernel void A(__global double* a, __global d...     253
# 108     1.09  __kernel void A(__global double* a, __global d...     408
# 109     1.88  __kernel void A(__global double* a, int b, int...     560
# 110     2.52  __kernel void A(__global float* a, __global fl...     393
# 111     1.01  __kernel void A(__global double* a, __global d...   17864
# 112     1.62  __kernel void A(__global double* a, int b, int...     560
# 113     1.39  __kernel void A(__global double* a, int b, int...     377
# 114     1.24  __kernel void A(__global int* a, __global int*...     421
# 115     2.17  __kernel void A(__global const float* a, __glo...    7939
# 116     1.16  __kernel void A(__global double* a, __global d...    4606
# 117     1.29  __kernel void A(__global double* a, __global d...     590
# 118     1.15  __kernel void A(__global int* a, __global int*...     382
# 119     2.05  __kernel void A(__global double* a, __global d...     895
# 120     2.65  __kernel void A(__global char* a, __global cha...     226
# 121     1.40  __kernel void A(__global double* a, __global d...   17654
# 122     1.38  __kernel void A(__global double* a, __global d...    4069
# 123    73.62  __kernel void A(__global double* a, __global d...     199
# 124     5.58  __kernel void A(__global double* a, int b, int...     419
#
#     synthetic    transfer  wgsize
# 0           0    17845344      61
# 1           0      804152      60
# 2           0     1807992      60
# 3           0     6346800      33
# 4           0    20401432      34
# 5           0    15948384      44
# 6           0   454882072      32
# 7           0   477311792       4
# 8           0   454884072      32
# 9           0    15948384      44
# 10          0   477315888      66
# 11          0    61898192       4
# 12          0   113094832      62
# 13          0    61898192      38
# 14          0      131072     256
# 15          0   958249884     256
# 16          0    47333288      62
# 17          0    15948384      48
# 18          0      349464      40
# 19          0   755866968      60
# 20          0  1815066672      64
# 21          0    15948384      44
# 22          0   320457304      64
# 23          0     4194304     256
# 24          0     6346800      62
# 25          0   454884072      32
# 26          0    51143900     128
# 27          0      263168     256
# 28          0    14742140     128
# 29          0   113094832      64
# ..        ...         ...     ...
# 95          0       24576      64
# 96          0  1313673512      32
# 97          0     6346800       2
# 98          0    14742140      64
# 99          0  3749228176       4
# 100         0   440404400     256
# 101         0     6347040      33
# 102         0    20402112      36
# 103         0   134217728     256
# 104         0   320454224      62
# 105         0   189794664      32
# 106         0    15949464      48
# 107         0   958249884     128
# 108         0    14742140     128
# 109         0    15949464      44
# 110         0    33595404     256
# 111         0   454882072      32
# 112         0    15949464      44
# 113         0     1807992      60
# 114         0    14742140      32
# 115         0    57594120     128
# 116         0   454882552      32
# 117         0      349464      60
# 118         0   958249884      32
# 119         0   454882072      10
# 120         0    38999881     256
# 121         0   113095432      62
# 122         0      349464      60
# 123         0    21138448      64
# 124         0  1313673512      32
#
# [7560 rows x 36 columns]

# %%
order = ["AMD", "NPB", "NVIDIA", "Parboil", "Polybench", "Rodinia", "SHOC", "Average"]
model_palette = sns.cubehelix_palette(len(keys), rot=1.8, light=.85, dark=.35)

def plot_ex1_graph(x="source", y="acc", hue="model_name", order=order, palette=model_palette,
                   data=data, atomizer="CharacterAtomizer", ylabel="Accuracy (%)"):
    for i, platform in enumerate(["amd", "nvidia"]):
        plt.subplot(2, 1, i + 1)
        msk = (data["platform"] == platform) & (data["atomizer"] == atomizer)
        ax = sns.barplot(x=x, y=y, hue=hue, order=order, palette=model_palette,
                         data=data[msk],
                         ci=95, errwidth=1, capsize=.08)

        plt.ylim((0, 100))
        plt.ylabel(ylabel)
        plt.xlabel("")
        
        # vertical divider for "Average" column
        plt.axvline(x=plt.xlim()[1] - 1, color="k", lw=1, linestyle="--")
        
        # legend
        plt.legend(loc='upper left', bbox_to_anchor=(1,1))
        ax.get_legend().set_title("")  # no legend title
        ax.get_legend().draw_frame(True)

        print(len(set(data[msk]["benchmark_name"])))
        
        plt.title("{platform} Platform".format(platform=platform.upper()))
        viz.finalise(figsize=(9,2.7))

# %%
for atomizer in ["GreedyAtomizer"]:
    print("Atomizer:", atomizer)
    plot_ex1_graph(x="benchmark_name", y="acc", data=d, order=benchmark_names, atomizer=atomizer)
# Out:
# Atomizer: GreedyAtomizer
# 27
# 24

# %% [markdown]
# ### Performance (% optimal)

# %%
for atomizer in ["GreedyAtomizer"]:
    print("Atomizer:", atomizer)
    plot_ex1_graph(x="benchmark_name", y="p_speedup_perc", ylabel="Performance\n(% optimal)", order=benchmark_names, data=d, atomizer=atomizer)
# Out:
# Atomizer: GreedyAtomizer
# 27
# 24

# %% [markdown]
# ### Data splits

# %%
# %run lib/preamble.py
d = load_data_desc("amd", "B", 1024, atomizer=CharacterAtomizer)
frame = d["dataframe"]

x = get_train_validation_test_splits(frame, seed=204)

plt.subplot(4, 1, 1)
sns.countplot(x="source", data=frame)
plt.subplot(4, 1, 2)
sns.countplot(x="benchmark_name", data=x[0])
plt.subplot(4, 1, 3)
sns.countplot(x="benchmark_name", data=x[1])
plt.subplot(4, 1, 4)
sns.countplot(x="benchmark_name", data=x[2])
viz.finalise(figsize=(11,10))
# Out:
# num instances 680 (0 synthetic, 680 benchmarks)
# unique kernels 247
# vocab size 84
# pad val 84
# padded seq length 1024
